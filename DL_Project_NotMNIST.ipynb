# %%
# Torch Imports
import torch, torchvision
import torch.nn as nn
import torchvision.transforms as T
from torch.utils.data import Dataset, DataLoader

# PLiNIO imports
from plinio.methods import PIT, SuperNet
from plinio.methods.mps import MPS, MPSType, get_default_qinfo
from plinio.methods.supernet import SuperNetModule
from plinio.cost import params, ops, params_bit, ops_bit
from plinio.regularizers import DUCCIO

# Stats imports
# import pandas as pd
import matplotlib.pyplot as plt

# Utils imports
import utils
import os
from PIL import Image, UnidentifiedImageError
from copy import deepcopy as dc
from glob import glob

# %%
# Setup device agnostic code
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# # 1. Dataset and DataLoader

# %%
# Transforms: we need to upscale our images
transforms = T.Compose([T.Resize([224,224]), T.ToTensor()])

# %%
image_folders = glob('.\Datasets\\notMNIST_large\*')

# Image classes available
image_folders
# Out:
# ['.\\Datasets\\notMNIST_large\\A',
#  '.\\Datasets\\notMNIST_large\\B',
#  '.\\Datasets\\notMNIST_large\\C',
#  '.\\Datasets\\notMNIST_large\\D',
#  '.\\Datasets\\notMNIST_large\\E',
#  '.\\Datasets\\notMNIST_large\\F',
#  '.\\Datasets\\notMNIST_large\\G',
#  '.\\Datasets\\notMNIST_large\\H',
#  '.\\Datasets\\notMNIST_large\\I',
#  '.\\Datasets\\notMNIST_large\\J']

# %%
# Dictionary: class names to idx
NotMNIST_class_dict = {
    'A': 0,
    'B': 1,
    'C': 2,
    'D': 3,
    'E': 4,
    'F': 5,
    'G': 6,
    'H': 7,
    'I': 8,
    'J': 9
}

# %%
# Train/test split percentage
NUN_SAMPLES = 6999
TRAIN_IDX = 5999

train_samples, train_labels = [], []
test_samples, test_labels = [], []
for folder in sorted(image_folders):
    # Sample label
    label = folder.split('\\')[-1]

    image_paths = glob(f'{folder}/*')
    for i, img_path in enumerate(image_paths):
        if i > NUN_SAMPLES: break
        
        try:
            # Apply transforms to the image
            img = transforms(Image.open(img_path)).unsqueeze(0)

            # Append to train or test set
            if i <= TRAIN_IDX:
                train_samples.append(img)
                train_labels.append(NotMNIST_class_dict[label])
            else:
                test_samples.append(img)
                test_labels.append(NotMNIST_class_dict[label])
        except UnidentifiedImageError as e:
            # Corrupted image detected
            print(f'Corrupted image. Removing {img_path}...')
            os.remove(img_path)

train_samples = torch.cat(train_samples)
test_samples = torch.cat(test_samples)

# %%
class NotMNISTDataset(Dataset):
    def __init__(self, X, y, class_dict):
        super().__init__()
        self.X = X
        self.y = y
        self.class_to_idx = class_dict
        self.classes = list(self.class_to_idx.keys())

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# 1. Training set
train_dataset = NotMNISTDataset(train_samples, train_labels, NotMNIST_class_dict)

# 2. Test set
test_dataset = NotMNISTDataset(test_samples, test_labels, NotMNIST_class_dict)

# %%
# Information about the dataset
random_sample = train_dataset[torch.randint(0, len(train_dataset), size=[1]).item()][0]
class_names = train_dataset.classes

print(f'#Training samples: {len(train_dataset)}')
print(f'#Test samples: {len(test_dataset)}')

print(f'\n#Classes: {len(class_names)}')
print(f'List of classes: {class_names}')

print(f'\nData shape: {random_sample.shape}')
# Out:
# #Training samples: 60000
# #Test samples: 10000
#
# #Classes: 10
# List of classes: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']
#
# Data shape: torch.Size([1, 224, 224])

# %%
torch.manual_seed(42)
ROWS, COLS = 4, 4

# Data visualization
fig = plt.figure(figsize=[9, 9])
for i in range(1, ROWS*COLS+1):
    random_idx = torch.randint(0, len(train_dataset), size=[1]).item()
    img, label = train_dataset[random_idx]
    fig.add_subplot(ROWS, COLS, i)
    plt.imshow(img.squeeze(), cmap='gray')
    plt.title(class_names[label])
    plt.axis(False)

# %%
BATCH_SIZE = 16

# 1. Training data loader
train_dataloader = DataLoader(
    dataset=train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    pin_memory=True,
    num_workers=0
)

# 2. Testing data loader
test_dataloader = DataLoader(
    dataset=test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    pin_memory=True,
    num_workers=0
)

print(f'Created {len(train_dataloader)} training batches of {BATCH_SIZE} samples.')
print(f'Created {len(test_dataloader)} testing batches of {BATCH_SIZE} samples.')
# Out:
# Created 3750 training batches of 16 samples.
# Created 625 testing batches of 16 samples.

# %% [markdown]
# # 2. VGG16 Model

# %%
torch.manual_seed(42)

# Load the PyTorch model
model = torchvision.models.vgg16()

# Model structure
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# We are working with gray scale images
num_channels = train_dataset[0][0].shape[0]
print(f'#Channels of our images: {num_channels}')
# Out:
# #Channels of our images: 1

# %%
torch.manual_seed(42)

# We need to change the 1st convolutional layer
old_layer = model.features[0]
new_layer = nn.Conv2d(num_channels, 64, kernel_size=3, stride=1, padding=1)
model.features[0] = new_layer

print(f'Old layer: {old_layer}')
print(f'New layer: {new_layer}')
# Out:
# Old layer: Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# New layer: Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))

# %%
torch.manual_seed(42)

# We need to change the last fully connected layer to output 10 values
old_fc = model.classifier[-1]
new_fc = nn.Linear(in_features=4096, out_features=len(class_names))
model.classifier[-1] = new_fc

print(f'Old layer: {old_fc}')
print(f'New layer: {new_fc}')
# Out:
# Old layer: Linear(in_features=4096, out_features=1000, bias=True)
# New layer: Linear(in_features=4096, out_features=10, bias=True)

# %%
# New model
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
# Save the model starting point for opitmization
torch.save(model, './Models_checkpoints/notMNIST/VGG16_notMNIST_Init.pth')

# %% [markdown]
# # 3. Traning loops

# %% [markdown]
# ## 3.1 Model without optimization

# %%
# Setup optimizer and loss function
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train the standard model
NoOpt_results = utils.train_model(
    model=model,
    data_loader=train_dataloader,
    device=device,
    loss_fn=loss_fn,
    optimizer=optimizer
)

print(f"Total training time (on {NoOpt_results['device']}): {NoOpt_results['total_time']:.3f} seconds.")
print(f"Avg training time (on {NoOpt_results['device']}): {(NoOpt_results['total_time']//3)} seconds.")
# Out:
# ********************
# EPOCH 0
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 2.13749 | Avg Accuracy: 23.41%
# Computed 999/3750 batches - Avg Loss: 1.57429 | Avg Accuracy: 46.99%
# Computed 1499/3750 batches - Avg Loss: 1.30635 | Avg Accuracy: 57.44%
# Computed 1999/3750 batches - Avg Loss: 1.14973 | Avg Accuracy: 63.26%
# Computed 2499/3750 batches - Avg Loss: 1.04856 | Avg Accuracy: 66.96%
# Computed 2999/3750 batches - Avg Loss: 0.97117 | Avg Accuracy: 69.66%
# Computed 3499/3750 batches - Avg Loss: 0.91246 | Avg Accuracy: 71.74%
#
# End of EPOCH 0 - Avg Loss: 0.88750 | Avg Accuracy: 72.57%
# Training time: 661.472 seconds.
# ********************
#
# ********************
# EPOCH 1
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.52610 | Avg Accuracy: 85.33%
# Computed 999/3750 batches - Avg Loss: 0.51625 | Avg Accuracy: 85.56%
# Computed 1499/3750 batches - Avg Loss: 0.50345 | Avg Accuracy: 85.82%
# Computed 1999/3750 batches - Avg Loss: 0.49832 | Avg Accuracy: 85.86%
# Computed 2499/3750 batches - Avg Loss: 0.49223 | Avg Accuracy: 85.95%
# Computed 2999/3750 batches - Avg Loss: 0.48767 | Avg Accuracy: 86.07%
# Computed 3499/3750 batches - Avg Loss: 0.48055 | Avg Accuracy: 86.25%
#
# End of EPOCH 1 - Avg Loss: 0.47731 | Avg Accuracy: 86.28%
# Training time: 657.133 seconds.
# ********************
#
# ********************
# EPOCH 2
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.42629 | Avg Accuracy: 87.83%
# Computed 999/3750 batches - Avg Loss: 0.42261 | Avg Accuracy: 87.78%
# Computed 1499/3750 batches - Avg Loss: 0.42439 | Avg Accuracy: 87.75%
# Computed 1999/3750 batches - Avg Loss: 0.42045 | Avg Accuracy: 87.82%
# Computed 2499/3750 batches - Avg Loss: 0.41687 | Avg Accuracy: 87.93%
# Computed 2999/3750 batches - Avg Loss: 0.41344 | Avg Accuracy: 88.07%
# Computed 3499/3750 batches - Avg Loss: 0.41032 | Avg Accuracy: 88.10%
#
# End of EPOCH 2 - Avg Loss: 0.40932 | Avg Accuracy: 88.14%
# Training time: 654.214 seconds.
# ********************
#
# ********************
# EPOCH 3
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.37277 | Avg Accuracy: 89.09%
# Computed 999/3750 batches - Avg Loss: 0.37699 | Avg Accuracy: 88.95%
# Computed 1499/3750 batches - Avg Loss: 0.36821 | Avg Accuracy: 89.23%
# Computed 1999/3750 batches - Avg Loss: 0.36667 | Avg Accuracy: 89.29%
# Computed 2499/3750 batches - Avg Loss: 0.36596 | Avg Accuracy: 89.31%
# Computed 2999/3750 batches - Avg Loss: 0.36481 | Avg Accuracy: 89.35%
# Computed 3499/3750 batches - Avg Loss: 0.36575 | Avg Accuracy: 89.29%
#
# End of EPOCH 3 - Avg Loss: 0.36617 | Avg Accuracy: 89.24%
# Training time: 653.399 seconds.
# ********************
#
# ********************
# EPOCH 4
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.34185 | Avg Accuracy: 90.19%
# Computed 999/3750 batches - Avg Loss: 0.34221 | Avg Accuracy: 90.02%
# Computed 1499/3750 batches - Avg Loss: 0.34039 | Avg Accuracy: 90.01%
# Computed 1999/3750 batches - Avg Loss: 0.34743 | Avg Accuracy: 89.78%
# Computed 2499/3750 batches - Avg Loss: 0.34431 | Avg Accuracy: 89.89%
# Computed 2999/3750 batches - Avg Loss: 0.34513 | Avg Accuracy: 89.83%
# Computed 3499/3750 batches - Avg Loss: 0.34263 | Avg Accuracy: 89.88%
#
# End of EPOCH 4 - Avg Loss: 0.34143 | Avg Accuracy: 89.91%
# Training time: 656.096 seconds.
# ********************
#
# Total training time (on cuda): 3282.313 seconds.
# Avg training time (on cuda): 1094.0 seconds.

# %%
# Save the trained model weights as checkpoint
torch.save(model, './Models_checkpoints/notMNIST/VGG16_notMNIST_NoOpt.pth')

# %% [markdown]
# ## 3.2 Models with optimization
#
# In the following sections, the standard training loop will be modified with **PLiNIO** cost specifications, depending on the applied optimization method.

# %% [markdown]
# ### 3.2.1 Pruning In Time (**PIT**)

# %%
# Load VGG16 initialization
PIT_init = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_Init.pth')

# Create PIT PLiNIO model object with parameters cost
PIT_model = PIT(model=PIT_init, input_shape=torch.Size([1,224,244]), cost={'size': params})
initial_size = PIT_model.get_cost('size').item()

print(f'#Parameters before PIT optimization: {int(initial_size)}')
# Out:
# #Parameters before PIT optimization: 134300368

# %%
# Setup loss_fn and regularizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=PIT_model.parameters(), lr=0.001)

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train the model with PIT optimization
PIT_results = utils.train_model(
    model=PIT_model,
    data_loader=train_dataloader,
    device=device,
    loss_fn=loss_fn,
    optimizer=optimizer,
    optim_method='PIT',
    cost_strength={'size': 1e-6}
)

print(f"Total training time (on {PIT_results['device']}): {PIT_results['total_time']:.3f} seconds.")
print(f"Avg training time (on {PIT_results['device']}): {(PIT_results['total_time']//3)} seconds.")
# Out:
# ********************
# EPOCH 0
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 130.48083 | Avg Accuracy: 23.27%
# Computed 999/3750 batches - Avg Loss: 123.75104 | Avg Accuracy: 46.94%
# Computed 1499/3750 batches - Avg Loss: 117.57865 | Avg Accuracy: 57.42%
# Computed 1999/3750 batches - Avg Loss: 111.70215 | Avg Accuracy: 63.27%
# Computed 2499/3750 batches - Avg Loss: 106.03816 | Avg Accuracy: 66.99%
# Computed 2999/3750 batches - Avg Loss: 100.66087 | Avg Accuracy: 65.48%
# Computed 3499/3750 batches - Avg Loss: 95.32305 | Avg Accuracy: 67.37%
#
# End of EPOCH 0 - Avg Loss: 92.67039 | Avg Accuracy: 68.27%
# Training time: 706.049 seconds.
#
# #Parameters after EPOCH 0: 52815968
# ********************
#
# ********************
# EPOCH 1
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 48.80189 | Avg Accuracy: 81.79%
# Computed 999/3750 batches - Avg Loss: 44.02430 | Avg Accuracy: 82.53%
# Computed 1499/3750 batches - Avg Loss: 39.39478 | Avg Accuracy: 82.94%
# Computed 1999/3750 batches - Avg Loss: 36.33380 | Avg Accuracy: 83.26%
# Computed 2499/3750 batches - Avg Loss: 34.46345 | Avg Accuracy: 83.49%
# Computed 2999/3750 batches - Avg Loss: 33.19204 | Avg Accuracy: 83.66%
# Computed 3499/3750 batches - Avg Loss: 32.25745 | Avg Accuracy: 83.90%
#
# End of EPOCH 1 - Avg Loss: 31.86867 | Avg Accuracy: 83.97%
# Training time: 699.089 seconds.
#
# #Parameters after EPOCH 1: 26009234
# ********************
#
# ********************
# EPOCH 2
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 26.48100 | Avg Accuracy: 86.15%
# Computed 999/3750 batches - Avg Loss: 26.37735 | Avg Accuracy: 86.09%
# Computed 1499/3750 batches - Avg Loss: 26.29919 | Avg Accuracy: 85.89%
# Computed 1999/3750 batches - Avg Loss: 26.21752 | Avg Accuracy: 85.94%
# Computed 2499/3750 batches - Avg Loss: 26.14141 | Avg Accuracy: 86.01%
# Computed 2999/3750 batches - Avg Loss: 26.06389 | Avg Accuracy: 86.09%
# Computed 3499/3750 batches - Avg Loss: 25.98878 | Avg Accuracy: 86.15%
#
# End of EPOCH 2 - Avg Loss: 25.94502 | Avg Accuracy: 86.18%
# Training time: 708.490 seconds.
#
# #Parameters after EPOCH 2: 24946582
# ********************
#
# ********************
# EPOCH 3
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 25.36404 | Avg Accuracy: 87.55%
# Computed 999/3750 batches - Avg Loss: 25.27253 | Avg Accuracy: 87.27%
# Computed 1499/3750 batches - Avg Loss: 25.18750 | Avg Accuracy: 87.42%
# Computed 1999/3750 batches - Avg Loss: 25.11445 | Avg Accuracy: 87.43%
# Computed 2499/3750 batches - Avg Loss: 25.04177 | Avg Accuracy: 87.40%
# Computed 2999/3750 batches - Avg Loss: 24.97178 | Avg Accuracy: 87.49%
# Computed 3499/3750 batches - Avg Loss: 24.90435 | Avg Accuracy: 87.42%
#
# End of EPOCH 3 - Avg Loss: 24.86340 | Avg Accuracy: 87.43%
# Training time: 700.424 seconds.
#
# #Parameters after EPOCH 3: 23931902
# ********************
#
# ********************
# EPOCH 4
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 24.31483 | Avg Accuracy: 87.99%
# Computed 999/3750 batches - Avg Loss: 24.22974 | Avg Accuracy: 87.94%
# Computed 1499/3750 batches - Avg Loss: 24.15654 | Avg Accuracy: 87.93%
# Computed 1999/3750 batches - Avg Loss: 24.09252 | Avg Accuracy: 87.79%
# Computed 2499/3750 batches - Avg Loss: 24.01827 | Avg Accuracy: 88.02%
# Computed 2999/3750 batches - Avg Loss: 23.95157 | Avg Accuracy: 88.00%
# Computed 3499/3750 batches - Avg Loss: 23.88245 | Avg Accuracy: 88.09%
#
# End of EPOCH 4 - Avg Loss: 23.84244 | Avg Accuracy: 88.12%
# Training time: 703.868 seconds.
#
# #Parameters after EPOCH 4: 22963104
# ********************
#
# Total training time (on cuda): 3517.921 seconds.
# Avg training time (on cuda): 1172.0 seconds.

# %%
# Check the results of optimization
optim_size = PIT_model.get_cost('size')
print(f'#Parameters went from {int(initial_size)} to {int(optim_size)} -> {((1 - (optim_size/initial_size))*100):.2f}% fewer parameters.')
# Out:
# #Parameters went from 134300368 to 22963102 -> 82.90% fewer parameters.

# %%
# Convert the model to PyTorch vanilla and save it
PIT_exported = PIT_model.export()
torch.save(PIT_exported, './Models_checkpoints/notMNIST/VGG16_notMNIST_PIT.pth')

# %% [markdown]
# ### 3.2.2 Cost-aware Pruning In Time (PIT with **DUCCIO** regularizer)
# *DUCCIO* regularizer is a feature of PLiNIO that allows to both eaily deal with multi-constraint optimization and treat cost metrics as constraints rather than just secondary objectives. The latter trait allows the regularizer to penalize the loss, whenever those constraints are exceeded, forcing the optimization to search only in a restricted space of the possible networks.
#
# In the following example of application, we focus as before on the number of parameters in addition to the number of **FLOPS** (_floating point operations_), trying to look for a model, which uses <u>only 10%</u> both of the original parameters and the original FLOPS.

# %%
# Load VGG16 initialization
PIT_duccio_init = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_Init.pth')

# Create PIT PLiNIO model object with parameters and FLOPS cost
PIT_duccio = PIT(model=PIT_duccio_init, input_shape=random_sample.shape, cost={'#Parameters': params, '#FLOPS': ops})
initial_params = PIT_duccio.get_cost('#Parameters').item()
initial_flops = PIT_duccio.get_cost('#FLOPS').item()

# Define the constraint for the regularizer - 10% of the original parameters and FLOPS
constraint_params = torch.tensor(initial_params*0.1, device=device)
constraint_flops = torch.tensor(initial_flops*0.1, device=device)
params_strength = torch.tensor(1e-6, device=device)
flops_strength = torch.tensor(1e-9, device=device)

print(f'#Parameters before PIT optimization: {int(initial_params)}')
print(f'#FLOPS before PIT optimization: {int(initial_flops)}')

print(f'\nConstraint for DUCCIO regularizer (parameters): {int(constraint_params.item())} parameters.')
print(f'Constraint for DUCCIO regularizer (FLOPS): {int(constraint_flops.item())} parameters.')

# Create the regularizer
regularizer = DUCCIO({'#Parameters': constraint_params, '#FLOPS': constraint_flops}, final_strengths=(params_strength, flops_strength))
# Out:
# #Parameters before PIT optimization: 134300368
# #FLOPS before PIT optimization: 15421962240
#
# Constraint for DUCCIO regularizer (parameters): 13430037 parameters.
# Constraint for DUCCIO regularizer (FLOPS): 1542196224 parameters.

# %%
# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=PIT_duccio.parameters(), lr=0.001)

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train the model with PIT optimization and DUCCIO regularizer
PIT_duccio_results = utils.train_model_duccio(
    model=PIT_duccio,
    data_loader=train_dataloader,
    device=device,
    loss_fn=loss_fn,
    optimizer=optimizer,
    cost_names=['#Parameters', '#FLOPS'],
    regularizer=regularizer
)

print(f"Total training time (on {PIT_duccio_results['device']}): {PIT_duccio_results['total_time']:.3f} seconds.")
print(f"Avg training time (on {PIT_duccio_results['device']}): {(PIT_duccio_results['total_time']/3):.3f} seconds.")
# Out:
# ********************
# EPOCH 0
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 3.48618 | Avg Accuracy: 23.40%
# Computed 999/3750 batches - Avg Loss: 2.92204 | Avg Accuracy: 47.05%
# Computed 1499/3750 batches - Avg Loss: 2.65249 | Avg Accuracy: 57.53%
# Computed 1999/3750 batches - Avg Loss: 2.49483 | Avg Accuracy: 63.38%
# Computed 2499/3750 batches - Avg Loss: 2.39304 | Avg Accuracy: 66.99%
# Computed 2999/3750 batches - Avg Loss: 2.31501 | Avg Accuracy: 69.69%
# Computed 3499/3750 batches - Avg Loss: 2.25564 | Avg Accuracy: 71.75%
#
# End of EPOCH 0 - Avg Loss: 2.23000 | Avg Accuracy: 72.56%
# Training time: 873.980 seconds.
#
# #Parameters after epoch EPOCH 0: 133358152
# #FLOPS after epoch EPOCH 0: 15404723200
# ********************
#
# ********************
# EPOCH 1
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 53.87745 | Avg Accuracy: 85.32%
# Computed 999/3750 batches - Avg Loss: 52.75425 | Avg Accuracy: 85.56%
# Computed 1499/3750 batches - Avg Loss: 51.67608 | Avg Accuracy: 85.77%
# Computed 1999/3750 batches - Avg Loss: 50.62680 | Avg Accuracy: 85.91%
# Computed 2499/3750 batches - Avg Loss: 49.59350 | Avg Accuracy: 86.00%
# Computed 2999/3750 batches - Avg Loss: 48.57458 | Avg Accuracy: 86.17%
# Computed 3499/3750 batches - Avg Loss: 47.56670 | Avg Accuracy: 86.32%
#
# End of EPOCH 1 - Avg Loss: 47.05493 | Avg Accuracy: 86.32%
# Training time: 877.379 seconds.
#
# #Parameters after epoch EPOCH 1: 97132808
# #FLOPS after epoch EPOCH 1: 14324458496
# ********************
#
# ********************
# EPOCH 2
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 74.30938 | Avg Accuracy: 88.03%
# Computed 999/3750 batches - Avg Loss: 70.64259 | Avg Accuracy: 87.88%
# Computed 1499/3750 batches - Avg Loss: 67.25655 | Avg Accuracy: 83.08%
# Computed 1999/3750 batches - Avg Loss: 63.86081 | Avg Accuracy: 81.83%
# Computed 2499/3750 batches - Avg Loss: 60.49086 | Avg Accuracy: 81.56%
# Computed 2999/3750 batches - Avg Loss: 57.16310 | Avg Accuracy: 81.62%
# Computed 3499/3750 batches - Avg Loss: 53.87771 | Avg Accuracy: 81.71%
#
# End of EPOCH 2 - Avg Loss: 52.23541 | Avg Accuracy: 81.79%
# Training time: 823.701 seconds.
#
# #Parameters after epoch EPOCH 2: 36606632
# #FLOPS after epoch EPOCH 2: 12407147520
# ********************
#
# ********************
# EPOCH 3
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 29.86375 | Avg Accuracy: 83.69%
# Computed 999/3750 batches - Avg Loss: 26.82339 | Avg Accuracy: 83.80%
# Computed 1499/3750 batches - Avg Loss: 25.60559 | Avg Accuracy: 84.33%
# Computed 1999/3750 batches - Avg Loss: 24.88358 | Avg Accuracy: 84.44%
# Computed 2499/3750 batches - Avg Loss: 24.35579 | Avg Accuracy: 84.76%
# Computed 2999/3750 batches - Avg Loss: 23.92987 | Avg Accuracy: 85.02%
# Computed 3499/3750 batches - Avg Loss: 23.56357 | Avg Accuracy: 85.12%
#
# End of EPOCH 3 - Avg Loss: 23.38887 | Avg Accuracy: 85.14%
# Training time: 822.913 seconds.
#
# #Parameters after epoch EPOCH 3: 24792496
# #FLOPS after epoch EPOCH 3: 10628842496
# ********************
#
# ********************
# EPOCH 4
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 20.71484 | Avg Accuracy: 87.15%
# Computed 999/3750 batches - Avg Loss: 20.48696 | Avg Accuracy: 86.90%
# Computed 1499/3750 batches - Avg Loss: 20.26890 | Avg Accuracy: 86.92%
# Computed 1999/3750 batches - Avg Loss: 20.06705 | Avg Accuracy: 86.84%
# Computed 2499/3750 batches - Avg Loss: 19.85955 | Avg Accuracy: 87.06%
# Computed 2999/3750 batches - Avg Loss: 19.66306 | Avg Accuracy: 87.07%
# Computed 3499/3750 batches - Avg Loss: 19.46604 | Avg Accuracy: 87.20%
#
# End of EPOCH 4 - Avg Loss: 19.36299 | Avg Accuracy: 87.28%
# Training time: 822.986 seconds.
#
# #Parameters after epoch EPOCH 4: 23329756
# #FLOPS after epoch EPOCH 4: 9160346624
# ********************
#
# Total training time (on cuda): 4220.959 seconds.
# Avg training time (on cuda): 1406.986 seconds.

# %%
# Check the results of optimization
optim_params = PIT_duccio.get_cost('#Parameters').item()
optim_flops = PIT_duccio.get_cost('#FLOPS').item()

print(f'#Parameters went from {int(initial_params)} to {int(optim_params)} -> {((1 - (optim_params/initial_params))*100):.2f}% fewer parameters.')
print(f'#FLOPS went from {int(initial_flops)} to {int(optim_flops)} -> {((1 - (optim_flops/initial_flops))*100):.2f}% fewer FLOPS.')
# Out:
# #Parameters went from 134300368 to 23329758 -> 82.63% fewer parameters.
# #FLOPS went from 15421962240 to 9160346624 -> 40.60% fewer FLOPS.

# %%
# Convert the model to PyTorch vanilla and save it
PIT_duccio_exported = PIT_duccio.export()
torch.save(PIT_duccio_exported, './Models_checkpoints/notMNIST/VGG16_notMNIST_PIT_duccio.pth')

# %% [markdown]
# ### 3.2.3 Mixed-Precision Search (**MPS**)

# %%
# Load VGG16 initialization
MPS_init = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_Init.pth')

# %%
# Create the baseline model to retrieve the full model costs
model_baseline =  MPS(model=MPS_init,
                input_shape=random_sample.shape,
                qinfo=get_default_qinfo(
                    w_precision=(32,), # torch uses 32-bit floating point
                    a_precision=(32,)  # torch uses 32-bit floating point
                ),
                w_search_type=MPSType.PER_LAYER,
                cost={'size': params_bit, 'macs': ops_bit})

# Bits required for storing the model's weights
initial_storage = model_baseline.get_cost('size').item()
# BitOPS performed by the model
initial_bitops = model_baseline.get_cost('macs').item()

print(f"Storage required for weights: {(initial_storage/(8*1024**2)):.2f} MB - {int(initial_storage)} bits")
print(f"#BitOPS: {int(initial_bitops)}")
# Out:
# Storage required for weights: 512.27 MB - 4297213952 bits
# #BitOPS: 15778208284672

# %%
# Create the PLiNIO model object with costs to optimize
MPS_model = MPS(model=MPS_init,
                input_shape=random_sample.shape,
                qinfo=get_default_qinfo(
                    w_precision=(8,16), # bit-widths to consider for weights
                    a_precision=(8,16)  # bit-widths to consider for activations
                ),
                w_search_type=MPSType.PER_LAYER,
                cost={'size': params_bit})

starting_storage = MPS_model.get_cost('size').item()

print(f"Starting storage required for weights: {(starting_storage/(8*1024**2)):.2f} MB - {int(starting_storage)} bits")
# Out:
# Starting storage required for weights: 207.78 MB - 1743013888 bits

# %%
# Initial precisions assigned to the layers 
MPS_model.summary()
# Out:
# {'x_input_quantizer': {'out_precision': 16, 'type': 'MPSIdentity'},
#  'features.0': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.2': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.5': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.7': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.10': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.12': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.14': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.17': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.19': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.21': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.24': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.26': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.28': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'classifier.0': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSLinear'},
#  'classifier.3': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSLinear'},
#  'classifier.6': {'in_precision': 16,
#   'out_precision': -1,
#   'w_precision': 16,
#   'type': 'MPSLinear'}}

# %%
# Setup loss_fn and regularizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=MPS_model.parameters(), lr=0.001)

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train the model with MPS optimization
MPS_results = utils.train_model(
    model=MPS_model,
    data_loader=train_dataloader,
    device=device,
    loss_fn=loss_fn,
    optimizer=optimizer,
    optim_method='MPS',
    cost_strength={'size': 1e-8}
)

print(f"Total training time (on {MPS_results['device']}): {MPS_results['total_time']:.3f} seconds.")
print(f"Avg training time (on {MPS_results['device']}): {(MPS_results['total_time']/3):.3f} seconds.")
# Out:
# ********************
# EPOCH 0
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 17.68137 | Avg Accuracy: 22.09%
# Computed 999/3750 batches - Avg Loss: 15.99202 | Avg Accuracy: 45.66%
# Computed 1499/3750 batches - Avg Loss: 15.11719 | Avg Accuracy: 56.48%
# Computed 1999/3750 batches - Avg Loss: 14.58126 | Avg Accuracy: 62.51%
# Computed 2499/3750 batches - Avg Loss: 14.21458 | Avg Accuracy: 66.32%
# Computed 2999/3750 batches - Avg Loss: 13.93555 | Avg Accuracy: 69.11%
# Computed 3499/3750 batches - Avg Loss: 13.71859 | Avg Accuracy: 71.20%
#
# End of EPOCH 0 - Avg Loss: 13.62284 | Avg Accuracy: 72.05%
# Training time: 3632.052 seconds.
#
# Storage required for weights: 140.34 MB - 1177226496 bits
# ********************
#
# ********************
# EPOCH 1
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 12.29410 | Avg Accuracy: 85.10%
# Computed 999/3750 batches - Avg Loss: 12.24466 | Avg Accuracy: 85.37%
# Computed 1499/3750 batches - Avg Loss: 12.20242 | Avg Accuracy: 85.51%
# Computed 1999/3750 batches - Avg Loss: 12.17256 | Avg Accuracy: 85.59%
# Computed 2499/3750 batches - Avg Loss: 12.14433 | Avg Accuracy: 85.71%
# Computed 2999/3750 batches - Avg Loss: 12.11880 | Avg Accuracy: 85.90%
# Computed 3499/3750 batches - Avg Loss: 12.09328 | Avg Accuracy: 86.06%
#
# End of EPOCH 1 - Avg Loss: 12.07829 | Avg Accuracy: 86.09%
# Training time: 3829.821 seconds.
#
# Storage required for weights: 136.76 MB - 1147193344 bits
# ********************
#
# ********************
# EPOCH 2
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 11.91472 | Avg Accuracy: 87.84%
# Computed 999/3750 batches - Avg Loss: 11.88456 | Avg Accuracy: 87.69%
# Computed 1499/3750 batches - Avg Loss: 11.87132 | Avg Accuracy: 87.58%
# Computed 1999/3750 batches - Avg Loss: 11.85390 | Avg Accuracy: 87.71%
# Computed 2499/3750 batches - Avg Loss: 11.83965 | Avg Accuracy: 87.77%
# Computed 2999/3750 batches - Avg Loss: 11.82589 | Avg Accuracy: 87.90%
# Computed 3499/3750 batches - Avg Loss: 11.81262 | Avg Accuracy: 87.97%
#
# End of EPOCH 2 - Avg Loss: 11.80366 | Avg Accuracy: 88.01%
# Training time: 3920.307 seconds.
#
# Storage required for weights: 135.00 MB - 1132489344 bits
# ********************
#
# ********************
# EPOCH 3
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 11.71506 | Avg Accuracy: 88.89%
# Computed 999/3750 batches - Avg Loss: 11.70069 | Avg Accuracy: 88.83%
# Computed 1499/3750 batches - Avg Loss: 11.68057 | Avg Accuracy: 89.19%
# Computed 1999/3750 batches - Avg Loss: 11.66985 | Avg Accuracy: 89.18%
# Computed 2499/3750 batches - Avg Loss: 11.66087 | Avg Accuracy: 89.15%
# Computed 2999/3750 batches - Avg Loss: 11.65247 | Avg Accuracy: 89.24%
# Computed 3499/3750 batches - Avg Loss: 11.64596 | Avg Accuracy: 89.21%
#
# End of EPOCH 3 - Avg Loss: 11.63948 | Avg Accuracy: 89.18%
# Training time: 3935.103 seconds.
#
# Storage required for weights: 133.80 MB - 1122355968 bits
# ********************
#
# ********************
# EPOCH 4
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 11.58392 | Avg Accuracy: 89.95%
# Computed 999/3750 batches - Avg Loss: 11.56458 | Avg Accuracy: 89.92%
# Computed 1499/3750 batches - Avg Loss: 11.55559 | Avg Accuracy: 89.93%
# Computed 1999/3750 batches - Avg Loss: 11.55472 | Avg Accuracy: 89.71%
# Computed 2499/3750 batches - Avg Loss: 11.54550 | Avg Accuracy: 89.80%
# Computed 2999/3750 batches - Avg Loss: 11.54078 | Avg Accuracy: 89.76%
# Computed 3499/3750 batches - Avg Loss: 11.53267 | Avg Accuracy: 89.83%
#
# End of EPOCH 4 - Avg Loss: 11.52599 | Avg Accuracy: 89.84%
# Training time: 3860.083 seconds.
#
# Storage required for weights: 132.90 MB - 1114853376 bits
# ********************
#
# Total training time (on cuda): 19177.367 seconds.
# Avg training time (on cuda): 6392.456 seconds.

# %%
optimized_storage = MPS_model.get_cost('size').item()

print(f'Storage required for weights after MPS: {(optimized_storage/(8*1024**2)):.2f} MB -> {((1 - (optimized_storage/initial_storage))*100):.2f}% less space required.')
# Out:
# Storage required for weights after MPS: 132.90 MB -> 74.06% less space required.

# %%
# Final precisions assigned to the layers
MPS_model.summary()
# Out:
# {'x_input_quantizer': {'out_precision': 16, 'type': 'MPSIdentity'},
#  'features.0': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.2': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.5': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.7': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.10': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.12': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.14': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 16,
#   'type': 'MPSConv2d'},
#  'features.17': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 8,
#   'type': 'MPSConv2d'},
#  'features.19': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 8,
#   'type': 'MPSConv2d'},
#  'features.21': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 8,
#   'type': 'MPSConv2d'},
#  'features.24': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 8,
#   'type': 'MPSConv2d'},
#  'features.26': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 8,
#   'type': 'MPSConv2d'},
#  'features.28': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 8,
#   'type': 'MPSConv2d'},
#  'classifier.0': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 8,
#   'type': 'MPSLinear'},
#  'classifier.3': {'in_precision': 16,
#   'out_precision': 16,
#   'w_precision': 8,
#   'type': 'MPSLinear'},
#  'classifier.6': {'in_precision': 16,
#   'out_precision': -1,
#   'w_precision': 16,
#   'type': 'MPSLinear'}}

# %%
# Convert the model to PyTorch vanilla
MPS_exported = MPS_model.export()

# Setup loss_fn and regularizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=MPS_exported.parameters(), lr=0.001)

# A couple of more epochs for fine-tuning
_ = utils.train_model(
    model=MPS_exported,
    data_loader=train_dataloader,
    device=device,
    loss_fn=loss_fn,
    optimizer=optimizer,
    epochs=2    
)

# Save the model
torch.save(MPS_exported, './Models_checkpoints/notMNIST/VGG16_notMNIST_MPS.pth')
# Out:
# ********************
# EPOCH 0
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.33206 | Avg Accuracy: 90.18%
# Computed 999/3750 batches - Avg Loss: 0.32765 | Avg Accuracy: 90.06%
# Computed 1499/3750 batches - Avg Loss: 0.33001 | Avg Accuracy: 90.09%
# Computed 1999/3750 batches - Avg Loss: 0.32699 | Avg Accuracy: 90.25%
# Computed 2499/3750 batches - Avg Loss: 0.32561 | Avg Accuracy: 90.27%
# Computed 2999/3750 batches - Avg Loss: 0.32417 | Avg Accuracy: 90.32%
# Computed 3499/3750 batches - Avg Loss: 0.31921 | Avg Accuracy: 90.45%
#
# End of EPOCH 0 - Avg Loss: 0.32144 | Avg Accuracy: 90.38%
# Training time: 1274.715 seconds.
# ********************
#
# ********************
# EPOCH 1
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.30265 | Avg Accuracy: 91.22%
# Computed 999/3750 batches - Avg Loss: 0.30553 | Avg Accuracy: 90.92%
# Computed 1499/3750 batches - Avg Loss: 0.30471 | Avg Accuracy: 90.90%
# Computed 1999/3750 batches - Avg Loss: 0.30347 | Avg Accuracy: 90.91%
# Computed 2499/3750 batches - Avg Loss: 0.30365 | Avg Accuracy: 90.85%
# Computed 2999/3750 batches - Avg Loss: 0.30431 | Avg Accuracy: 90.83%
# Computed 3499/3750 batches - Avg Loss: 0.30421 | Avg Accuracy: 90.80%
#
# End of EPOCH 1 - Avg Loss: 0.30305 | Avg Accuracy: 90.82%
# Training time: 1246.424 seconds.
# ********************

# %%
MPS_exported
# Out:
# VGG(
#   (x_input_quantizer): QuantIdentity(
#     (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#     tensor([1.0000], requires_grad=True), scale_factor=1.525908737676218e-05)
#   )
#   (features): Module(
#     (0): QuantConv2d(
#       1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([1.0000], requires_grad=True), scale_factor=1.525908737676218e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([9.8640e-06, 9.2526e-06, 8.0300e-06, 1.0050e-05, 9.7476e-06, 1.0070e-05,
#               8.0587e-06, 9.0607e-06, 1.0080e-05, 7.6590e-06, 9.3059e-06, 9.8430e-06,
#               1.0169e-05, 8.9510e-06, 8.8079e-06, 1.0316e-05, 9.2753e-06, 8.9916e-06,
#               8.9649e-06, 9.5770e-06, 5.4544e-06, 8.7354e-06, 9.3221e-06, 9.8708e-06,
#               1.0120e-05, 1.0087e-05, 9.5150e-06, 7.4623e-06, 9.6912e-06, 9.5698e-06,
#               1.0060e-05, 1.0125e-05, 9.9214e-06, 8.7803e-06, 1.0076e-05, 1.0304e-05,
#               1.0039e-05, 8.3540e-06, 9.8038e-06, 9.9332e-06, 9.5043e-06, 9.2863e-06,
#               9.3231e-06, 7.2880e-06, 8.2571e-06, 9.7042e-06, 7.6260e-06, 9.3807e-06,
#               8.1015e-06, 9.9154e-06, 1.0035e-05, 8.4654e-06, 1.0101e-05, 6.8920e-06,
#               1.0228e-05, 9.4070e-06, 9.5032e-06, 9.8230e-06, 8.3644e-06, 9.6603e-06,
#               9.7491e-06, 6.8981e-06, 1.0034e-05, 1.0029e-05], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([1.5052e-10, 1.4119e-10, 1.2253e-10, 1.5336e-10, 1.4874e-10, 1.5366e-10,
#               1.2297e-10, 1.3826e-10, 1.5381e-10, 1.1687e-10, 1.4200e-10, 1.5020e-10,
#               1.5517e-10, 1.3658e-10, 1.3440e-10, 1.5742e-10, 1.4153e-10, 1.3720e-10,
#               1.3680e-10, 1.4614e-10, 8.3230e-11, 1.3329e-10, 1.4225e-10, 1.5062e-10,
#               1.5442e-10, 1.5392e-10, 1.4519e-10, 1.1387e-10, 1.4788e-10, 1.4603e-10,
#               1.5351e-10, 1.5450e-10, 1.5139e-10, 1.3398e-10, 1.5376e-10, 1.5722e-10,
#               1.5319e-10, 1.2748e-10, 1.4960e-10, 1.5157e-10, 1.4503e-10, 1.4170e-10,
#               1.4226e-10, 1.1121e-10, 1.2600e-10, 1.4808e-10, 1.1637e-10, 1.4314e-10,
#               1.2362e-10, 1.5130e-10, 1.5313e-10, 1.2917e-10, 1.5413e-10, 1.0517e-10,
#               1.5607e-10, 1.4354e-10, 1.4501e-10, 1.4989e-10, 1.2763e-10, 1.4741e-10,
#               1.4876e-10, 1.0526e-10, 1.5312e-10, 1.5303e-10], device='cuda:0'))
#     )
#     (1): ReLU(inplace=True)
#     (2): QuantConv2d(
#       64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([5.9194e-06, 5.8212e-06, 7.3598e-06, 5.9381e-06, 5.4656e-06, 6.2827e-06,
#               6.7580e-06, 6.1793e-06, 6.0249e-06, 6.5032e-06, 5.8777e-06, 5.6153e-06,
#               4.9716e-06, 6.5857e-06, 5.9579e-06, 6.0179e-06, 4.9314e-06, 5.8628e-06,
#               6.0969e-06, 6.3826e-06, 5.8008e-06, 6.4739e-06, 5.3267e-06, 5.8650e-06,
#               5.4325e-06, 5.4553e-06, 5.4515e-06, 5.1550e-06, 6.1554e-06, 5.7196e-06,
#               6.9696e-06, 5.8450e-06, 5.9219e-06, 5.1235e-06, 5.9796e-06, 6.0345e-06,
#               5.6518e-06, 5.9031e-06, 6.0892e-06, 6.3667e-06, 4.9562e-06, 6.7677e-06,
#               5.9577e-06, 5.8609e-06, 5.0943e-06, 5.4054e-06, 5.8335e-06, 6.2672e-06,
#               6.3940e-06, 6.6509e-06, 5.7024e-06, 6.2055e-06, 4.9175e-06, 6.1095e-06,
#               5.4899e-06, 5.6286e-06, 5.9235e-06, 5.5806e-06, 5.0860e-06, 6.2595e-06,
#               5.8662e-06, 6.7709e-06, 6.1332e-06, 5.1247e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([5.4194e-10, 5.3295e-10, 6.7382e-10, 5.4366e-10, 5.0040e-10, 5.7521e-10,
#               6.1872e-10, 5.6574e-10, 5.5160e-10, 5.9540e-10, 5.3813e-10, 5.1410e-10,
#               4.5517e-10, 6.0295e-10, 5.4547e-10, 5.5097e-10, 4.5149e-10, 5.3676e-10,
#               5.5819e-10, 5.8435e-10, 5.3108e-10, 5.9271e-10, 4.8768e-10, 5.3696e-10,
#               4.9737e-10, 4.9946e-10, 4.9911e-10, 4.7196e-10, 5.6355e-10, 5.2365e-10,
#               6.3810e-10, 5.3513e-10, 5.4218e-10, 4.6908e-10, 5.4746e-10, 5.5248e-10,
#               5.1744e-10, 5.4046e-10, 5.5749e-10, 5.8290e-10, 4.5376e-10, 6.1961e-10,
#               5.4545e-10, 5.3659e-10, 4.6641e-10, 4.9489e-10, 5.3408e-10, 5.7379e-10,
#               5.8539e-10, 6.0892e-10, 5.2208e-10, 5.6814e-10, 4.5021e-10, 5.5935e-10,
#               5.0262e-10, 5.1532e-10, 5.4233e-10, 5.1092e-10, 4.6565e-10, 5.7308e-10,
#               5.3708e-10, 6.1990e-10, 5.6152e-10, 4.6919e-10], device='cuda:0'))
#     )
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): QuantConv2d(
#       64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([4.4725e-06, 3.4540e-06, 3.6406e-06, 4.3915e-06, 4.0882e-06, 3.6660e-06,
#               4.2775e-06, 4.1260e-06, 3.9519e-06, 5.2054e-06, 5.0116e-06, 4.0356e-06,
#               4.0475e-06, 4.6874e-06, 4.3058e-06, 3.6413e-06, 5.3130e-06, 4.2903e-06,
#               4.7392e-06, 3.9871e-06, 3.4015e-06, 4.2186e-06, 4.2402e-06, 3.5516e-06,
#               4.0714e-06, 4.3595e-06, 4.5649e-06, 3.9573e-06, 4.6227e-06, 4.3401e-06,
#               4.5929e-06, 4.0914e-06, 4.2858e-06, 3.9711e-06, 4.8146e-06, 4.8191e-06,
#               4.4456e-06, 3.7601e-06, 5.3120e-06, 3.9374e-06, 4.0115e-06, 4.4192e-06,
#               4.4525e-06, 4.2873e-06, 4.3730e-06, 3.4052e-06, 3.7336e-06, 3.9811e-06,
#               5.0841e-06, 3.9419e-06, 3.9459e-06, 4.2743e-06, 4.6430e-06, 3.9618e-06,
#               3.7694e-06, 4.2726e-06, 4.7124e-06, 4.1731e-06, 4.9882e-06, 3.5422e-06,
#               4.2089e-06, 4.7299e-06, 3.8190e-06, 3.8210e-06, 4.0539e-06, 3.9879e-06,
#               4.0873e-06, 3.8502e-06, 4.2153e-06, 4.1670e-06, 4.1307e-06, 4.0710e-06,
#               4.3422e-06, 4.5157e-06, 4.3150e-06, 3.6633e-06, 4.7199e-06, 3.8319e-06,
#               4.1333e-06, 3.7293e-06, 4.1731e-06, 3.9183e-06, 3.7582e-06, 5.0503e-06,
#               3.5703e-06, 4.5665e-06, 4.9102e-06, 3.4916e-06, 3.9350e-06, 5.3689e-06,
#               5.0365e-06, 4.3198e-06, 4.0202e-06, 4.4897e-06, 4.3820e-06, 4.8325e-06,
#               4.3489e-06, 3.8724e-06, 5.3183e-06, 4.3073e-06, 4.5610e-06, 3.6112e-06,
#               3.7633e-06, 4.3833e-06, 4.2096e-06, 3.6551e-06, 3.8006e-06, 4.0176e-06,
#               3.6251e-06, 3.6677e-06, 4.5325e-06, 3.8402e-06, 4.1355e-06, 4.3471e-06,
#               3.8460e-06, 4.7088e-06, 4.7556e-06, 3.9427e-06, 4.8077e-06, 3.9401e-06,
#               3.8613e-06, 4.1678e-06, 3.8890e-06, 3.8349e-06, 5.0002e-06, 4.5013e-06,
#               3.9520e-06, 3.8156e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([4.0947e-10, 3.1623e-10, 3.3331e-10, 4.0206e-10, 3.7429e-10, 3.3564e-10,
#               3.9162e-10, 3.7775e-10, 3.6181e-10, 4.7657e-10, 4.5883e-10, 3.6948e-10,
#               3.7057e-10, 4.2915e-10, 3.9421e-10, 3.3337e-10, 4.8643e-10, 3.9279e-10,
#               4.3389e-10, 3.6503e-10, 3.1143e-10, 3.8623e-10, 3.8821e-10, 3.2517e-10,
#               3.7275e-10, 3.9913e-10, 4.1793e-10, 3.6231e-10, 4.2322e-10, 3.9735e-10,
#               4.2050e-10, 3.7459e-10, 3.9238e-10, 3.6357e-10, 4.4080e-10, 4.4121e-10,
#               4.0701e-10, 3.4425e-10, 4.8634e-10, 3.6049e-10, 3.6727e-10, 4.0460e-10,
#               4.0765e-10, 3.9252e-10, 4.0036e-10, 3.1176e-10, 3.4183e-10, 3.6449e-10,
#               4.6547e-10, 3.6090e-10, 3.6126e-10, 3.9133e-10, 4.2509e-10, 3.6271e-10,
#               3.4511e-10, 3.9118e-10, 4.3144e-10, 3.8207e-10, 4.5669e-10, 3.2430e-10,
#               3.8534e-10, 4.3304e-10, 3.4965e-10, 3.4983e-10, 3.7115e-10, 3.6511e-10,
#               3.7421e-10, 3.5250e-10, 3.8592e-10, 3.8151e-10, 3.7818e-10, 3.7271e-10,
#               3.9755e-10, 4.1343e-10, 3.9505e-10, 3.3539e-10, 4.3213e-10, 3.5083e-10,
#               3.7842e-10, 3.4143e-10, 3.8206e-10, 3.5874e-10, 3.4408e-10, 4.6237e-10,
#               3.2687e-10, 4.1808e-10, 4.4955e-10, 3.1967e-10, 3.6026e-10, 4.9155e-10,
#               4.6111e-10, 3.9550e-10, 3.6807e-10, 4.1105e-10, 4.0119e-10, 4.4244e-10,
#               3.9816e-10, 3.5454e-10, 4.8692e-10, 3.9435e-10, 4.1757e-10, 3.3062e-10,
#               3.4455e-10, 4.0131e-10, 3.8541e-10, 3.3464e-10, 3.4796e-10, 3.6783e-10,
#               3.3190e-10, 3.3579e-10, 4.1497e-10, 3.5159e-10, 3.7862e-10, 3.9799e-10,
#               3.5211e-10, 4.3111e-10, 4.3539e-10, 3.6097e-10, 4.4016e-10, 3.6073e-10,
#               3.5351e-10, 3.8158e-10, 3.5605e-10, 3.5110e-10, 4.5779e-10, 4.1211e-10,
#               3.6182e-10, 3.4934e-10], device='cuda:0'))
#     )
#     (6): ReLU(inplace=True)
#     (7): QuantConv2d(
#       128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([4.5378e-06, 4.0342e-06, 4.3788e-06, 4.0474e-06, 4.6579e-06, 4.3932e-06,
#               3.9547e-06, 3.8103e-06, 4.6554e-06, 4.0692e-06, 4.4959e-06, 4.1553e-06,
#               3.9731e-06, 5.3819e-06, 4.2331e-06, 3.9483e-06, 4.4862e-06, 4.1000e-06,
#               3.8887e-06, 4.1408e-06, 4.8342e-06, 4.8411e-06, 4.0201e-06, 4.2024e-06,
#               4.0789e-06, 4.6114e-06, 4.4294e-06, 4.3078e-06, 3.8302e-06, 4.0000e-06,
#               4.0106e-06, 4.2999e-06, 4.1258e-06, 5.1729e-06, 4.4410e-06, 4.2937e-06,
#               4.7233e-06, 4.4177e-06, 4.9801e-06, 4.1466e-06, 4.2844e-06, 4.4293e-06,
#               3.7786e-06, 4.4364e-06, 3.9245e-06, 4.4798e-06, 3.9007e-06, 3.9875e-06,
#               4.6227e-06, 5.7849e-06, 4.1942e-06, 3.8028e-06, 5.0606e-06, 3.9505e-06,
#               4.6153e-06, 5.3645e-06, 4.0911e-06, 4.1665e-06, 4.8923e-06, 4.1013e-06,
#               4.1389e-06, 4.6086e-06, 4.1559e-06, 5.0408e-06, 3.8885e-06, 4.4608e-06,
#               4.3869e-06, 5.4165e-06, 4.7491e-06, 4.0912e-06, 4.6481e-06, 4.3045e-06,
#               4.8759e-06, 4.3548e-06, 4.6209e-06, 4.5471e-06, 4.8853e-06, 4.1189e-06,
#               4.1654e-06, 4.0913e-06, 6.0849e-06, 4.6220e-06, 4.9973e-06, 4.4200e-06,
#               4.7737e-06, 5.1693e-06, 4.2528e-06, 4.7415e-06, 4.0249e-06, 4.1556e-06,
#               4.1572e-06, 3.9442e-06, 4.4864e-06, 4.1765e-06, 4.4931e-06, 3.9194e-06,
#               4.1845e-06, 4.7695e-06, 4.1999e-06, 3.3272e-06, 4.0422e-06, 4.3538e-06,
#               4.2241e-06, 4.6949e-06, 4.3220e-06, 4.8847e-06, 4.7204e-06, 5.1655e-06,
#               4.3855e-06, 4.1274e-06, 4.2699e-06, 4.7686e-06, 4.2068e-06, 4.1436e-06,
#               4.4133e-06, 4.2544e-06, 4.5562e-06, 5.0180e-06, 4.4488e-06, 4.0114e-06,
#               4.9651e-06, 4.4238e-06, 4.6059e-06, 3.9483e-06, 4.5419e-06, 5.2056e-06,
#               4.8679e-06, 4.2008e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([4.1546e-10, 3.6935e-10, 4.0090e-10, 3.7056e-10, 4.2645e-10, 4.0222e-10,
#               3.6207e-10, 3.4885e-10, 4.2622e-10, 3.7255e-10, 4.1162e-10, 3.8043e-10,
#               3.6375e-10, 4.9273e-10, 3.8756e-10, 3.6148e-10, 4.1073e-10, 3.7537e-10,
#               3.5603e-10, 3.7911e-10, 4.4259e-10, 4.4322e-10, 3.6806e-10, 3.8474e-10,
#               3.7344e-10, 4.2219e-10, 4.0553e-10, 3.9440e-10, 3.5067e-10, 3.6622e-10,
#               3.6718e-10, 3.9367e-10, 3.7773e-10, 4.7360e-10, 4.0659e-10, 3.9311e-10,
#               4.3244e-10, 4.0446e-10, 4.5595e-10, 3.7964e-10, 3.9226e-10, 4.0552e-10,
#               3.4595e-10, 4.0617e-10, 3.5931e-10, 4.1014e-10, 3.5713e-10, 3.6507e-10,
#               4.2323e-10, 5.2963e-10, 3.8400e-10, 3.4817e-10, 4.6332e-10, 3.6169e-10,
#               4.2255e-10, 4.9114e-10, 3.7455e-10, 3.8146e-10, 4.4791e-10, 3.7549e-10,
#               3.7893e-10, 4.2193e-10, 3.8049e-10, 4.6151e-10, 3.5601e-10, 4.0841e-10,
#               4.0164e-10, 4.9591e-10, 4.3480e-10, 3.7457e-10, 4.2556e-10, 3.9410e-10,
#               4.4641e-10, 3.9870e-10, 4.2307e-10, 4.1631e-10, 4.4727e-10, 3.7710e-10,
#               3.8136e-10, 3.7457e-10, 5.5710e-10, 4.2317e-10, 4.5752e-10, 4.0467e-10,
#               4.3705e-10, 4.7327e-10, 3.8936e-10, 4.3410e-10, 3.6849e-10, 3.8047e-10,
#               3.8061e-10, 3.6111e-10, 4.1075e-10, 3.8238e-10, 4.1136e-10, 3.5884e-10,
#               3.8311e-10, 4.3666e-10, 3.8452e-10, 3.0462e-10, 3.7008e-10, 3.9861e-10,
#               3.8673e-10, 4.2984e-10, 3.9570e-10, 4.4722e-10, 4.3217e-10, 4.7292e-10,
#               4.0151e-10, 3.7788e-10, 3.9093e-10, 4.3658e-10, 3.8515e-10, 3.7936e-10,
#               4.0405e-10, 3.8950e-10, 4.1713e-10, 4.5942e-10, 4.0731e-10, 3.6726e-10,
#               4.5458e-10, 4.0502e-10, 4.2169e-10, 3.6148e-10, 4.1583e-10, 4.7659e-10,
#               4.4567e-10, 3.8460e-10], device='cuda:0'))
#     )
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): QuantConv2d(
#       128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([3.4312e-06, 3.0423e-06, 2.9862e-06, 3.3037e-06, 3.0946e-06, 3.1827e-06,
#               2.6641e-06, 2.7613e-06, 3.1504e-06, 3.2920e-06, 3.7545e-06, 3.2203e-06,
#               2.9135e-06, 3.2822e-06, 3.1509e-06, 3.2705e-06, 2.9648e-06, 3.5323e-06,
#               3.5031e-06, 2.8192e-06, 3.1679e-06, 2.8015e-06, 3.2838e-06, 3.4825e-06,
#               2.7373e-06, 2.9041e-06, 2.8318e-06, 3.1192e-06, 3.0789e-06, 3.3372e-06,
#               3.2866e-06, 2.6893e-06, 3.1892e-06, 3.0934e-06, 2.8287e-06, 3.4115e-06,
#               3.2363e-06, 3.3968e-06, 2.6937e-06, 4.1110e-06, 2.6674e-06, 2.9059e-06,
#               3.5160e-06, 2.9117e-06, 3.0089e-06, 3.4309e-06, 2.7332e-06, 3.2847e-06,
#               3.3531e-06, 3.0442e-06, 3.0461e-06, 3.3085e-06, 3.4748e-06, 3.2246e-06,
#               3.1334e-06, 3.2002e-06, 3.4175e-06, 3.0157e-06, 3.2602e-06, 2.7680e-06,
#               3.5195e-06, 2.7169e-06, 3.1381e-06, 3.3629e-06, 3.3153e-06, 3.5320e-06,
#               2.9642e-06, 3.0652e-06, 3.4338e-06, 3.1153e-06, 3.4530e-06, 2.7473e-06,
#               3.0457e-06, 2.9633e-06, 3.0381e-06, 3.0972e-06, 3.1138e-06, 2.8584e-06,
#               3.0108e-06, 3.2683e-06, 3.5816e-06, 2.6609e-06, 2.9531e-06, 2.8927e-06,
#               3.0116e-06, 3.2842e-06, 3.3669e-06, 3.1165e-06, 3.1679e-06, 3.1729e-06,
#               2.9268e-06, 3.1576e-06, 3.0193e-06, 2.8451e-06, 3.0306e-06, 3.6104e-06,
#               2.6986e-06, 4.3165e-06, 3.1627e-06, 3.7052e-06, 3.0407e-06, 3.3817e-06,
#               4.0135e-06, 2.7746e-06, 2.6559e-06, 3.2771e-06, 3.8363e-06, 2.6259e-06,
#               3.7507e-06, 2.8345e-06, 2.9651e-06, 3.3164e-06, 3.1643e-06, 3.7840e-06,
#               2.9168e-06, 3.1845e-06, 2.9757e-06, 3.1630e-06, 2.9196e-06, 2.8601e-06,
#               3.2251e-06, 3.6011e-06, 2.6523e-06, 3.4554e-06, 2.9050e-06, 3.7161e-06,
#               2.8857e-06, 2.9878e-06, 3.1059e-06, 3.5183e-06, 2.9414e-06, 2.9496e-06,
#               3.1828e-06, 3.4519e-06, 3.4434e-06, 2.9859e-06, 3.2954e-06, 3.0827e-06,
#               3.1997e-06, 3.8580e-06, 3.3235e-06, 3.1586e-06, 3.0281e-06, 3.5829e-06,
#               3.1675e-06, 3.1765e-06, 3.0896e-06, 3.5476e-06, 3.0635e-06, 3.1572e-06,
#               3.1684e-06, 3.6320e-06, 2.7240e-06, 3.1148e-06, 3.0724e-06, 2.8693e-06,
#               2.9801e-06, 3.3900e-06, 3.4515e-06, 4.1879e-06, 2.7780e-06, 3.2878e-06,
#               3.3167e-06, 2.9305e-06, 3.2181e-06, 3.1968e-06, 3.1829e-06, 2.7201e-06,
#               2.7194e-06, 3.9798e-06, 2.8916e-06, 3.1842e-06, 3.4471e-06, 3.1396e-06,
#               2.7903e-06, 3.6074e-06, 2.7374e-06, 3.0692e-06, 2.9927e-06, 3.0929e-06,
#               2.8484e-06, 3.2016e-06, 2.9105e-06, 3.1430e-06, 3.5815e-06, 3.2971e-06,
#               3.0459e-06, 2.9627e-06, 3.0407e-06, 2.7717e-06, 3.4373e-06, 4.3610e-06,
#               3.0229e-06, 4.0983e-06, 3.1090e-06, 3.8891e-06, 3.2523e-06, 3.4609e-06,
#               3.1555e-06, 2.9463e-06, 2.6849e-06, 3.3960e-06, 3.4543e-06, 3.0468e-06,
#               3.2111e-06, 3.1209e-06, 3.2231e-06, 3.1114e-06, 3.1341e-06, 3.1643e-06,
#               2.9293e-06, 3.0216e-06, 3.1159e-06, 3.0080e-06, 3.1904e-06, 3.1733e-06,
#               3.0280e-06, 3.9168e-06, 2.6222e-06, 3.1048e-06, 2.9087e-06, 2.7899e-06,
#               3.2396e-06, 3.1842e-06, 3.2169e-06, 3.3130e-06, 3.0614e-06, 2.7063e-06,
#               3.3222e-06, 2.9368e-06, 3.2225e-06, 2.9840e-06, 3.4232e-06, 3.4833e-06,
#               2.7281e-06, 3.9016e-06, 3.3759e-06, 2.7846e-06, 3.5099e-06, 3.2715e-06,
#               2.6610e-06, 2.9489e-06, 2.8060e-06, 2.7995e-06, 3.6626e-06, 3.4008e-06,
#               3.2471e-06, 3.5003e-06, 3.1730e-06, 2.9734e-06, 3.0780e-06, 2.8371e-06,
#               3.2974e-06, 3.0114e-06, 2.9220e-06, 3.0730e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([3.1414e-10, 2.7854e-10, 2.7340e-10, 3.0247e-10, 2.8332e-10, 2.9139e-10,
#               2.4391e-10, 2.5280e-10, 2.8844e-10, 3.0140e-10, 3.4374e-10, 2.9484e-10,
#               2.6674e-10, 3.0050e-10, 2.8848e-10, 2.9942e-10, 2.7144e-10, 3.2340e-10,
#               3.2072e-10, 2.5811e-10, 2.9003e-10, 2.5649e-10, 3.0064e-10, 3.1884e-10,
#               2.5061e-10, 2.6589e-10, 2.5926e-10, 2.8557e-10, 2.8189e-10, 3.0554e-10,
#               3.0091e-10, 2.4622e-10, 2.9198e-10, 2.8322e-10, 2.5898e-10, 3.1234e-10,
#               2.9630e-10, 3.1099e-10, 2.4662e-10, 3.7638e-10, 2.4421e-10, 2.6604e-10,
#               3.2191e-10, 2.6658e-10, 2.7548e-10, 3.1411e-10, 2.5024e-10, 3.0073e-10,
#               3.0699e-10, 2.7871e-10, 2.7888e-10, 3.0291e-10, 3.1813e-10, 2.9523e-10,
#               2.8687e-10, 2.9299e-10, 3.1288e-10, 2.7610e-10, 2.9849e-10, 2.5342e-10,
#               3.2222e-10, 2.4874e-10, 2.8730e-10, 3.0788e-10, 3.0353e-10, 3.2337e-10,
#               2.7139e-10, 2.8063e-10, 3.1438e-10, 2.8522e-10, 3.1613e-10, 2.5152e-10,
#               2.7885e-10, 2.7130e-10, 2.7815e-10, 2.8356e-10, 2.8508e-10, 2.6170e-10,
#               2.7565e-10, 2.9923e-10, 3.2791e-10, 2.4362e-10, 2.7037e-10, 2.6484e-10,
#               2.7572e-10, 3.0068e-10, 3.0826e-10, 2.8533e-10, 2.9004e-10, 2.9049e-10,
#               2.6796e-10, 2.8909e-10, 2.7643e-10, 2.6048e-10, 2.7747e-10, 3.3055e-10,
#               2.4706e-10, 3.9519e-10, 2.8956e-10, 3.3923e-10, 2.7839e-10, 3.0961e-10,
#               3.6746e-10, 2.5402e-10, 2.4316e-10, 3.0003e-10, 3.5123e-10, 2.4042e-10,
#               3.4339e-10, 2.5951e-10, 2.7147e-10, 3.0363e-10, 2.8970e-10, 3.4644e-10,
#               2.6705e-10, 2.9156e-10, 2.7244e-10, 2.8958e-10, 2.6730e-10, 2.6185e-10,
#               2.9528e-10, 3.2970e-10, 2.4283e-10, 3.1635e-10, 2.6597e-10, 3.4022e-10,
#               2.6420e-10, 2.7355e-10, 2.8436e-10, 3.2212e-10, 2.6930e-10, 2.7005e-10,
#               2.9140e-10, 3.1604e-10, 3.1525e-10, 2.7337e-10, 3.0171e-10, 2.8224e-10,
#               2.9295e-10, 3.5321e-10, 3.0428e-10, 2.8918e-10, 2.7723e-10, 3.2803e-10,
#               2.9000e-10, 2.9082e-10, 2.8287e-10, 3.2480e-10, 2.8048e-10, 2.8905e-10,
#               2.9008e-10, 3.3253e-10, 2.4939e-10, 2.8518e-10, 2.8129e-10, 2.6269e-10,
#               2.7284e-10, 3.1037e-10, 3.1600e-10, 3.8342e-10, 2.5434e-10, 3.0101e-10,
#               3.0366e-10, 2.6830e-10, 2.9463e-10, 2.9268e-10, 2.9141e-10, 2.4904e-10,
#               2.4897e-10, 3.6437e-10, 2.6474e-10, 2.9152e-10, 3.1559e-10, 2.8744e-10,
#               2.5546e-10, 3.3027e-10, 2.5062e-10, 2.8100e-10, 2.7400e-10, 2.8317e-10,
#               2.6078e-10, 2.9312e-10, 2.6647e-10, 2.8776e-10, 3.2790e-10, 3.0187e-10,
#               2.7886e-10, 2.7125e-10, 2.7839e-10, 2.5376e-10, 3.1470e-10, 3.9926e-10,
#               2.7676e-10, 3.7521e-10, 2.8464e-10, 3.5606e-10, 2.9776e-10, 3.1686e-10,
#               2.8890e-10, 2.6974e-10, 2.4581e-10, 3.1092e-10, 3.1625e-10, 2.7895e-10,
#               2.9399e-10, 2.8573e-10, 2.9509e-10, 2.8486e-10, 2.8694e-10, 2.8971e-10,
#               2.6819e-10, 2.7664e-10, 2.8527e-10, 2.7540e-10, 2.9209e-10, 2.9053e-10,
#               2.7722e-10, 3.5860e-10, 2.4008e-10, 2.8426e-10, 2.6630e-10, 2.5542e-10,
#               2.9660e-10, 2.9153e-10, 2.9452e-10, 3.0332e-10, 2.8029e-10, 2.4778e-10,
#               3.0416e-10, 2.6888e-10, 2.9503e-10, 2.7320e-10, 3.1341e-10, 3.1891e-10,
#               2.4977e-10, 3.5720e-10, 3.0908e-10, 2.5494e-10, 3.2134e-10, 2.9952e-10,
#               2.4363e-10, 2.6998e-10, 2.5690e-10, 2.5631e-10, 3.3533e-10, 3.1136e-10,
#               2.9728e-10, 3.2047e-10, 2.9050e-10, 2.7223e-10, 2.8180e-10, 2.5975e-10,
#               3.0189e-10, 2.7571e-10, 2.6752e-10, 2.8134e-10], device='cuda:0'))
#     )
#     (11): ReLU(inplace=True)
#     (12): QuantConv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0007], requires_grad=True), scale_factor=9.156471060123295e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([3.1861e-06, 3.3484e-06, 3.6270e-06, 3.5296e-06, 3.0417e-06, 2.8602e-06,
#               3.2133e-06, 3.4838e-06, 3.3670e-06, 3.0231e-06, 3.4276e-06, 3.1864e-06,
#               3.3628e-06, 3.3704e-06, 3.3463e-06, 3.2142e-06, 3.6922e-06, 2.9871e-06,
#               2.9850e-06, 3.2062e-06, 3.1483e-06, 3.4310e-06, 3.2082e-06, 2.5784e-06,
#               3.4686e-06, 2.9784e-06, 3.0760e-06, 3.4573e-06, 3.4976e-06, 3.0710e-06,
#               2.9652e-06, 3.3549e-06, 3.2879e-06, 3.3225e-06, 3.1810e-06, 3.1489e-06,
#               3.6708e-06, 3.5202e-06, 3.2766e-06, 3.0403e-06, 3.1803e-06, 3.2012e-06,
#               2.9493e-06, 3.7339e-06, 2.8708e-06, 3.2826e-06, 3.3199e-06, 3.2092e-06,
#               3.2272e-06, 3.4709e-06, 3.2428e-06, 2.9040e-06, 3.0544e-06, 3.1467e-06,
#               3.3916e-06, 3.4058e-06, 3.2080e-06, 3.0323e-06, 2.9185e-06, 3.4937e-06,
#               3.1201e-06, 3.9485e-06, 2.9147e-06, 3.5673e-06, 3.7167e-06, 3.4541e-06,
#               3.2867e-06, 3.2966e-06, 2.9571e-06, 2.8989e-06, 3.1030e-06, 2.9981e-06,
#               3.7770e-06, 3.0551e-06, 3.0787e-06, 3.1049e-06, 3.1955e-06, 2.9307e-06,
#               3.2207e-06, 3.2397e-06, 3.6105e-06, 3.0002e-06, 3.0769e-06, 3.1237e-06,
#               3.4216e-06, 3.2182e-06, 2.9702e-06, 3.3118e-06, 2.7984e-06, 3.3192e-06,
#               2.9191e-06, 3.5825e-06, 3.0638e-06, 3.3703e-06, 3.7391e-06, 3.2626e-06,
#               2.9712e-06, 3.2132e-06, 2.8819e-06, 2.9755e-06, 3.1706e-06, 3.8363e-06,
#               3.2805e-06, 3.2506e-06, 3.1640e-06, 3.2689e-06, 3.6249e-06, 3.0752e-06,
#               3.3960e-06, 2.9116e-06, 3.5345e-06, 3.3423e-06, 3.7977e-06, 3.5037e-06,
#               3.0125e-06, 3.0966e-06, 3.1662e-06, 3.1701e-06, 4.0485e-06, 3.1078e-06,
#               3.4033e-06, 3.4850e-06, 3.1470e-06, 3.1201e-06, 3.8897e-06, 3.0921e-06,
#               2.9446e-06, 3.3857e-06, 3.6052e-06, 2.6908e-06, 2.7615e-06, 3.2414e-06,
#               3.0472e-06, 3.0659e-06, 3.6178e-06, 3.2523e-06, 3.2534e-06, 3.2657e-06,
#               3.0178e-06, 2.9555e-06, 3.1769e-06, 4.0153e-06, 3.0285e-06, 3.2902e-06,
#               3.6328e-06, 3.4069e-06, 3.2611e-06, 3.7956e-06, 3.6839e-06, 2.8803e-06,
#               3.6944e-06, 3.4953e-06, 3.0988e-06, 3.0515e-06, 3.3686e-06, 3.1912e-06,
#               2.9271e-06, 2.9312e-06, 3.3313e-06, 4.0613e-06, 3.1339e-06, 3.6547e-06,
#               2.9234e-06, 3.6924e-06, 3.2730e-06, 3.3050e-06, 2.8681e-06, 3.4725e-06,
#               3.0973e-06, 2.7814e-06, 3.0282e-06, 3.3916e-06, 3.0875e-06, 3.2622e-06,
#               3.2125e-06, 2.9853e-06, 3.1863e-06, 3.0011e-06, 3.1272e-06, 2.8097e-06,
#               3.4983e-06, 3.5326e-06, 3.3402e-06, 3.4461e-06, 3.1714e-06, 2.8525e-06,
#               3.3864e-06, 2.8898e-06, 3.3026e-06, 3.2913e-06, 2.9425e-06, 3.4292e-06,
#               3.2862e-06, 3.2187e-06, 3.5876e-06, 3.6114e-06, 3.2304e-06, 3.0747e-06,
#               2.9819e-06, 3.5055e-06, 3.4630e-06, 2.9262e-06, 3.0800e-06, 3.1178e-06,
#               2.8290e-06, 3.1830e-06, 2.9789e-06, 3.5862e-06, 2.9453e-06, 2.8880e-06,
#               3.4949e-06, 2.9088e-06, 3.1836e-06, 3.1949e-06, 3.1426e-06, 2.8440e-06,
#               3.4408e-06, 3.4013e-06, 3.1378e-06, 3.3810e-06, 2.8920e-06, 3.2545e-06,
#               3.1808e-06, 2.9408e-06, 2.9293e-06, 3.2116e-06, 3.8925e-06, 2.8914e-06,
#               3.3631e-06, 3.3834e-06, 3.4147e-06, 3.4486e-06, 3.3108e-06, 3.3015e-06,
#               2.9956e-06, 3.4824e-06, 2.9660e-06, 3.3310e-06, 3.2651e-06, 3.3408e-06,
#               3.1192e-06, 3.4995e-06, 3.6197e-06, 3.1393e-06, 3.5374e-06, 3.0572e-06,
#               3.2145e-06, 2.9246e-06, 3.1588e-06, 3.0244e-06, 3.4028e-06, 3.3432e-06,
#               2.8685e-06, 2.7805e-06, 3.2450e-06, 2.8238e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([2.9170e-10, 3.0656e-10, 3.3207e-10, 3.2315e-10, 2.7848e-10, 2.6186e-10,
#               2.9419e-10, 3.1895e-10, 3.0826e-10, 2.7677e-10, 3.1381e-10, 2.9173e-10,
#               3.0788e-10, 3.0857e-10, 3.0637e-10, 2.9427e-10, 3.3804e-10, 2.7348e-10,
#               2.7329e-10, 2.9354e-10, 2.8824e-10, 3.1412e-10, 2.9372e-10, 2.3606e-10,
#               3.1756e-10, 2.7268e-10, 2.8162e-10, 3.1653e-10, 3.2022e-10, 2.8116e-10,
#               2.7147e-10, 3.0715e-10, 3.0102e-10, 3.0419e-10, 2.9124e-10, 2.8830e-10,
#               3.3608e-10, 3.2229e-10, 2.9998e-10, 2.7836e-10, 2.9117e-10, 2.9308e-10,
#               2.7002e-10, 3.4186e-10, 2.6283e-10, 3.0054e-10, 3.0395e-10, 2.9381e-10,
#               2.9547e-10, 3.1778e-10, 2.9689e-10, 2.6588e-10, 2.7965e-10, 2.8809e-10,
#               3.1051e-10, 3.1182e-10, 2.9371e-10, 2.7762e-10, 2.6720e-10, 3.1986e-10,
#               2.8566e-10, 3.6150e-10, 2.6685e-10, 3.2660e-10, 3.4028e-10, 3.1624e-10,
#               3.0091e-10, 3.0182e-10, 2.7074e-10, 2.6541e-10, 2.8409e-10, 2.7449e-10,
#               3.4580e-10, 2.7971e-10, 2.8187e-10, 2.8427e-10, 2.9256e-10, 2.6832e-10,
#               2.9487e-10, 2.9661e-10, 3.3056e-10, 2.7468e-10, 2.8170e-10, 2.8599e-10,
#               3.1326e-10, 2.9464e-10, 2.7193e-10, 3.0321e-10, 2.5620e-10, 3.0389e-10,
#               2.6726e-10, 3.2799e-10, 2.8051e-10, 3.0857e-10, 3.4233e-10, 2.9871e-10,
#               2.7203e-10, 2.9418e-10, 2.6385e-10, 2.7242e-10, 2.9028e-10, 3.5123e-10,
#               3.0034e-10, 2.9761e-10, 2.8968e-10, 2.9928e-10, 3.3188e-10, 2.8155e-10,
#               3.1091e-10, 2.6656e-10, 3.2360e-10, 3.0600e-10, 3.4769e-10, 3.2078e-10,
#               2.7580e-10, 2.8351e-10, 2.8988e-10, 2.9024e-10, 3.7066e-10, 2.8453e-10,
#               3.1159e-10, 3.1907e-10, 2.8812e-10, 2.8566e-10, 3.5612e-10, 2.8309e-10,
#               2.6959e-10, 3.0998e-10, 3.3007e-10, 2.4636e-10, 2.5282e-10, 2.9677e-10,
#               2.7898e-10, 2.8069e-10, 3.3123e-10, 2.9776e-10, 2.9786e-10, 2.9899e-10,
#               2.7629e-10, 2.7059e-10, 2.9086e-10, 3.6762e-10, 2.7727e-10, 3.0123e-10,
#               3.3259e-10, 3.1192e-10, 2.9857e-10, 3.4751e-10, 3.3728e-10, 2.6370e-10,
#               3.3823e-10, 3.2000e-10, 2.8371e-10, 2.7938e-10, 3.0841e-10, 2.9217e-10,
#               2.6799e-10, 2.6836e-10, 3.0500e-10, 3.7183e-10, 2.8693e-10, 3.3461e-10,
#               2.6765e-10, 3.3806e-10, 2.9966e-10, 3.0258e-10, 2.6258e-10, 3.1792e-10,
#               2.8357e-10, 2.5465e-10, 2.7724e-10, 3.1051e-10, 2.8268e-10, 2.9866e-10,
#               2.9412e-10, 2.7332e-10, 2.9172e-10, 2.7477e-10, 2.8631e-10, 2.5724e-10,
#               3.2028e-10, 3.2343e-10, 3.0581e-10, 3.1551e-10, 2.9036e-10, 2.6116e-10,
#               3.1004e-10, 2.6457e-10, 3.0236e-10, 3.0133e-10, 2.6940e-10, 3.1396e-10,
#               3.0086e-10, 2.9469e-10, 3.2846e-10, 3.3064e-10, 2.9575e-10, 2.8150e-10,
#               2.7301e-10, 3.2095e-10, 3.1705e-10, 2.6790e-10, 2.8199e-10, 2.8545e-10,
#               2.5901e-10, 2.9141e-10, 2.7273e-10, 3.2833e-10, 2.6966e-10, 2.6441e-10,
#               3.1997e-10, 2.6631e-10, 2.9147e-10, 2.9251e-10, 2.8772e-10, 2.6038e-10,
#               3.1502e-10, 3.1140e-10, 2.8728e-10, 3.0955e-10, 2.6478e-10, 2.9796e-10,
#               2.9121e-10, 2.6924e-10, 2.6819e-10, 2.9403e-10, 3.5638e-10, 2.6472e-10,
#               3.0790e-10, 3.0977e-10, 3.1263e-10, 3.1574e-10, 3.0312e-10, 3.0226e-10,
#               2.7426e-10, 3.1883e-10, 2.7155e-10, 3.0497e-10, 2.9893e-10, 3.0586e-10,
#               2.8557e-10, 3.2040e-10, 3.3140e-10, 2.8741e-10, 3.2387e-10, 2.7990e-10,
#               2.9430e-10, 2.6776e-10, 2.8920e-10, 2.7690e-10, 3.1154e-10, 3.0608e-10,
#               2.6262e-10, 2.5457e-10, 2.9710e-10, 2.5853e-10], device='cuda:0'))
#     )
#     (13): ReLU(inplace=True)
#     (14): QuantConv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0007], requires_grad=True), scale_factor=9.156471060123295e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0063], requires_grad=True), scale_factor=9.165062510874122e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([2.9270e-06, 3.0665e-06, 3.3881e-06, 2.9632e-06, 4.2027e-06, 2.9224e-06,
#               3.2426e-06, 3.1937e-06, 3.8531e-06, 2.9056e-06, 3.7946e-06, 3.5325e-06,
#               3.3519e-06, 3.3103e-06, 3.7432e-06, 3.3098e-06, 2.8281e-06, 3.0314e-06,
#               2.9931e-06, 3.7415e-06, 3.3300e-06, 3.3890e-06, 2.9764e-06, 3.4176e-06,
#               2.9923e-06, 3.2012e-06, 3.6995e-06, 3.0725e-06, 3.2701e-06, 3.0092e-06,
#               3.4738e-06, 3.1457e-06, 3.4546e-06, 3.0452e-06, 3.1292e-06, 3.3376e-06,
#               2.9724e-06, 3.2024e-06, 3.4329e-06, 3.1690e-06, 3.0090e-06, 3.1892e-06,
#               2.8110e-06, 3.2321e-06, 3.5544e-06, 3.2280e-06, 3.0277e-06, 3.3753e-06,
#               3.0396e-06, 3.3876e-06, 3.4435e-06, 3.1190e-06, 2.8661e-06, 3.2664e-06,
#               3.4529e-06, 3.1018e-06, 3.5551e-06, 3.1484e-06, 3.3891e-06, 3.7735e-06,
#               3.0667e-06, 2.9075e-06, 3.1700e-06, 3.4080e-06, 3.0060e-06, 3.1776e-06,
#               3.5591e-06, 3.2378e-06, 3.3283e-06, 3.2818e-06, 3.5360e-06, 3.1728e-06,
#               3.2089e-06, 3.7041e-06, 3.7172e-06, 3.3174e-06, 3.3873e-06, 3.2818e-06,
#               3.5645e-06, 2.7712e-06, 3.9409e-06, 3.4919e-06, 3.2224e-06, 3.0915e-06,
#               2.9806e-06, 2.9593e-06, 3.1796e-06, 3.1245e-06, 3.3391e-06, 3.2222e-06,
#               3.3327e-06, 3.0892e-06, 3.4809e-06, 3.0543e-06, 2.9096e-06, 3.1919e-06,
#               3.5042e-06, 3.2452e-06, 3.1072e-06, 3.8197e-06, 3.3947e-06, 3.0356e-06,
#               3.2896e-06, 3.4115e-06, 3.0365e-06, 3.2733e-06, 3.6818e-06, 2.9796e-06,
#               3.7399e-06, 3.0371e-06, 3.2030e-06, 3.5176e-06, 3.0859e-06, 3.3119e-06,
#               3.0723e-06, 3.0361e-06, 2.9132e-06, 3.3875e-06, 3.6859e-06, 3.4171e-06,
#               3.0747e-06, 3.1131e-06, 3.6124e-06, 3.4013e-06, 3.5666e-06, 3.1927e-06,
#               3.3641e-06, 3.3758e-06, 4.4060e-06, 3.6246e-06, 3.5711e-06, 3.0639e-06,
#               3.0563e-06, 3.5308e-06, 2.8136e-06, 3.1588e-06, 3.0836e-06, 3.0450e-06,
#               3.3400e-06, 3.3935e-06, 3.6904e-06, 3.1147e-06, 3.1039e-06, 3.0932e-06,
#               3.2379e-06, 3.5500e-06, 3.5107e-06, 2.8988e-06, 2.9191e-06, 3.5038e-06,
#               3.2240e-06, 3.4382e-06, 3.3255e-06, 3.1688e-06, 3.2858e-06, 3.3895e-06,
#               3.4458e-06, 2.9129e-06, 3.1079e-06, 3.2381e-06, 3.1487e-06, 3.6135e-06,
#               3.0949e-06, 2.9829e-06, 3.1411e-06, 3.4917e-06, 2.9280e-06, 3.2661e-06,
#               3.1275e-06, 3.2733e-06, 2.9156e-06, 3.7129e-06, 3.1224e-06, 3.0696e-06,
#               3.1839e-06, 3.1280e-06, 3.0632e-06, 3.5166e-06, 2.8788e-06, 2.9499e-06,
#               3.2383e-06, 3.4701e-06, 3.5705e-06, 3.5372e-06, 3.0398e-06, 3.2698e-06,
#               2.7938e-06, 3.1118e-06, 3.2230e-06, 3.0921e-06, 2.9963e-06, 3.0714e-06,
#               3.9901e-06, 3.2097e-06, 3.2621e-06, 3.5329e-06, 2.9412e-06, 3.0028e-06,
#               3.4588e-06, 3.6077e-06, 3.4428e-06, 3.1023e-06, 3.4733e-06, 2.9709e-06,
#               2.9422e-06, 3.6717e-06, 3.0125e-06, 3.2139e-06, 3.3557e-06, 3.3111e-06,
#               2.9986e-06, 3.6203e-06, 3.2803e-06, 3.2443e-06, 3.5294e-06, 2.8984e-06,
#               3.4012e-06, 3.2444e-06, 3.7914e-06, 3.3133e-06, 3.6943e-06, 3.3858e-06,
#               3.3435e-06, 3.5305e-06, 3.8921e-06, 3.0962e-06, 3.5807e-06, 3.0678e-06,
#               3.6326e-06, 3.4354e-06, 3.1287e-06, 2.9983e-06, 3.3400e-06, 3.4239e-06,
#               3.3262e-06, 3.6154e-06, 3.6005e-06, 3.5845e-06, 3.4930e-06, 3.2231e-06,
#               3.1729e-06, 2.9430e-06, 3.5937e-06, 3.2096e-06, 3.0020e-06, 3.3623e-06,
#               3.0078e-06, 3.8951e-06, 3.0140e-06, 3.2795e-06, 3.3883e-06, 3.8356e-06,
#               3.0003e-06, 2.8895e-06, 3.0820e-06, 3.4653e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([2.6801e-10, 2.8078e-10, 3.1023e-10, 2.7132e-10, 3.8482e-10, 2.6759e-10,
#               2.9691e-10, 2.9243e-10, 3.5281e-10, 2.6605e-10, 3.4745e-10, 3.2345e-10,
#               3.0691e-10, 3.0311e-10, 3.4274e-10, 3.0306e-10, 2.5896e-10, 2.7757e-10,
#               2.7406e-10, 3.4259e-10, 3.0491e-10, 3.1031e-10, 2.7254e-10, 3.1293e-10,
#               2.7399e-10, 2.9312e-10, 3.3874e-10, 2.8133e-10, 2.9942e-10, 2.7554e-10,
#               3.1808e-10, 2.8804e-10, 3.1632e-10, 2.7883e-10, 2.8653e-10, 3.0561e-10,
#               2.7217e-10, 2.9323e-10, 3.1434e-10, 2.9017e-10, 2.7552e-10, 2.9202e-10,
#               2.5739e-10, 2.9594e-10, 3.2545e-10, 2.9557e-10, 2.7723e-10, 3.0906e-10,
#               2.7832e-10, 3.1018e-10, 3.1530e-10, 2.8559e-10, 2.6244e-10, 2.9908e-10,
#               3.1616e-10, 2.8402e-10, 3.2552e-10, 2.8828e-10, 3.1032e-10, 3.4552e-10,
#               2.8080e-10, 2.6623e-10, 2.9026e-10, 3.1205e-10, 2.7525e-10, 2.9096e-10,
#               3.2589e-10, 2.9647e-10, 3.0476e-10, 3.0050e-10, 3.2377e-10, 2.9051e-10,
#               2.9382e-10, 3.3916e-10, 3.4036e-10, 3.0376e-10, 3.1015e-10, 3.0049e-10,
#               3.2639e-10, 2.5375e-10, 3.6085e-10, 3.1973e-10, 2.9506e-10, 2.8307e-10,
#               2.7292e-10, 2.7097e-10, 2.9114e-10, 2.8609e-10, 3.0575e-10, 2.9504e-10,
#               3.0516e-10, 2.8286e-10, 3.1873e-10, 2.7967e-10, 2.6641e-10, 2.9226e-10,
#               3.2086e-10, 2.9714e-10, 2.8451e-10, 3.4975e-10, 3.1084e-10, 2.7795e-10,
#               3.0122e-10, 3.1238e-10, 2.7804e-10, 2.9972e-10, 3.3712e-10, 2.7283e-10,
#               3.4245e-10, 2.7809e-10, 2.9328e-10, 3.2209e-10, 2.8256e-10, 3.0325e-10,
#               2.8132e-10, 2.7800e-10, 2.6675e-10, 3.1018e-10, 3.3750e-10, 3.1289e-10,
#               2.8154e-10, 2.8505e-10, 3.3077e-10, 3.1144e-10, 3.2658e-10, 2.9234e-10,
#               3.0803e-10, 3.0910e-10, 4.0343e-10, 3.3189e-10, 3.2698e-10, 2.8055e-10,
#               2.7985e-10, 3.2330e-10, 2.5762e-10, 2.8924e-10, 2.8235e-10, 2.7882e-10,
#               3.0583e-10, 3.1072e-10, 3.3791e-10, 2.8520e-10, 2.8421e-10, 2.8323e-10,
#               2.9647e-10, 3.2506e-10, 3.2145e-10, 2.6543e-10, 2.6729e-10, 3.2083e-10,
#               2.9520e-10, 3.1482e-10, 3.0450e-10, 2.9015e-10, 3.0086e-10, 3.1036e-10,
#               3.1551e-10, 2.6672e-10, 2.8458e-10, 2.9649e-10, 2.8831e-10, 3.3087e-10,
#               2.8338e-10, 2.7313e-10, 2.8761e-10, 3.1972e-10, 2.6810e-10, 2.9906e-10,
#               2.8637e-10, 2.9972e-10, 2.6696e-10, 3.3997e-10, 2.8591e-10, 2.8107e-10,
#               2.9153e-10, 2.8642e-10, 2.8048e-10, 3.2200e-10, 2.6360e-10, 2.7011e-10,
#               2.9651e-10, 3.1774e-10, 3.2693e-10, 3.2389e-10, 2.7834e-10, 2.9940e-10,
#               2.5582e-10, 2.8493e-10, 2.9511e-10, 2.8313e-10, 2.7435e-10, 2.8123e-10,
#               3.6535e-10, 2.9389e-10, 2.9869e-10, 3.2349e-10, 2.6931e-10, 2.7495e-10,
#               3.1670e-10, 3.3034e-10, 3.1524e-10, 2.8406e-10, 3.1803e-10, 2.7203e-10,
#               2.6940e-10, 3.3620e-10, 2.7584e-10, 2.9428e-10, 3.0726e-10, 3.0318e-10,
#               2.7457e-10, 3.3149e-10, 3.0036e-10, 2.9706e-10, 3.2317e-10, 2.6539e-10,
#               3.1143e-10, 2.9708e-10, 3.4715e-10, 3.0338e-10, 3.3827e-10, 3.1002e-10,
#               3.0614e-10, 3.2326e-10, 3.5638e-10, 2.8350e-10, 3.2786e-10, 2.8090e-10,
#               3.3262e-10, 3.1456e-10, 2.8648e-10, 2.7454e-10, 3.0582e-10, 3.1351e-10,
#               3.0456e-10, 3.3105e-10, 3.2968e-10, 3.2821e-10, 3.1983e-10, 2.9512e-10,
#               2.9053e-10, 2.6947e-10, 3.2906e-10, 2.9389e-10, 2.7487e-10, 3.0787e-10,
#               2.7541e-10, 3.5665e-10, 2.7598e-10, 3.0028e-10, 3.1025e-10, 3.5121e-10,
#               2.7472e-10, 2.6457e-10, 2.8221e-10, 3.1730e-10], device='cuda:0'))
#     )
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): QuantConv2d(
#       256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0063], requires_grad=True), scale_factor=9.165062510874122e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0015], requires_grad=True), scale_factor=9.157729800790548e-05)
#       (w_quantizer): MinMaxWeight(precision=8, scale_factor=tensor([0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0008, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0005, 0.0007,
#               0.0006, 0.0005, 0.0005, 0.0005, 0.0005, 0.0007, 0.0006, 0.0006, 0.0005,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0007, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0005, 0.0007,
#               0.0006, 0.0008, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0005,
#               0.0006, 0.0005, 0.0007, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0007, 0.0007, 0.0008, 0.0005, 0.0005, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0005, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0007, 0.0005, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0005, 0.0006, 0.0005, 0.0005, 0.0007, 0.0006,
#               0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0005, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0005, 0.0006, 0.0006,
#               0.0006, 0.0005, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0005, 0.0005, 0.0005, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0005, 0.0005, 0.0007, 0.0005, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0007, 0.0005, 0.0005, 0.0006,
#               0.0007, 0.0007, 0.0005, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0007, 0.0005, 0.0007, 0.0007,
#               0.0006, 0.0005, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0008,
#               0.0006, 0.0006, 0.0006, 0.0005, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0005, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0005, 0.0006, 0.0006, 0.0005, 0.0005, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0005, 0.0007, 0.0007, 0.0006, 0.0007, 0.0006, 0.0005, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0005, 0.0006,
#               0.0006, 0.0006, 0.0005, 0.0006, 0.0005, 0.0005, 0.0008, 0.0005, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0005, 0.0007,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0005, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0005, 0.0006, 0.0007, 0.0005, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0008, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005,
#               0.0007, 0.0007, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0005, 0.0006, 0.0005, 0.0005, 0.0006, 0.0006, 0.0006, 0.0005,
#               0.0005, 0.0007, 0.0005, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0005, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0006,
#               0.0005, 0.0006, 0.0007, 0.0005, 0.0006, 0.0008, 0.0006, 0.0006, 0.0005,
#               0.0006, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006],
#              device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([5.7597e-08, 6.0490e-08, 5.3328e-08, 5.9462e-08, 5.3637e-08, 5.7455e-08,
#               5.0653e-08, 5.6903e-08, 5.3691e-08, 6.5642e-08, 5.2914e-08, 5.6919e-08,
#               5.8074e-08, 6.2494e-08, 5.1014e-08, 5.8134e-08, 5.1999e-08, 5.4848e-08,
#               4.9902e-08, 5.3337e-08, 5.3987e-08, 5.1386e-08, 5.3028e-08, 6.9037e-08,
#               5.0870e-08, 5.3990e-08, 6.5075e-08, 5.1265e-08, 5.2627e-08, 5.4566e-08,
#               5.0548e-08, 6.0332e-08, 5.9772e-08, 5.1249e-08, 5.0184e-08, 6.4569e-08,
#               5.3782e-08, 4.8623e-08, 4.9438e-08, 4.7567e-08, 5.0298e-08, 6.1101e-08,
#               5.5412e-08, 5.0730e-08, 4.9491e-08, 5.3117e-08, 5.4961e-08, 5.4744e-08,
#               5.4410e-08, 5.9540e-08, 5.5307e-08, 5.1600e-08, 5.6528e-08, 5.8685e-08,
#               4.9763e-08, 6.2166e-08, 5.8716e-08, 5.9515e-08, 4.9412e-08, 5.5817e-08,
#               5.6367e-08, 4.9483e-08, 6.2588e-08, 5.7957e-08, 7.3997e-08, 5.5560e-08,
#               5.5921e-08, 5.0092e-08, 5.3908e-08, 5.8152e-08, 5.2550e-08, 4.9826e-08,
#               5.3336e-08, 4.7187e-08, 6.0088e-08, 5.0747e-08, 5.0164e-08, 5.1641e-08,
#               5.9293e-08, 5.4967e-08, 6.0050e-08, 6.1952e-08, 6.2641e-08, 7.0797e-08,
#               4.9223e-08, 4.8368e-08, 5.5119e-08, 5.5380e-08, 6.0917e-08, 5.3569e-08,
#               4.6621e-08, 5.6745e-08, 5.4575e-08, 5.9603e-08, 6.2734e-08, 5.4674e-08,
#               5.4030e-08, 5.8175e-08, 5.6465e-08, 5.2979e-08, 6.2606e-08, 5.5120e-08,
#               5.4595e-08, 4.9982e-08, 6.7531e-08, 5.2396e-08, 5.0925e-08, 5.4171e-08,
#               5.4071e-08, 5.1267e-08, 4.9917e-08, 5.4385e-08, 5.6304e-08, 5.5659e-08,
#               5.9757e-08, 4.9069e-08, 5.1163e-08, 4.7651e-08, 5.5944e-08, 5.5838e-08,
#               4.9197e-08, 5.6366e-08, 5.0057e-08, 5.0134e-08, 6.8692e-08, 5.3240e-08,
#               5.0679e-08, 4.8094e-08, 5.4106e-08, 5.1465e-08, 5.5111e-08, 5.7167e-08,
#               5.3169e-08, 5.9417e-08, 5.5451e-08, 4.6768e-08, 5.6859e-08, 5.9041e-08,
#               5.4010e-08, 5.5360e-08, 5.3709e-08, 5.5889e-08, 5.3585e-08, 5.7419e-08,
#               5.1850e-08, 6.6822e-08, 4.6667e-08, 5.4231e-08, 5.2605e-08, 5.8102e-08,
#               5.1699e-08, 5.1361e-08, 5.2095e-08, 5.3304e-08, 5.3974e-08, 5.1518e-08,
#               5.5216e-08, 5.1569e-08, 5.5650e-08, 5.5079e-08, 5.3737e-08, 6.1917e-08,
#               5.3841e-08, 5.4027e-08, 5.5855e-08, 5.3056e-08, 5.5178e-08, 5.2453e-08,
#               4.9662e-08, 5.9219e-08, 5.5469e-08, 6.2298e-08, 5.1859e-08, 5.3404e-08,
#               5.6668e-08, 5.9587e-08, 5.1932e-08, 5.7849e-08, 5.4061e-08, 5.9955e-08,
#               5.2014e-08, 5.2698e-08, 5.3385e-08, 5.5165e-08, 5.5015e-08, 5.4026e-08,
#               6.0612e-08, 5.0333e-08, 5.6686e-08, 5.4665e-08, 5.8082e-08, 5.1270e-08,
#               5.1171e-08, 5.1961e-08, 4.5639e-08, 4.8670e-08, 5.2345e-08, 5.7903e-08,
#               5.2350e-08, 4.7115e-08, 5.3993e-08, 5.4310e-08, 6.4905e-08, 6.7297e-08,
#               5.7427e-08, 5.4231e-08, 5.2463e-08, 6.1195e-08, 5.6611e-08, 4.7421e-08,
#               4.9811e-08, 4.9181e-08, 5.1739e-08, 5.9674e-08, 5.7724e-08, 5.6234e-08,
#               5.3133e-08, 5.6520e-08, 6.1992e-08, 5.8141e-08, 5.2177e-08, 6.2298e-08,
#               5.2596e-08, 5.4652e-08, 6.4168e-08, 5.7142e-08, 5.3869e-08, 4.7677e-08,
#               4.7469e-08, 6.2484e-08, 5.0132e-08, 5.4617e-08, 5.6082e-08, 5.9586e-08,
#               5.0702e-08, 5.8944e-08, 6.4778e-08, 5.5969e-08, 6.0555e-08, 6.1791e-08,
#               5.0325e-08, 4.6425e-08, 5.2892e-08, 6.0154e-08, 6.3517e-08, 4.7921e-08,
#               6.0789e-08, 5.0508e-08, 5.5781e-08, 5.7395e-08, 5.5408e-08, 5.3085e-08,
#               5.1764e-08, 5.4610e-08, 4.9812e-08, 5.2954e-08, 5.9089e-08, 5.1566e-08,
#               5.5630e-08, 5.8970e-08, 5.5499e-08, 6.0613e-08, 5.4593e-08, 5.2823e-08,
#               5.7065e-08, 5.1096e-08, 5.0260e-08, 5.1413e-08, 5.5339e-08, 5.2769e-08,
#               5.1932e-08, 5.0265e-08, 5.3892e-08, 5.6810e-08, 5.6770e-08, 5.4178e-08,
#               5.9275e-08, 5.6684e-08, 5.3763e-08, 5.8209e-08, 5.4414e-08, 5.1464e-08,
#               5.2697e-08, 4.7722e-08, 6.0455e-08, 4.2907e-08, 6.3937e-08, 5.9863e-08,
#               5.4712e-08, 4.9506e-08, 5.2497e-08, 6.1018e-08, 5.2921e-08, 5.8632e-08,
#               6.4208e-08, 5.6410e-08, 6.8775e-08, 5.0510e-08, 5.2770e-08, 5.3477e-08,
#               4.7623e-08, 5.6585e-08, 4.4678e-08, 5.7894e-08, 5.9017e-08, 5.3451e-08,
#               5.5758e-08, 5.1084e-08, 5.6123e-08, 4.8167e-08, 5.7357e-08, 6.5849e-08,
#               5.2106e-08, 5.9510e-08, 5.8102e-08, 5.7357e-08, 5.7203e-08, 5.8691e-08,
#               5.0028e-08, 5.0503e-08, 5.2509e-08, 5.7210e-08, 5.6104e-08, 5.0528e-08,
#               4.9624e-08, 4.4847e-08, 5.3915e-08, 5.0761e-08, 4.8646e-08, 4.8851e-08,
#               5.3852e-08, 5.0464e-08, 5.1924e-08, 4.7712e-08, 5.0306e-08, 6.0261e-08,
#               6.0747e-08, 5.0769e-08, 5.9738e-08, 5.3848e-08, 4.8586e-08, 5.4746e-08,
# ...
#               5.7374e-08, 6.7994e-08, 5.1494e-08, 5.9393e-08, 7.1443e-08, 5.0621e-08,
#               6.7928e-08, 5.4467e-08, 5.9818e-08, 5.2434e-08, 5.0533e-08, 5.7736e-08,
#               5.3866e-08, 5.4407e-08, 5.5692e-08, 5.5894e-08, 5.7553e-08, 5.2934e-08,
#               5.1620e-08, 5.3466e-08, 5.1057e-08, 6.5107e-08, 5.3943e-08, 5.1343e-08,
#               6.0324e-08, 5.0546e-08, 5.0844e-08, 5.8972e-08, 6.1328e-08, 5.5353e-08,
#               5.4692e-08, 5.3578e-08, 7.0655e-08, 5.5064e-08, 5.8922e-08, 5.0487e-08,
#               4.6827e-08, 5.9743e-08], device='cuda:0'))
#     )
#     (27): ReLU(inplace=True)
#     (28): QuantConv2d(
#       512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0052], requires_grad=True), scale_factor=9.163349022855982e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0094], requires_grad=True), scale_factor=9.169772965833545e-05)
#       (w_quantizer): MinMaxWeight(precision=8, scale_factor=tensor([0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0005, 0.0007, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0008, 0.0007, 0.0007, 0.0007, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0008, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0007,
#               0.0007, 0.0006, 0.0006, 0.0007, 0.0007, 0.0007, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0008, 0.0007, 0.0007, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0005,
#               0.0007, 0.0006, 0.0005, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0008, 0.0006, 0.0006, 0.0005, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0007, 0.0006, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0007, 0.0005, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0007, 0.0007, 0.0005, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0007, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0008, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0007, 0.0007,
#               0.0007, 0.0007, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0007,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0008, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0008, 0.0007, 0.0007, 0.0005,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0006, 0.0007, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007,
#               0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0008, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0005, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007],
#              device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([6.2495e-08, 5.3221e-08, 5.6828e-08, 5.2221e-08, 5.5874e-08, 5.6392e-08,
#               6.6514e-08, 5.3423e-08, 6.8227e-08, 5.6073e-08, 5.6918e-08, 5.3379e-08,
#               5.4040e-08, 6.5411e-08, 5.2837e-08, 5.3655e-08, 5.7108e-08, 6.3175e-08,
#               5.4917e-08, 5.4510e-08, 5.8894e-08, 6.7877e-08, 5.4165e-08, 5.7631e-08,
#               5.4563e-08, 6.2249e-08, 5.3945e-08, 5.5152e-08, 5.7960e-08, 4.9957e-08,
#               6.0221e-08, 6.0840e-08, 5.1458e-08, 6.4484e-08, 5.7091e-08, 5.8356e-08,
#               5.1546e-08, 5.9365e-08, 6.7121e-08, 5.5114e-08, 6.4469e-08, 6.1996e-08,
#               6.5900e-08, 5.9294e-08, 5.6576e-08, 5.0920e-08, 5.5602e-08, 5.6235e-08,
#               5.7544e-08, 5.4847e-08, 6.3861e-08, 5.5170e-08, 5.7601e-08, 5.0557e-08,
#               5.6644e-08, 5.5059e-08, 5.9854e-08, 7.0447e-08, 6.0521e-08, 6.1490e-08,
#               6.0910e-08, 6.3365e-08, 5.7171e-08, 5.3689e-08, 5.2450e-08, 5.7732e-08,
#               5.2907e-08, 5.6743e-08, 5.5785e-08, 5.4647e-08, 6.0808e-08, 6.2890e-08,
#               5.7145e-08, 6.0305e-08, 5.4674e-08, 5.5969e-08, 5.8913e-08, 5.8291e-08,
#               7.1454e-08, 5.6853e-08, 5.8041e-08, 6.0608e-08, 5.6074e-08, 5.3505e-08,
#               5.6108e-08, 6.0601e-08, 5.5762e-08, 5.5628e-08, 5.5647e-08, 5.9317e-08,
#               4.7929e-08, 5.1831e-08, 5.8741e-08, 6.0106e-08, 5.5166e-08, 6.2627e-08,
#               5.9510e-08, 5.5580e-08, 5.6839e-08, 6.0708e-08, 5.6455e-08, 5.8982e-08,
#               5.5936e-08, 5.9173e-08, 5.6592e-08, 5.4194e-08, 6.1297e-08, 5.6637e-08,
#               5.9208e-08, 5.5895e-08, 5.9953e-08, 5.9246e-08, 5.8324e-08, 5.2646e-08,
#               5.2896e-08, 5.6214e-08, 5.0991e-08, 6.3428e-08, 5.3279e-08, 5.8005e-08,
#               5.5054e-08, 5.7817e-08, 6.0919e-08, 6.4783e-08, 5.5836e-08, 6.1320e-08,
#               6.5584e-08, 5.1994e-08, 5.7871e-08, 6.5936e-08, 6.0756e-08, 6.0006e-08,
#               5.2790e-08, 6.3971e-08, 5.6096e-08, 5.5288e-08, 6.1381e-08, 6.6107e-08,
#               5.9260e-08, 5.9036e-08, 5.6933e-08, 5.2709e-08, 5.7706e-08, 5.5738e-08,
#               6.3643e-08, 6.8987e-08, 6.1426e-08, 6.4585e-08, 4.9211e-08, 5.9173e-08,
#               5.4309e-08, 5.6512e-08, 5.9093e-08, 6.0226e-08, 6.0663e-08, 5.1967e-08,
#               5.4530e-08, 5.4010e-08, 6.4013e-08, 5.9339e-08, 5.5565e-08, 4.9403e-08,
#               6.2575e-08, 5.4369e-08, 5.0079e-08, 6.3923e-08, 5.9976e-08, 6.4734e-08,
#               5.5358e-08, 5.0927e-08, 5.3991e-08, 6.3439e-08, 6.3605e-08, 5.4094e-08,
#               5.2915e-08, 5.7685e-08, 6.0678e-08, 6.0376e-08, 5.3995e-08, 5.5490e-08,
#               6.0712e-08, 5.6828e-08, 5.3603e-08, 5.7715e-08, 7.3221e-08, 5.2150e-08,
#               5.3868e-08, 5.0370e-08, 5.6720e-08, 5.5279e-08, 5.6751e-08, 6.1097e-08,
#               5.4584e-08, 5.7324e-08, 6.0271e-08, 5.7813e-08, 6.0315e-08, 5.5922e-08,
#               5.3149e-08, 5.6867e-08, 5.6609e-08, 6.3934e-08, 5.9613e-08, 5.3327e-08,
#               5.4675e-08, 5.7091e-08, 6.0141e-08, 6.2442e-08, 5.8105e-08, 6.2605e-08,
#               5.2871e-08, 6.0985e-08, 5.5501e-08, 5.4773e-08, 6.3771e-08, 5.6949e-08,
#               6.1096e-08, 6.2874e-08, 5.6661e-08, 6.1060e-08, 5.0323e-08, 5.8478e-08,
#               5.7820e-08, 6.2320e-08, 5.5083e-08, 6.2183e-08, 6.3925e-08, 5.0293e-08,
#               5.2125e-08, 6.1646e-08, 5.7964e-08, 5.6074e-08, 5.6860e-08, 6.5231e-08,
#               5.4345e-08, 6.4881e-08, 5.5175e-08, 5.2822e-08, 5.6507e-08, 5.0903e-08,
#               5.9165e-08, 5.3429e-08, 5.3979e-08, 6.0470e-08, 5.8677e-08, 5.1766e-08,
#               5.5165e-08, 5.1952e-08, 6.2102e-08, 5.8705e-08, 5.7176e-08, 5.3747e-08,
#               6.0892e-08, 6.4037e-08, 6.5504e-08, 5.7339e-08, 5.1059e-08, 5.6692e-08,
#               5.1814e-08, 5.2710e-08, 5.2313e-08, 5.3909e-08, 5.5058e-08, 5.5493e-08,
#               5.5935e-08, 5.0191e-08, 6.3184e-08, 5.2683e-08, 6.0710e-08, 5.4165e-08,
#               5.8600e-08, 6.1868e-08, 5.9771e-08, 5.6704e-08, 5.7890e-08, 5.7010e-08,
#               6.9072e-08, 5.8856e-08, 5.6594e-08, 6.7397e-08, 6.0549e-08, 5.5123e-08,
#               5.0545e-08, 6.2101e-08, 5.5225e-08, 5.9551e-08, 5.5374e-08, 6.0061e-08,
#               5.5465e-08, 6.2434e-08, 5.5174e-08, 5.7940e-08, 5.4443e-08, 6.0300e-08,
#               6.2558e-08, 6.4037e-08, 6.7546e-08, 6.4479e-08, 6.2981e-08, 6.7354e-08,
#               5.7101e-08, 6.0040e-08, 5.4954e-08, 5.0860e-08, 5.1633e-08, 6.4684e-08,
#               5.6853e-08, 5.8191e-08, 5.7249e-08, 6.1666e-08, 5.5135e-08, 6.2834e-08,
#               5.5950e-08, 5.6748e-08, 5.5664e-08, 6.3554e-08, 5.2411e-08, 5.5219e-08,
#               5.5342e-08, 6.5298e-08, 5.4842e-08, 5.5280e-08, 5.3678e-08, 5.0691e-08,
#               5.3592e-08, 5.4000e-08, 5.9165e-08, 5.7782e-08, 6.0880e-08, 5.1829e-08,
#               5.6116e-08, 6.3077e-08, 6.2192e-08, 5.7608e-08, 5.7846e-08, 6.2763e-08,
#               5.5139e-08, 5.6303e-08, 5.1954e-08, 6.2599e-08, 5.2894e-08, 6.1028e-08,
#               5.1807e-08, 5.2838e-08, 7.0741e-08, 5.3402e-08, 5.3912e-08, 5.9464e-08,
#               5.3647e-08, 5.4552e-08, 6.4068e-08, 5.6335e-08, 5.3020e-08, 5.9740e-08,
#               6.5298e-08, 5.6538e-08, 5.4709e-08, 5.9349e-08, 6.2096e-08, 5.1713e-08,
#               5.5726e-08, 5.6124e-08, 6.5869e-08, 6.5249e-08, 6.3896e-08, 5.1630e-08,
#               5.5426e-08, 5.6863e-08, 5.8871e-08, 5.6361e-08, 5.5634e-08, 5.9194e-08,
#               6.3107e-08, 6.0510e-08, 5.7818e-08, 5.5257e-08, 6.3285e-08, 5.1938e-08,
#               5.1040e-08, 5.9715e-08, 6.4657e-08, 5.0795e-08, 5.3562e-08, 6.9106e-08,
#               6.0332e-08, 6.0973e-08, 4.6328e-08, 5.6095e-08, 5.6440e-08, 5.5921e-08,
#               5.7948e-08, 5.5276e-08, 5.4165e-08, 5.7309e-08, 6.5508e-08, 5.5375e-08,
#               5.2261e-08, 5.1407e-08, 5.2657e-08, 5.3515e-08, 6.4270e-08, 5.5494e-08,
#               5.6270e-08, 5.4309e-08, 5.1109e-08, 5.4657e-08, 5.9883e-08, 5.1817e-08,
#               6.2362e-08, 6.1334e-08, 6.1954e-08, 6.0159e-08, 5.1569e-08, 5.7739e-08,
#               5.6946e-08, 5.5160e-08, 5.8513e-08, 5.9878e-08, 5.1194e-08, 5.7482e-08,
#               6.0491e-08, 5.4946e-08, 5.2433e-08, 5.7729e-08, 5.3543e-08, 6.5288e-08,
#               6.7399e-08, 5.8120e-08, 5.4622e-08, 5.7477e-08, 6.4834e-08, 6.1650e-08,
#               5.9190e-08, 5.3477e-08, 6.2202e-08, 6.2040e-08, 5.7642e-08, 5.1794e-08,
#               5.7050e-08, 5.4574e-08, 5.7352e-08, 6.4591e-08, 6.7969e-08, 5.5792e-08,
#               5.5012e-08, 5.2314e-08, 6.2473e-08, 5.6298e-08, 5.6943e-08, 5.7384e-08,
#               5.8198e-08, 6.0673e-08, 5.1975e-08, 5.6780e-08, 6.2878e-08, 6.8963e-08,
#               5.9190e-08, 5.3771e-08, 5.3788e-08, 6.3973e-08, 5.3702e-08, 5.9602e-08,
#               6.0088e-08, 5.2943e-08, 5.0738e-08, 6.3727e-08, 5.6465e-08, 5.8935e-08,
#               5.7342e-08, 5.5556e-08, 5.1458e-08, 6.0586e-08, 5.3377e-08, 5.7288e-08,
#               5.1863e-08, 5.5348e-08, 5.7480e-08, 5.5590e-08, 5.3778e-08, 5.1450e-08,
#               6.1617e-08, 5.3780e-08, 5.4130e-08, 5.7036e-08, 5.9040e-08, 5.7805e-08,
#               5.8717e-08, 5.3140e-08, 5.4063e-08, 4.9852e-08, 6.0344e-08, 6.4065e-08,
#               5.3428e-08, 5.2224e-08, 5.3264e-08, 5.9469e-08, 5.5622e-08, 5.6795e-08,
#               5.2912e-08, 6.0120e-08, 5.4285e-08, 6.4061e-08, 5.5346e-08, 5.8504e-08,
#               6.1326e-08, 5.5975e-08, 5.1908e-08, 5.8218e-08, 5.4538e-08, 5.9807e-08,
#               5.7413e-08, 6.0966e-08], device='cuda:0'))
#     )
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Module(
#     (0): QuantLinear(
#       in_features=25088, out_features=4096, bias=True
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0094], requires_grad=True), scale_factor=9.169772965833545e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0042], requires_grad=True), scale_factor=9.16184508241713e-05)
#       (w_quantizer): MinMaxWeight(precision=8, scale_factor=tensor([0.0003, 0.0003, 0.0004,  ..., 0.0004, 0.0003, 0.0003], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([3.1060e-08, 2.9734e-08, 3.2870e-08,  ..., 3.3292e-08, 3.0402e-08,
#               3.0947e-08], device='cuda:0'))
#     )
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): QuantLinear(
#       in_features=4096, out_features=4096, bias=True
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0042], requires_grad=True), scale_factor=9.16184508241713e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0000], requires_grad=True), scale_factor=9.155402221949771e-05)
#       (w_quantizer): MinMaxWeight(precision=8, scale_factor=tensor([0.0003, 0.0003, 0.0003,  ..., 0.0003, 0.0003, 0.0003], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([2.6870e-08, 2.6487e-08, 2.8261e-08,  ..., 2.5933e-08, 2.9229e-08,
#               2.7700e-08], device='cuda:0'))
#     )
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): QuantLinear(
#       in_features=4096, out_features=10, bias=True
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0000], requires_grad=True), scale_factor=9.155402221949771e-05)
#       (out_quantizer): DummyQuantizer(precision=None (dummy quantizer), scale_factor=1.0)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([1.3251e-06, 1.2513e-06, 1.2681e-06, 1.2420e-06, 1.3987e-06, 1.2554e-06,
#               1.2495e-06, 1.1633e-06, 1.2031e-06, 1.1958e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([1.2131e-10, 1.1456e-10, 1.1610e-10, 1.1371e-10, 1.2806e-10, 1.1494e-10,
#               1.1439e-10, 1.0650e-10, 1.1015e-10, 1.0948e-10], device='cuda:0'))
#     )
#   )
# )

# %% [markdown]
# ### 3.2.4 SuperNet

# %%
SuperNet_init = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_Init.pth')

# Initial structure
SuperNet_init
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# In order to apply SuperNet optimization, we need to manually define alternatives for either single layers or enitre modules if the original structure. The alternatives you see down below have been tested, so that all of them do not compromise the training phase, meaning that the model should still learn.
#
# VGG structure is mainly composed of two kinds of layers: **Convolutional** and **Linear**. Therefore the alternatives being considered are either special forms of these layers or the same layers with less parameters:
# * for the _convolutional_ layers, since the `SuperNetModule` requires alternatives with the same output shape, we have selected specific convolutional layers of the VGG feature extractor, by considering either a **depth-wise** or a **point-wise** version of those layers;
# * for the _linear_ layers, we have considered variations of the VGG classifier structure, by considering either the same number of layers with less parameters (hidden units) or a lower number of layers with less number of parameters (hidden units)

# %%
# Original features structure
original_features = SuperNet_init.features

# 1st alternative - depth-wise convolution on layers increasing the number of channels
alt_1 = dc(original_features)
alt_1[5] = nn.Conv2d(original_features[5].in_channels, original_features[5].out_channels, original_features[5].kernel_size, stride=1, padding=original_features[5].padding, groups=original_features[5].in_channels)
alt_1[10] = nn.Conv2d(original_features[10].in_channels, original_features[10].out_channels, original_features[10].kernel_size, stride=1, padding=original_features[10].padding, groups=original_features[10].in_channels)
alt_1[17] = nn.Conv2d(original_features[17].in_channels, original_features[17].out_channels, original_features[17].kernel_size, stride=1, padding=original_features[17].padding, groups=original_features[17].in_channels)

# 2nd alternative - point-wise convolution on layers increasing the number of channels
alt_2 = dc(original_features)
alt_2[5] = nn.Conv2d(original_features[5].in_channels, original_features[5].out_channels, kernel_size=1 , stride=1)
alt_2[10] = nn.Conv2d(original_features[10].in_channels, original_features[10].out_channels,  kernel_size=1 , stride=1)
alt_2[17] = nn.Conv2d(original_features[17].in_channels, original_features[17].out_channels,  kernel_size=1 , stride=1)

# 3rd alternative - depth-wise convolution on the last 2 convolutional layers
alt_3 = dc(original_features)
alt_3[26] = nn.Conv2d(original_features[26].in_channels, original_features[26].out_channels, original_features[26].kernel_size, stride=1, padding=original_features[26].padding, groups=original_features[26].in_channels)
alt_3[28] = nn.Conv2d(original_features[28].in_channels, original_features[28].out_channels, original_features[28].kernel_size, stride=1, padding=original_features[28].padding, groups=original_features[28].in_channels)

# %%
# Original model's classifier structure
original_classifier = SuperNet_init.classifier

# 1st alternative
classifier_1 = nn.Sequential(
    nn.Linear(in_features=25088, out_features=2048, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=2048, out_features=2048, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=2048, out_features=10, bias=True)
)

# 2nd alternative
classifier_2 = nn.Sequential(
    nn.Linear(in_features=25088, out_features=2048, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=2048, out_features=10, bias=True)
)

# 3rd alternative
classifier_3 = nn.Sequential(
    nn.Linear(in_features=25088, out_features=1024, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=1024, out_features=10, bias=True)
)

# %%
# Modify the features structure for SuperNet optimization
SuperNet_init.features = SuperNetModule([
    original_features,
    alt_1,
    alt_2,
    alt_3
])

# Modify the classifer structure for SuperNet optimization
SuperNet_init.classifier = SuperNetModule([
    original_classifier,
    classifier_1,
    classifier_2,
    classifier_3
])

# New structure
SuperNet_init
# Out:
# VGG(
#   (features): SuperNetModule(
#     (sn_branches): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (1): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (2): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (3): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (sn_combiner): SuperNetCombiner()
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): SuperNetModule(
#     (sn_branches): ModuleList(
#       (0): Sequential(
#         (0): Linear(in_features=25088, out_features=4096, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=4096, out_features=4096, bias=True)
#         (4): ReLU(inplace=True)
#         (5): Dropout(p=0.5, inplace=False)
#         (6): Linear(in_features=4096, out_features=10, bias=True)
#       )
#       (1): Sequential(
#         (0): Linear(in_features=25088, out_features=2048, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=2048, out_features=2048, bias=True)
#         (4): ReLU(inplace=True)
#         (5): Dropout(p=0.5, inplace=False)
#         (6): Linear(in_features=2048, out_features=10, bias=True)
#       )
#       (2): Sequential(
#         (0): Linear(in_features=25088, out_features=2048, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=2048, out_features=10, bias=True)
#       )
#       (3): Sequential(
#         (0): Linear(in_features=25088, out_features=1024, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=1024, out_features=10, bias=True)
#       )
#     )
#     (sn_combiner): SuperNetCombiner()
#   )
# )

# %%
# Create PIT PLiNIO model object with parameters cost
SuperNet_model = SuperNet(SuperNet_init, input_shape=random_sample.shape, cost={'size': params})

initial_params = SuperNet_model.get_cost('size').item()
print(f"Parameters cost befor SuperNet optimization: {int(SuperNet_model.get_cost('size').item())}")
# Out:
# Parameters cost befor SuperNet optimization: 76264656

# %%
# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(SuperNet_model.parameters(), lr=0.001)

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train the model with SuperNet optimization
SuperNet_results = utils.train_model(
    model=SuperNet_model,
    data_loader=train_dataloader,
    device=device,
    loss_fn=loss_fn,
    optimizer=optimizer,
    optim_method='SuperNet',
    cost_strength={'size': 1e-7}
)

print(f"Total training time (on {SuperNet_results['device']}): {SuperNet_results['total_time']:.3f} seconds.")
print(f"Avg training time (on {SuperNet_results['device']}): {(SuperNet_results['total_time']/3):.3f} seconds.")
# Out:
# ********************
# EPOCH 0
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 9.32876 | Avg Accuracy: 11.06%
# Computed 999/3750 batches - Avg Loss: 8.85278 | Avg Accuracy: 11.82%
# Computed 1499/3750 batches - Avg Loss: 8.46305 | Avg Accuracy: 13.51%
# Computed 1999/3750 batches - Avg Loss: 7.98866 | Avg Accuracy: 22.73%
# Computed 2499/3750 batches - Avg Loss: 7.48361 | Avg Accuracy: 33.43%
# Computed 2999/3750 batches - Avg Loss: 7.08589 | Avg Accuracy: 41.21%
# Computed 3499/3750 batches - Avg Loss: 6.77339 | Avg Accuracy: 47.07%
#
# End of EPOCH 0 - Avg Loss: 6.63962 | Avg Accuracy: 49.48%
# Training time: 5970.878 seconds.
#
# #Parameters after EPOCH 0: 42029980
# ********************
#
# ********************
# EPOCH 1
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 4.72539 | Avg Accuracy: 84.17%
# Computed 999/3750 batches - Avg Loss: 4.68558 | Avg Accuracy: 84.47%
# Computed 1499/3750 batches - Avg Loss: 4.64362 | Avg Accuracy: 84.80%
# Computed 1999/3750 batches - Avg Loss: 4.61360 | Avg Accuracy: 85.16%
# Computed 2499/3750 batches - Avg Loss: 4.58690 | Avg Accuracy: 85.33%
# Computed 2999/3750 batches - Avg Loss: 4.56303 | Avg Accuracy: 85.55%
# Computed 3499/3750 batches - Avg Loss: 4.53748 | Avg Accuracy: 85.85%
#
# End of EPOCH 1 - Avg Loss: 4.52531 | Avg Accuracy: 85.93%
# Training time: 6105.277 seconds.
#
# #Parameters after EPOCH 1: 39418316
# ********************
#
# ********************
# EPOCH 2
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 4.35246 | Avg Accuracy: 88.36%
# Computed 999/3750 batches - Avg Loss: 4.33432 | Avg Accuracy: 88.28%
# Computed 1499/3750 batches - Avg Loss: 4.32496 | Avg Accuracy: 88.19%
# Computed 1999/3750 batches - Avg Loss: 4.31362 | Avg Accuracy: 88.22%
# Computed 2499/3750 batches - Avg Loss: 4.30240 | Avg Accuracy: 88.33%
# Computed 2999/3750 batches - Avg Loss: 4.29115 | Avg Accuracy: 88.48%
# Computed 3499/3750 batches - Avg Loss: 4.28051 | Avg Accuracy: 88.57%
#
# End of EPOCH 2 - Avg Loss: 4.27536 | Avg Accuracy: 88.57%
# Training time: 6016.823 seconds.
#
# #Parameters after EPOCH 2: 38353180
# ********************
#
# ********************
# EPOCH 3
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 4.18765 | Avg Accuracy: 89.94%
# Computed 999/3750 batches - Avg Loss: 4.18461 | Avg Accuracy: 89.81%
# Computed 1499/3750 batches - Avg Loss: 4.17158 | Avg Accuracy: 89.86%
# Computed 1999/3750 batches - Avg Loss: 4.16355 | Avg Accuracy: 89.90%
# Computed 2499/3750 batches - Avg Loss: 4.15580 | Avg Accuracy: 89.96%
# Computed 2999/3750 batches - Avg Loss: 4.15018 | Avg Accuracy: 89.98%
# Computed 3499/3750 batches - Avg Loss: 4.14669 | Avg Accuracy: 89.93%
#
# End of EPOCH 3 - Avg Loss: 4.14340 | Avg Accuracy: 89.89%
# Training time: 5943.369 seconds.
#
# #Parameters after EPOCH 3: 37661168
# ********************
#
# ********************
# EPOCH 4
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 4.07625 | Avg Accuracy: 90.86%
# Computed 999/3750 batches - Avg Loss: 4.06844 | Avg Accuracy: 90.92%
# Computed 1499/3750 batches - Avg Loss: 4.06397 | Avg Accuracy: 90.83%
# Computed 1999/3750 batches - Avg Loss: 4.06647 | Avg Accuracy: 90.65%
# Computed 2499/3750 batches - Avg Loss: 4.06134 | Avg Accuracy: 90.68%
# Computed 2999/3750 batches - Avg Loss: 4.05903 | Avg Accuracy: 90.66%
# Computed 3499/3750 batches - Avg Loss: 4.05425 | Avg Accuracy: 90.73%
#
# End of EPOCH 4 - Avg Loss: 4.05055 | Avg Accuracy: 90.75%
# Training time: 6034.911 seconds.
#
# #Parameters after EPOCH 4: 37195876
# ********************
#
# Total training time (on cuda): 30071.258 seconds.
# Avg training time (on cuda): 10023.753 seconds.

# %%
optim_params = SuperNet_model.get_cost('size')
print(f'#Parameters after SuperNet optimzation: {int(optim_params)} -> {((1 - optim_params/initial_params)*100):.2f}% fewer parameters.')
# Out:
# #Parameters after SuperNet optimzation: 37195876 -> 51.23% fewer parameters.

# %%
# Export the model to PyTorch vanilla and save it
SuperNet_exported = SuperNet_model.export()
torch.save(SuperNet_exported, './Models_checkpoints/notMNIST/VGG16_notMNIST_SuperNet.pth')

# %%
# Check the model structure assigned
SuperNet_exported
# Out:
# VGG(
#   (features): Module(
#     (sn_branches): Module(
#       (3): Module(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Module(
#     (sn_branches): Module(
#       (3): Module(
#         (0): Linear(in_features=25088, out_features=1024, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=1024, out_features=10, bias=True)
#       )
#     )
#   )
# )

# %% [markdown]
# #### **LIMITATION**

# %%
# Results
SuperNet_model_results = utils.evaluate_model(model=SuperNet_exported, device=device, loss_fn=loss_fn, data_loader=train_dataloader)

print(f'''SuperNet optimization Results (on {SuperNet_model_results['device']}):
    - Total inference time: {SuperNet_model_results['total_inference_time']:.3f} seconds
    - Inference time per batch: {SuperNet_model_results['avg_inference_time']:.3f} seconds
    - Minimum inference time: {SuperNet_model_results['min_inference_time']:.3f} seconds
    - Average loss: {SuperNet_model_results['avg_loss']:.5f}
    - Average accuracy: {(SuperNet_model_results['avg_acc']*100):.2f} %''')
# Out:
# SuperNet optimization Results (on cuda):
#     - Total inference time: 20.920 seconds
#     - Inference time per batch: 5.579 seconds
#     - Minimum inference time: 3.205 seconds
#     - Average loss: 2.30484
#     - Average accuracy: 10.00 %

# %% [markdown]
# It looks like that the framework exports <u>only the architecture of the model</u>, rather the _trained_ model itself. Thus, further training is required!

# %%
# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(SuperNet_exported.parameters(), lr=0.001)

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train the model with SuperNet optimization
SuperNet_exported_results = utils.train_model(
    model=SuperNet_exported,
    data_loader=train_dataloader,
    device=device,
    loss_fn=loss_fn,
    optimizer=optimizer
)

print(f"Total training time (on {SuperNet_exported_results['device']}): {SuperNet_exported_results['total_time']:.3f} seconds.")
print(f"Avg training time (on {SuperNet_exported_results['device']}): {(SuperNet_exported_results['total_time']/3):.3f} seconds.")
# Out:
# ********************
# EPOCH 0
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 2.30808 | Avg Accuracy: 9.82%
# Computed 999/3750 batches - Avg Loss: 2.30507 | Avg Accuracy: 9.97%
# Computed 1499/3750 batches - Avg Loss: 2.30248 | Avg Accuracy: 10.82%
# Computed 1999/3750 batches - Avg Loss: 2.21925 | Avg Accuracy: 16.39%
# Computed 2499/3750 batches - Avg Loss: 1.98666 | Avg Accuracy: 26.94%
# Computed 2999/3750 batches - Avg Loss: 1.79349 | Avg Accuracy: 35.09%
# Computed 3499/3750 batches - Avg Loss: 1.63915 | Avg Accuracy: 41.42%
#
# End of EPOCH 0 - Avg Loss: 1.57265 | Avg Accuracy: 44.11%
# Training time: 638.275 seconds.
# ********************
#
# ********************
# EPOCH 1
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.59353 | Avg Accuracy: 83.23%
# Computed 999/3750 batches - Avg Loss: 0.57552 | Avg Accuracy: 83.67%
# Computed 1499/3750 batches - Avg Loss: 0.54894 | Avg Accuracy: 84.25%
# Computed 1999/3750 batches - Avg Loss: 0.53411 | Avg Accuracy: 84.62%
# Computed 2499/3750 batches - Avg Loss: 0.52234 | Avg Accuracy: 84.93%
# Computed 2999/3750 batches - Avg Loss: 0.51129 | Avg Accuracy: 85.23%
# Computed 3499/3750 batches - Avg Loss: 0.49976 | Avg Accuracy: 85.52%
#
# End of EPOCH 1 - Avg Loss: 0.49435 | Avg Accuracy: 85.63%
# Training time: 633.615 seconds.
# ********************
#
# ********************
# EPOCH 2
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.41218 | Avg Accuracy: 88.26%
# Computed 999/3750 batches - Avg Loss: 0.40834 | Avg Accuracy: 88.09%
# Computed 1499/3750 batches - Avg Loss: 0.40871 | Avg Accuracy: 88.08%
# Computed 1999/3750 batches - Avg Loss: 0.40248 | Avg Accuracy: 88.13%
# Computed 2499/3750 batches - Avg Loss: 0.39983 | Avg Accuracy: 88.25%
# Computed 2999/3750 batches - Avg Loss: 0.39548 | Avg Accuracy: 88.42%
# Computed 3499/3750 batches - Avg Loss: 0.39190 | Avg Accuracy: 88.48%
#
# End of EPOCH 2 - Avg Loss: 0.39134 | Avg Accuracy: 88.48%
# Training time: 625.345 seconds.
# ********************
#
# ********************
# EPOCH 3
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.35410 | Avg Accuracy: 89.55%
# Computed 999/3750 batches - Avg Loss: 0.36009 | Avg Accuracy: 89.34%
# Computed 1499/3750 batches - Avg Loss: 0.35274 | Avg Accuracy: 89.53%
# Computed 1999/3750 batches - Avg Loss: 0.35071 | Avg Accuracy: 89.64%
# Computed 2499/3750 batches - Avg Loss: 0.34933 | Avg Accuracy: 89.71%
# Computed 2999/3750 batches - Avg Loss: 0.34876 | Avg Accuracy: 89.75%
# Computed 3499/3750 batches - Avg Loss: 0.35009 | Avg Accuracy: 89.72%
#
# End of EPOCH 3 - Avg Loss: 0.34992 | Avg Accuracy: 89.66%
# Training time: 620.359 seconds.
# ********************
#
# ********************
# EPOCH 4
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.31865 | Avg Accuracy: 90.71%
# Computed 999/3750 batches - Avg Loss: 0.32041 | Avg Accuracy: 90.50%
# Computed 1499/3750 batches - Avg Loss: 0.32040 | Avg Accuracy: 90.44%
# Computed 1999/3750 batches - Avg Loss: 0.32613 | Avg Accuracy: 90.26%
# Computed 2499/3750 batches - Avg Loss: 0.32349 | Avg Accuracy: 90.30%
# Computed 2999/3750 batches - Avg Loss: 0.32384 | Avg Accuracy: 90.34%
# Computed 3499/3750 batches - Avg Loss: 0.32139 | Avg Accuracy: 90.37%
#
# End of EPOCH 4 - Avg Loss: 0.31972 | Avg Accuracy: 90.41%
# Training time: 636.141 seconds.
# ********************
#
# Total training time (on cuda): 3153.735 seconds.
# Avg training time (on cuda): 1051.245 seconds.

# %%
# Save the actually trained model
torch.save(SuperNet_exported, './Models_checkpoints/notMNIST/VGG16_notMNIST_SuperNet.pth')

# %% [markdown]
# ### 3.2.5 Cost-aware SuperNet optimization (with **DUCCIO** regularizer)
#
# As for cost-aware PIT, we now want to consider costs as constraints rather than just secondary objectives.
#
# In order to do so we apply the SuperNet optimization, on the same modified model we used for standard SuperNet, adding the constraint of FLOPS to the list of costs. As before, the regularizer will be created in order to search in the space of networks which have <u>only 10%</u> pf the original parameters and FLOPS.

# %%
# Load VGG16 initialization
SuperNet_init = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_Init.pth')

# Initial structure
SuperNet_init
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
# Original features structure
original_features = SuperNet_init.features

# 1st alternative - depth-wise convolution on layers increasing the number of channels
alt_1 = dc(original_features)
alt_1[5] = nn.Conv2d(original_features[5].in_channels, original_features[5].out_channels, original_features[5].kernel_size, stride=1, padding=original_features[5].padding, groups=original_features[5].in_channels)
alt_1[10] = nn.Conv2d(original_features[10].in_channels, original_features[10].out_channels, original_features[10].kernel_size, stride=1, padding=original_features[10].padding, groups=original_features[10].in_channels)
alt_1[17] = nn.Conv2d(original_features[17].in_channels, original_features[17].out_channels, original_features[17].kernel_size, stride=1, padding=original_features[17].padding, groups=original_features[17].in_channels)

# 2nd alternative - point-wise convolution on layers increasing the number of channels
alt_2 = dc(original_features)
alt_2[5] = nn.Conv2d(original_features[5].in_channels, original_features[5].out_channels, kernel_size=1 , stride=1)
alt_2[10] = nn.Conv2d(original_features[10].in_channels, original_features[10].out_channels,  kernel_size=1 , stride=1)
alt_2[17] = nn.Conv2d(original_features[17].in_channels, original_features[17].out_channels,  kernel_size=1 , stride=1)

# 3rd alternative - depth-wise convolution on the last 2 convolutional layers
alt_3 = dc(original_features)
alt_3[26] = nn.Conv2d(original_features[26].in_channels, original_features[26].out_channels, original_features[26].kernel_size, stride=1, padding=original_features[26].padding, groups=original_features[26].in_channels)
alt_3[28] = nn.Conv2d(original_features[28].in_channels, original_features[28].out_channels, original_features[28].kernel_size, stride=1, padding=original_features[28].padding, groups=original_features[28].in_channels)

# %%
# Original model's classifier structure
original_classifier = SuperNet_init.classifier

# 1st alternative
classifier_1 = nn.Sequential(
    nn.Linear(in_features=25088, out_features=2048, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=2048, out_features=2048, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=2048, out_features=10, bias=True)
)

# 2nd alternative
classifier_2 = nn.Sequential(
    nn.Linear(in_features=25088, out_features=2048, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=2048, out_features=10, bias=True)
)

# 3rd alternative
classifier_3 = nn.Sequential(
    nn.Linear(in_features=25088, out_features=1024, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=1024, out_features=10, bias=True)
)

# %%
# Modify the features structure for SuperNet optimization
SuperNet_init.features = SuperNetModule([
    original_features,
    alt_1,
    alt_2,
    alt_3
])

# Modify the classifer structure for SuperNet optimization
SuperNet_init.classifier = SuperNetModule([
    original_classifier,
    classifier_1,
    classifier_2,
    classifier_3
])

# New structure
SuperNet_init
# Out:
# VGG(
#   (features): SuperNetModule(
#     (sn_branches): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (1): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (2): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (3): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (sn_combiner): SuperNetCombiner()
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): SuperNetModule(
#     (sn_branches): ModuleList(
#       (0): Sequential(
#         (0): Linear(in_features=25088, out_features=4096, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=4096, out_features=4096, bias=True)
#         (4): ReLU(inplace=True)
#         (5): Dropout(p=0.5, inplace=False)
#         (6): Linear(in_features=4096, out_features=10, bias=True)
#       )
#       (1): Sequential(
#         (0): Linear(in_features=25088, out_features=2048, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=2048, out_features=2048, bias=True)
#         (4): ReLU(inplace=True)
#         (5): Dropout(p=0.5, inplace=False)
#         (6): Linear(in_features=2048, out_features=10, bias=True)
#       )
#       (2): Sequential(
#         (0): Linear(in_features=25088, out_features=2048, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=2048, out_features=10, bias=True)
#       )
#       (3): Sequential(
#         (0): Linear(in_features=25088, out_features=1024, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=1024, out_features=10, bias=True)
#       )
#     )
#     (sn_combiner): SuperNetCombiner()
#   )
# )

# %%
# Create SuperNet PLiNIO model object with parameters and FLOPS cost
SuperNet_duccio = SuperNet(model=SuperNet_init, input_shape=random_sample.shape, cost={'#Parameters': params, '#FLOPS': ops})
initial_params = SuperNet_duccio.get_cost('#Parameters').item()
initial_flops = SuperNet_duccio.get_cost('#FLOPS').item()

# Define the constraint for the regularizer - 10% of the original parameters and FLOPS
constraint_params = torch.tensor(initial_params*0.1, device=device)
constraint_flops = torch.tensor(initial_flops*0.1, device=device)
params_strength = torch.tensor(1e-7, device=device)
flops_strength = torch.tensor(1e-10, device=device)

print(f'#Parameters before SuperNet optimization: {int(initial_params)}')
print(f'#FLOPS before SuperNet optimization: {int(initial_flops)}')

print(f'\nConstraint for DUCCIO regularizer (parameters): {int(constraint_params.item())} parameters.')
print(f'Constraint for DUCCIO regularizer (FLOPS): {int(constraint_flops.item())} parameters.')

# Create the regularizer
regularizer = DUCCIO({'#Parameters': constraint_params, '#FLOPS': constraint_flops}, final_strengths=(params_strength, flops_strength))
# Out:
# #Parameters before SuperNet optimization: 76264656
# #FLOPS before SuperNet optimization: 14518124544
#
# Constraint for DUCCIO regularizer (parameters): 7626465 parameters.
# Constraint for DUCCIO regularizer (FLOPS): 1451812480 parameters.

# %%
# Setup loss function ad optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(SuperNet_duccio.parameters(), lr=0.001)

# %%
torch.cuda.empty_cache()

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train the model with SuperNet optimization and DUCCIO regularizer
SuperNet_duccio_results = utils.train_model_duccio(
    model=SuperNet_duccio,
    data_loader=train_dataloader,
    device=device,
    loss_fn=loss_fn,
    optimizer=optimizer,
    cost_names=['#Parameters', '#FLOPS'],
    regularizer=regularizer
)

print(f"Total training time (on {SuperNet_duccio_results['device']}): {SuperNet_duccio_results['total_time']:.3f} seconds.")
print(f"Avg training time (on {SuperNet_duccio_results['device']}): {(SuperNet_duccio_results['total_time']/3):.3f} seconds.")
# Out:
# ********************
# EPOCH 0
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 2.38823 | Avg Accuracy: 10.83%
# Computed 999/3750 batches - Avg Loss: 2.38512 | Avg Accuracy: 10.69%
# Computed 1499/3750 batches - Avg Loss: 2.38293 | Avg Accuracy: 11.14%
# Computed 1999/3750 batches - Avg Loss: 2.37941 | Avg Accuracy: 12.18%
# Computed 2499/3750 batches - Avg Loss: 2.29306 | Avg Accuracy: 18.21%
# Computed 2999/3750 batches - Avg Loss: 2.07479 | Avg Accuracy: 27.53%
# Computed 3499/3750 batches - Avg Loss: 1.89444 | Avg Accuracy: 34.98%
#
# End of EPOCH 0 - Avg Loss: 1.81816 | Avg Accuracy: 38.08%
# Training time: 6414.842 seconds.
#
# #Parameters after epoch EPOCH 0: 74274736
# #FLOPS after epoch EPOCH 0: 14532871168
# ********************
#
# ********************
# EPOCH 1
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 3.77661 | Avg Accuracy: 82.38%
# Computed 999/3750 batches - Avg Loss: 3.66078 | Avg Accuracy: 82.80%
# Computed 1499/3750 batches - Avg Loss: 3.55462 | Avg Accuracy: 83.24%
# Computed 1999/3750 batches - Avg Loss: 3.46424 | Avg Accuracy: 83.69%
# Computed 2499/3750 batches - Avg Loss: 3.38234 | Avg Accuracy: 84.02%
# Computed 2999/3750 batches - Avg Loss: 3.30842 | Avg Accuracy: 84.37%
# Computed 3499/3750 batches - Avg Loss: 3.23705 | Avg Accuracy: 84.70%
#
# End of EPOCH 1 - Avg Loss: 3.20383 | Avg Accuracy: 84.82%
# Training time: 6292.153 seconds.
#
# #Parameters after epoch EPOCH 1: 50713556
# #FLOPS after epoch EPOCH 1: 14456420352
# ********************
#
# ********************
# EPOCH 2
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 4.81632 | Avg Accuracy: 87.61%
# Computed 999/3750 batches - Avg Loss: 4.70825 | Avg Accuracy: 87.58%
# Computed 1499/3750 batches - Avg Loss: 4.62767 | Avg Accuracy: 87.51%
# Computed 1999/3750 batches - Avg Loss: 4.55679 | Avg Accuracy: 87.49%
# Computed 2499/3750 batches - Avg Loss: 4.49863 | Avg Accuracy: 87.64%
# Computed 2999/3750 batches - Avg Loss: 4.44887 | Avg Accuracy: 87.82%
# Computed 3499/3750 batches - Avg Loss: 4.40596 | Avg Accuracy: 87.93%
#
# End of EPOCH 2 - Avg Loss: 4.38649 | Avg Accuracy: 87.98%
# Training time: 6389.231 seconds.
#
# #Parameters after epoch EPOCH 2: 41140032
# #FLOPS after epoch EPOCH 2: 14348547072
# ********************
#
# ********************
# EPOCH 3
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 4.99060 | Avg Accuracy: 89.68%
# Computed 999/3750 batches - Avg Loss: 4.97498 | Avg Accuracy: 89.36%
# Computed 1499/3750 batches - Avg Loss: 4.94758 | Avg Accuracy: 89.44%
# Computed 1999/3750 batches - Avg Loss: 4.92864 | Avg Accuracy: 89.44%
# Computed 2499/3750 batches - Avg Loss: 4.91077 | Avg Accuracy: 89.54%
# Computed 2999/3750 batches - Avg Loss: 4.89691 | Avg Accuracy: 89.58%
# Computed 3499/3750 batches - Avg Loss: 4.88583 | Avg Accuracy: 89.52%
#
# End of EPOCH 3 - Avg Loss: 4.87832 | Avg Accuracy: 89.52%
# Training time: 6206.707 seconds.
#
# #Parameters after epoch EPOCH 3: 39180848
# #FLOPS after epoch EPOCH 3: 14272978944
# ********************
#
# ********************
# EPOCH 4
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 4.75617 | Avg Accuracy: 90.72%
# Computed 999/3750 batches - Avg Loss: 4.74541 | Avg Accuracy: 90.57%
# Computed 1499/3750 batches - Avg Loss: 4.73599 | Avg Accuracy: 90.57%
# Computed 1999/3750 batches - Avg Loss: 4.73272 | Avg Accuracy: 90.48%
# Computed 2499/3750 batches - Avg Loss: 4.72322 | Avg Accuracy: 90.53%
# Computed 2999/3750 batches - Avg Loss: 4.71801 | Avg Accuracy: 90.51%
# Computed 3499/3750 batches - Avg Loss: 4.71025 | Avg Accuracy: 90.55%
#
# End of EPOCH 4 - Avg Loss: 4.70485 | Avg Accuracy: 90.55%
# Training time: 6290.550 seconds.
#
# #Parameters after epoch EPOCH 4: 38283812
# #FLOPS after epoch EPOCH 4: 14250912768
# ********************
#
# Total training time (on cuda): 31593.483 seconds.
# Avg training time (on cuda): 10531.161 seconds.

# %%
# Check the results of optimization
optim_params = SuperNet_duccio.get_cost('#Parameters').item()
optim_flops = SuperNet_duccio.get_cost('#FLOPS').item()

print(f'#Parameters went from {int(initial_params)} to {int(optim_params)} -> {((1 - (optim_params/initial_params))*100):.2f}% fewer parameters.')
print(f'#FLOPS went from {int(initial_flops)} to {int(optim_flops)} -> {((1 - (optim_flops/initial_flops))*100):.2f}% fewer FLOPS.')
# Out:
# #Parameters went from 76264656 to 38283812 -> 49.80% fewer parameters.
# #FLOPS went from 14518124544 to 14250912768 -> 1.84% fewer FLOPS.

# %%
# Convert the model to PyTorch vanilla and save it
SuperNet_duccio_exported = SuperNet_duccio.export()
torch.save(SuperNet_duccio_exported, './Models_checkpoints/notMNIST/VGG16_notMNIST_SuperNet_duccio.pth')

# %%
SuperNet_duccio_exported
# Out:
# VGG(
#   (features): Module(
#     (sn_branches): Module(
#       (3): Module(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Module(
#     (sn_branches): Module(
#       (3): Module(
#         (0): Linear(in_features=25088, out_features=1024, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=1024, out_features=10, bias=True)
#       )
#     )
#   )
# )

# %% [markdown]
# #### **LIMITATION**
#
# For the same reason as standard SuperNet, also in this case only the architecture is exported rather than the whole trained model. Thus, further training is required!

# %%
# Setup loss_fn and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(SuperNet_duccio_exported.parameters(), lr=0.001)

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train the model with SuperNet optimization
SuperNet_exported_results = utils.train_model(
    model=SuperNet_duccio_exported,
    data_loader=train_dataloader,
    device=device,
    loss_fn=loss_fn,
    optimizer=optimizer
)

print(f"Total training time (on {SuperNet_exported_results['device']}): {SuperNet_exported_results['total_time']:.3f} seconds.")
print(f"Avg training time (on {SuperNet_exported_results['device']}): {(SuperNet_exported_results['total_time']/3):.3f} seconds.")
# Out:
# ********************
# EPOCH 0
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 2.30726 | Avg Accuracy: 9.68%
# Computed 999/3750 batches - Avg Loss: 2.30452 | Avg Accuracy: 10.11%
# Computed 1499/3750 batches - Avg Loss: 2.30335 | Avg Accuracy: 10.36%
# Computed 1999/3750 batches - Avg Loss: 2.30239 | Avg Accuracy: 10.79%
# Computed 2499/3750 batches - Avg Loss: 2.30110 | Avg Accuracy: 11.75%
# Computed 2999/3750 batches - Avg Loss: 2.29538 | Avg Accuracy: 13.67%
# Computed 3499/3750 batches - Avg Loss: 2.14441 | Avg Accuracy: 20.63%
#
# End of EPOCH 0 - Avg Loss: 2.05720 | Avg Accuracy: 24.31%
# Training time: 814.751 seconds.
# ********************
#
# ********************
# EPOCH 1
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.71170 | Avg Accuracy: 80.52%
# Computed 999/3750 batches - Avg Loss: 0.67000 | Avg Accuracy: 81.25%
# Computed 1499/3750 batches - Avg Loss: 0.62805 | Avg Accuracy: 82.17%
# Computed 1999/3750 batches - Avg Loss: 0.60117 | Avg Accuracy: 82.75%
# Computed 2499/3750 batches - Avg Loss: 0.57983 | Avg Accuracy: 83.24%
# Computed 2999/3750 batches - Avg Loss: 0.56245 | Avg Accuracy: 83.79%
# Computed 3499/3750 batches - Avg Loss: 0.54501 | Avg Accuracy: 84.24%
#
# End of EPOCH 1 - Avg Loss: 0.53754 | Avg Accuracy: 84.41%
# Training time: 696.249 seconds.
# ********************
#
# ********************
# EPOCH 2
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.41908 | Avg Accuracy: 88.01%
# Computed 999/3750 batches - Avg Loss: 0.41514 | Avg Accuracy: 87.87%
# Computed 1499/3750 batches - Avg Loss: 0.41546 | Avg Accuracy: 87.89%
# Computed 1999/3750 batches - Avg Loss: 0.41070 | Avg Accuracy: 87.95%
# Computed 2499/3750 batches - Avg Loss: 0.40764 | Avg Accuracy: 88.02%
# Computed 2999/3750 batches - Avg Loss: 0.40351 | Avg Accuracy: 88.16%
# Computed 3499/3750 batches - Avg Loss: 0.39949 | Avg Accuracy: 88.28%
#
# End of EPOCH 2 - Avg Loss: 0.39873 | Avg Accuracy: 88.28%
# Training time: 658.459 seconds.
# ********************
#
# ********************
# EPOCH 3
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.35308 | Avg Accuracy: 89.45%
# Computed 999/3750 batches - Avg Loss: 0.36090 | Avg Accuracy: 89.39%
# Computed 1499/3750 batches - Avg Loss: 0.35390 | Avg Accuracy: 89.55%
# Computed 1999/3750 batches - Avg Loss: 0.35124 | Avg Accuracy: 89.56%
# Computed 2499/3750 batches - Avg Loss: 0.35033 | Avg Accuracy: 89.62%
# Computed 2999/3750 batches - Avg Loss: 0.35019 | Avg Accuracy: 89.62%
# Computed 3499/3750 batches - Avg Loss: 0.35080 | Avg Accuracy: 89.59%
#
# End of EPOCH 3 - Avg Loss: 0.35112 | Avg Accuracy: 89.53%
# Training time: 671.569 seconds.
# ********************
#
# ********************
# EPOCH 4
#   0%|          | 0/3750 [00:00<?, ?batch/s]
# Computed 499/3750 batches - Avg Loss: 0.32573 | Avg Accuracy: 90.61%
# Computed 999/3750 batches - Avg Loss: 0.32453 | Avg Accuracy: 90.35%
# Computed 1499/3750 batches - Avg Loss: 0.32307 | Avg Accuracy: 90.30%
# Computed 1999/3750 batches - Avg Loss: 0.32688 | Avg Accuracy: 90.21%
# Computed 2499/3750 batches - Avg Loss: 0.32444 | Avg Accuracy: 90.26%
# Computed 2999/3750 batches - Avg Loss: 0.32525 | Avg Accuracy: 90.27%
# Computed 3499/3750 batches - Avg Loss: 0.32235 | Avg Accuracy: 90.34%
#
# End of EPOCH 4 - Avg Loss: 0.32185 | Avg Accuracy: 90.34%
# Training time: 672.943 seconds.
# ********************
#
# Total training time (on cuda): 3513.970 seconds.
# Avg training time (on cuda): 1171.323 seconds.

# %%
# Save the actually trained model
torch.save(SuperNet_duccio_exported, './Models_checkpoints/notMNIST/VGG16_notMNIST_SuperNet_duccio.pth')

# %% [markdown]
# # 4. Evaluation (models comparison)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
# Setup loss function
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# ## 4.1 Standard VGG16

# %%
# Model
standard_model = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_NoOpt.pth')

# Results
size_mb_baseline = utils.model_size(model=standard_model)
standard_model_results = utils.evaluate_model(model=standard_model, device=device, loss_fn=loss_fn, data_loader=test_dataloader)

print(f'''Standard VGG16 Inference Results (on {standard_model_results['device']}):
    - Model size: {size_mb_baseline:.3f} MB
    - Total inference time: {standard_model_results['total_inference_time']:.3f} seconds
    - Inference time per batch: {standard_model_results['avg_inference_time']:.3f} milliseconds
    - Minimum inference time: {standard_model_results['min_inference_time']:.3f} milliseconds
    - Average loss: {standard_model_results['avg_loss']:.5f}
    - Average accuracy: {(standard_model_results['avg_acc']*100):.2f}%''')
# Out:
# Standard VGG16 Inference Results (on cuda):
#     - Model size: 512.315 MB
#     - Total inference time: 3.350 seconds
#     - Inference time per batch: 5.361 milliseconds
#     - Minimum inference time: 3.111 milliseconds
#     - Average loss: 0.30265
#     - Average accuracy: 91.90%

# %% [markdown]
# ## 4.2 VGG16 with PIT optimization

# %%
# Model
PIT_model = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_PIT.pth')

# Results
size_mb = utils.model_size(model=PIT_model)
PIT_model_results = utils.evaluate_model(model=PIT_model, device=device, loss_fn=loss_fn, data_loader=test_dataloader)

# Compare the results with the standard model
size_ratio = size_mb / size_mb_baseline

print(f'''PIT optimization Results (on {PIT_model_results['device']}):
    - Model size: {size_mb:.3f} MB -> {((1 - size_ratio)*100):.2f}% lighter than baseline
    - Total inference time: {PIT_model_results['total_inference_time']:.3f} milliseconds
    - Inference time per batch: {PIT_model_results['avg_inference_time']:.3f} milliseconds
    - Minimum inference time: {PIT_model_results['min_inference_time']:.3f} seconds
    - Average loss: {PIT_model_results['avg_loss']:.5f}
    - Average accuracy: {(PIT_model_results['avg_acc']*100):.2f}%''')
# Out:
# PIT optimization Results (on cuda):
#     - Model size: 112.096 MB -> 78.12% lighter than baseline
#     - Total inference time: 3.585 milliseconds
#     - Inference time per batch: 5.736 milliseconds
#     - Minimum inference time: 3.219 seconds
#     - Average loss: 0.32679
#     - Average accuracy: 91.03%

# %%
PIT_model
# Out:
# GraphModule(
#   (features): Module(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Module(
#     (0): Linear(in_features=49, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## 4.3 VGG16 with PIT-DUCCIO optimization

# %%
# Model
PIT_duccio_model = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_PIT_duccio.pth')

# Results
size_mb = utils.model_size(model=PIT_duccio_model)
PIT_duccio_model_results = utils.evaluate_model(model=PIT_duccio_model, device=device, loss_fn=loss_fn, data_loader=test_dataloader)

# Compare the results with the standard model
size_ratio = size_mb / size_mb_baseline

print(f'''PIT-DUCCIO optimization Results (on {PIT_duccio_model_results['device']}):
    - Model size: {size_mb:.3f} MB -> {((1 - size_ratio)*100):.2f}% lighter than baseline
    - Total inference time: {PIT_duccio_model_results['total_inference_time']:.3f} seconds
    - Inference time per batch: {PIT_duccio_model_results['avg_inference_time']:.3f} milliseconds
    - Minimum inference time: {PIT_duccio_model_results['min_inference_time']:.3f} milliseconds
    - Average loss: {PIT_duccio_model_results['avg_loss']:.5f}
    - Average accuracy: {(PIT_duccio_model_results['avg_acc']*100):.2f} %''')
# Out:
# PIT-DUCCIO optimization Results (on cuda):
#     - Model size: 112.096 MB -> 78.12% lighter than baseline
#     - Total inference time: 3.514 seconds
#     - Inference time per batch: 5.622 milliseconds
#     - Minimum inference time: 3.621 milliseconds
#     - Average loss: 0.32980
#     - Average accuracy: 90.71 %

# %%
PIT_duccio_model
# Out:
# GraphModule(
#   (features): Module(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Module(
#     (0): Linear(in_features=49, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## 4.4 VGG16 with MPS optimization

# %%
# Model
MPS_model = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_MPS.pth')

# Results
size_mb = utils.model_size(model=MPS_model)
MPS_model_results = utils.evaluate_model(model=MPS_model, device=device, loss_fn=loss_fn, data_loader=test_dataloader)

# Compare the results with the standard model
size_ratio = size_mb / size_mb_baseline

print(f'''MPS optimization Results (on {MPS_model_results['device']}):
    - Model size: {size_mb:.3f} MB -> {((1 - size_ratio)*100):.2f}% lighter than baseline
    - Total inference time: {MPS_model_results['total_inference_time']:.3f} seconds
    - Inference time per batch: {MPS_model_results['avg_inference_time']:.3f} milliseconds
    - Minimum inference time: {MPS_model_results['min_inference_time']:.3f} milliseconds
    - Average loss: {MPS_model_results['avg_loss']:.5f}
    - Average accuracy: {(MPS_model_results['avg_acc']*100):.2f} %''')
# Out:
# MPS optimization Results (on cuda):
#     - Model size: 512.315 MB -> -0.00% lighter than baseline
#     - Total inference time: 89.227 seconds
#     - Inference time per batch: 142.763 milliseconds
#     - Minimum inference time: 138.362 milliseconds
#     - Average loss: 0.29953
#     - Average accuracy: 91.77 %

# %%
MPS_model
# Out:
# GraphModule(
#   (x_input_quantizer): QuantIdentity(
#     (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#     tensor([1.0000], requires_grad=True), scale_factor=1.525908737676218e-05)
#   )
#   (features): Module(
#     (0): QuantConv2d(
#       1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([1.0000], requires_grad=True), scale_factor=1.525908737676218e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([9.8637e-06, 9.2523e-06, 8.0300e-06, 1.0050e-05, 9.7473e-06, 1.0070e-05,
#               8.0587e-06, 9.0606e-06, 1.0080e-05, 7.6590e-06, 9.3060e-06, 9.8430e-06,
#               1.0169e-05, 8.9510e-06, 8.8078e-06, 1.0316e-05, 9.2752e-06, 8.9917e-06,
#               8.9649e-06, 9.5770e-06, 5.4544e-06, 8.7355e-06, 9.3221e-06, 9.8708e-06,
#               1.0120e-05, 1.0087e-05, 9.5150e-06, 7.4623e-06, 9.6912e-06, 9.5698e-06,
#               1.0060e-05, 1.0125e-05, 9.9214e-06, 8.7803e-06, 1.0076e-05, 1.0303e-05,
#               1.0039e-05, 8.3540e-06, 9.8038e-06, 9.9331e-06, 9.5043e-06, 9.2862e-06,
#               9.3231e-06, 7.2879e-06, 8.2571e-06, 9.7042e-06, 7.6260e-06, 9.3808e-06,
#               8.1015e-06, 9.9154e-06, 1.0035e-05, 8.4654e-06, 1.0101e-05, 6.8920e-06,
#               1.0228e-05, 9.4069e-06, 9.5032e-06, 9.8230e-06, 8.3646e-06, 9.6602e-06,
#               9.7490e-06, 6.8981e-06, 1.0035e-05, 1.0029e-05], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([1.5051e-10, 1.4118e-10, 1.2253e-10, 1.5336e-10, 1.4873e-10, 1.5366e-10,
#               1.2297e-10, 1.3826e-10, 1.5381e-10, 1.1687e-10, 1.4200e-10, 1.5020e-10,
#               1.5517e-10, 1.3658e-10, 1.3440e-10, 1.5742e-10, 1.4153e-10, 1.3720e-10,
#               1.3680e-10, 1.4614e-10, 8.3229e-11, 1.3330e-10, 1.4225e-10, 1.5062e-10,
#               1.5442e-10, 1.5392e-10, 1.4519e-10, 1.1387e-10, 1.4788e-10, 1.4603e-10,
#               1.5351e-10, 1.5450e-10, 1.5139e-10, 1.3398e-10, 1.5375e-10, 1.5722e-10,
#               1.5319e-10, 1.2748e-10, 1.4960e-10, 1.5157e-10, 1.4503e-10, 1.4170e-10,
#               1.4226e-10, 1.1121e-10, 1.2600e-10, 1.4808e-10, 1.1637e-10, 1.4314e-10,
#               1.2362e-10, 1.5130e-10, 1.5313e-10, 1.2917e-10, 1.5413e-10, 1.0517e-10,
#               1.5607e-10, 1.4354e-10, 1.4501e-10, 1.4989e-10, 1.2764e-10, 1.4741e-10,
#               1.4876e-10, 1.0526e-10, 1.5312e-10, 1.5303e-10], device='cuda:0'))
#     )
#     (1): ReLU(inplace=True)
#     (2): QuantConv2d(
#       64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([5.9194e-06, 5.8211e-06, 7.3598e-06, 5.9381e-06, 5.4656e-06, 6.2827e-06,
#               6.7580e-06, 6.1793e-06, 6.0249e-06, 6.5032e-06, 5.8777e-06, 5.6153e-06,
#               4.9717e-06, 6.5858e-06, 5.9579e-06, 6.0179e-06, 4.9314e-06, 5.8628e-06,
#               6.0969e-06, 6.3826e-06, 5.8008e-06, 6.4739e-06, 5.3267e-06, 5.8650e-06,
#               5.4325e-06, 5.4553e-06, 5.4516e-06, 5.1550e-06, 6.1554e-06, 5.7195e-06,
#               6.9695e-06, 5.8450e-06, 5.9219e-06, 5.1235e-06, 5.9796e-06, 6.0345e-06,
#               5.6518e-06, 5.9031e-06, 6.0892e-06, 6.3667e-06, 4.9563e-06, 6.7678e-06,
#               5.9577e-06, 5.8609e-06, 5.0943e-06, 5.4054e-06, 5.8335e-06, 6.2672e-06,
#               6.3939e-06, 6.6509e-06, 5.7024e-06, 6.2055e-06, 4.9175e-06, 6.1094e-06,
#               5.4898e-06, 5.6286e-06, 5.9235e-06, 5.5806e-06, 5.0860e-06, 6.2595e-06,
#               5.8662e-06, 6.7708e-06, 6.1332e-06, 5.1247e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([5.4194e-10, 5.3294e-10, 6.7382e-10, 5.4366e-10, 5.0040e-10, 5.7521e-10,
#               6.1873e-10, 5.6574e-10, 5.5160e-10, 5.9540e-10, 5.3813e-10, 5.1410e-10,
#               4.5518e-10, 6.0296e-10, 5.4547e-10, 5.5097e-10, 4.5149e-10, 5.3676e-10,
#               5.5819e-10, 5.8435e-10, 5.3108e-10, 5.9271e-10, 4.8768e-10, 5.3696e-10,
#               4.9737e-10, 4.9946e-10, 4.9912e-10, 4.7196e-10, 5.6355e-10, 5.2365e-10,
#               6.3809e-10, 5.3513e-10, 5.4218e-10, 4.6908e-10, 5.4746e-10, 5.5248e-10,
#               5.1744e-10, 5.4046e-10, 5.5749e-10, 5.8290e-10, 4.5377e-10, 6.1962e-10,
#               5.4545e-10, 5.3659e-10, 4.6641e-10, 4.9489e-10, 5.3408e-10, 5.7379e-10,
#               5.8539e-10, 6.0892e-10, 5.2208e-10, 5.6814e-10, 4.5021e-10, 5.5934e-10,
#               5.0261e-10, 5.1532e-10, 5.4233e-10, 5.1092e-10, 4.6565e-10, 5.7308e-10,
#               5.3708e-10, 6.1990e-10, 5.6152e-10, 4.6919e-10], device='cuda:0'))
#     )
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): QuantConv2d(
#       64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([4.4725e-06, 3.4540e-06, 3.6406e-06, 4.3915e-06, 4.0882e-06, 3.6660e-06,
#               4.2775e-06, 4.1260e-06, 3.9518e-06, 5.2054e-06, 5.0116e-06, 4.0356e-06,
#               4.0475e-06, 4.6874e-06, 4.3058e-06, 3.6413e-06, 5.3130e-06, 4.2902e-06,
#               4.7392e-06, 3.9871e-06, 3.4015e-06, 4.2186e-06, 4.2402e-06, 3.5517e-06,
#               4.0714e-06, 4.3595e-06, 4.5649e-06, 3.9573e-06, 4.6227e-06, 4.3401e-06,
#               4.5929e-06, 4.0914e-06, 4.2858e-06, 3.9711e-06, 4.8146e-06, 4.8191e-06,
#               4.4456e-06, 3.7601e-06, 5.3120e-06, 3.9374e-06, 4.0115e-06, 4.4192e-06,
#               4.4525e-06, 4.2873e-06, 4.3729e-06, 3.4052e-06, 3.7336e-06, 3.9811e-06,
#               5.0841e-06, 3.9419e-06, 3.9459e-06, 4.2743e-06, 4.6430e-06, 3.9618e-06,
#               3.7694e-06, 4.2726e-06, 4.7124e-06, 4.1731e-06, 4.9882e-06, 3.5422e-06,
#               4.2089e-06, 4.7299e-06, 3.8190e-06, 3.8210e-06, 4.0539e-06, 3.9879e-06,
#               4.0873e-06, 3.8502e-06, 4.2153e-06, 4.1670e-06, 4.1307e-06, 4.0710e-06,
#               4.3422e-06, 4.5157e-06, 4.3150e-06, 3.6633e-06, 4.7200e-06, 3.8319e-06,
#               4.1332e-06, 3.7293e-06, 4.1731e-06, 3.9183e-06, 3.7582e-06, 5.0503e-06,
#               3.5703e-06, 4.5665e-06, 4.9102e-06, 3.4916e-06, 3.9350e-06, 5.3689e-06,
#               5.0365e-06, 4.3198e-06, 4.0202e-06, 4.4896e-06, 4.3820e-06, 4.8325e-06,
#               4.3489e-06, 3.8724e-06, 5.3183e-06, 4.3073e-06, 4.5610e-06, 3.6112e-06,
#               3.7633e-06, 4.3833e-06, 4.2096e-06, 3.6551e-06, 3.8006e-06, 4.0177e-06,
#               3.6251e-06, 3.6677e-06, 4.5325e-06, 3.8402e-06, 4.1355e-06, 4.3471e-06,
#               3.8459e-06, 4.7088e-06, 4.7556e-06, 3.9427e-06, 4.8077e-06, 3.9401e-06,
#               3.8613e-06, 4.1678e-06, 3.8890e-06, 3.8349e-06, 5.0002e-06, 4.5013e-06,
#               3.9520e-06, 3.8157e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([4.0947e-10, 3.1623e-10, 3.3331e-10, 4.0206e-10, 3.7429e-10, 3.3564e-10,
#               3.9162e-10, 3.7775e-10, 3.6181e-10, 4.7657e-10, 4.5883e-10, 3.6947e-10,
#               3.7057e-10, 4.2915e-10, 3.9421e-10, 3.3337e-10, 4.8642e-10, 3.9279e-10,
#               4.3389e-10, 3.6503e-10, 3.1143e-10, 3.8623e-10, 3.8821e-10, 3.2517e-10,
#               3.7275e-10, 3.9913e-10, 4.1793e-10, 3.6231e-10, 4.2322e-10, 3.9735e-10,
#               4.2050e-10, 3.7459e-10, 3.9238e-10, 3.6357e-10, 4.4080e-10, 4.4121e-10,
#               4.0701e-10, 3.4425e-10, 4.8634e-10, 3.6049e-10, 3.6727e-10, 4.0460e-10,
#               4.0765e-10, 3.9252e-10, 4.0036e-10, 3.1176e-10, 3.4183e-10, 3.6449e-10,
#               4.6547e-10, 3.6090e-10, 3.6126e-10, 3.9133e-10, 4.2509e-10, 3.6271e-10,
#               3.4510e-10, 3.9118e-10, 4.3144e-10, 3.8207e-10, 4.5669e-10, 3.2430e-10,
#               3.8534e-10, 4.3304e-10, 3.4965e-10, 3.4983e-10, 3.7115e-10, 3.6511e-10,
#               3.7421e-10, 3.5250e-10, 3.8592e-10, 3.8151e-10, 3.7818e-10, 3.7271e-10,
#               3.9755e-10, 4.1343e-10, 3.9505e-10, 3.3539e-10, 4.3213e-10, 3.5083e-10,
#               3.7842e-10, 3.4143e-10, 3.8206e-10, 3.5874e-10, 3.4408e-10, 4.6237e-10,
#               3.2687e-10, 4.1808e-10, 4.4955e-10, 3.1967e-10, 3.6026e-10, 4.9155e-10,
#               4.6111e-10, 3.9550e-10, 3.6807e-10, 4.1104e-10, 4.0119e-10, 4.4244e-10,
#               3.9816e-10, 3.5454e-10, 4.8692e-10, 3.9435e-10, 4.1757e-10, 3.3062e-10,
#               3.4455e-10, 4.0131e-10, 3.8541e-10, 3.3464e-10, 3.4796e-10, 3.6783e-10,
#               3.3190e-10, 3.3579e-10, 4.1497e-10, 3.5159e-10, 3.7862e-10, 3.9799e-10,
#               3.5211e-10, 4.3111e-10, 4.3539e-10, 3.6097e-10, 4.4016e-10, 3.6073e-10,
#               3.5351e-10, 3.8158e-10, 3.5605e-10, 3.5110e-10, 4.5779e-10, 4.1211e-10,
#               3.6182e-10, 3.4934e-10], device='cuda:0'))
#     )
#     (6): ReLU(inplace=True)
#     (7): QuantConv2d(
#       128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([4.5378e-06, 4.0342e-06, 4.3788e-06, 4.0474e-06, 4.6579e-06, 4.3932e-06,
#               3.9546e-06, 3.8103e-06, 4.6554e-06, 4.0692e-06, 4.4959e-06, 4.1553e-06,
#               3.9731e-06, 5.3819e-06, 4.2331e-06, 3.9483e-06, 4.4862e-06, 4.1000e-06,
#               3.8887e-06, 4.1408e-06, 4.8342e-06, 4.8411e-06, 4.0201e-06, 4.2024e-06,
#               4.0789e-06, 4.6114e-06, 4.4294e-06, 4.3078e-06, 3.8302e-06, 4.0000e-06,
#               4.0106e-06, 4.2999e-06, 4.1257e-06, 5.1729e-06, 4.4410e-06, 4.2937e-06,
#               4.7233e-06, 4.4177e-06, 4.9801e-06, 4.1466e-06, 4.2844e-06, 4.4293e-06,
#               3.7786e-06, 4.4364e-06, 3.9245e-06, 4.4798e-06, 3.9007e-06, 3.9876e-06,
#               4.6227e-06, 5.7849e-06, 4.1942e-06, 3.8028e-06, 5.0606e-06, 3.9505e-06,
#               4.6153e-06, 5.3645e-06, 4.0911e-06, 4.1665e-06, 4.8923e-06, 4.1013e-06,
#               4.1389e-06, 4.6086e-06, 4.1559e-06, 5.0408e-06, 3.8885e-06, 4.4608e-06,
#               4.3869e-06, 5.4165e-06, 4.7491e-06, 4.0912e-06, 4.6481e-06, 4.3045e-06,
#               4.8759e-06, 4.3548e-06, 4.6209e-06, 4.5471e-06, 4.8853e-06, 4.1189e-06,
#               4.1654e-06, 4.0913e-06, 6.0849e-06, 4.6220e-06, 4.9973e-06, 4.4200e-06,
#               4.7737e-06, 5.1693e-06, 4.2528e-06, 4.7415e-06, 4.0249e-06, 4.1556e-06,
#               4.1572e-06, 3.9442e-06, 4.4865e-06, 4.1765e-06, 4.4931e-06, 3.9195e-06,
#               4.1845e-06, 4.7695e-06, 4.1999e-06, 3.3272e-06, 4.0422e-06, 4.3538e-06,
#               4.2241e-06, 4.6949e-06, 4.3220e-06, 4.8847e-06, 4.7203e-06, 5.1655e-06,
#               4.3855e-06, 4.1274e-06, 4.2699e-06, 4.7686e-06, 4.2068e-06, 4.1436e-06,
#               4.4133e-06, 4.2544e-06, 4.5562e-06, 5.0180e-06, 4.4487e-06, 4.0114e-06,
#               4.9651e-06, 4.4238e-06, 4.6059e-06, 3.9483e-06, 4.5419e-06, 5.2056e-06,
#               4.8679e-06, 4.2008e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([4.1546e-10, 3.6935e-10, 4.0090e-10, 3.7056e-10, 4.2645e-10, 4.0222e-10,
#               3.6206e-10, 3.4885e-10, 4.2622e-10, 3.7255e-10, 4.1162e-10, 3.8043e-10,
#               3.6375e-10, 4.9273e-10, 3.8756e-10, 3.6148e-10, 4.1073e-10, 3.7537e-10,
#               3.5603e-10, 3.7911e-10, 4.4259e-10, 4.4322e-10, 3.6806e-10, 3.8474e-10,
#               3.7344e-10, 4.2219e-10, 4.0553e-10, 3.9440e-10, 3.5067e-10, 3.6622e-10,
#               3.6718e-10, 3.9367e-10, 3.7773e-10, 4.7360e-10, 4.0659e-10, 3.9311e-10,
#               4.3244e-10, 4.0446e-10, 4.5595e-10, 3.7964e-10, 3.9226e-10, 4.0552e-10,
#               3.4595e-10, 4.0617e-10, 3.5931e-10, 4.1014e-10, 3.5713e-10, 3.6508e-10,
#               4.2323e-10, 5.2963e-10, 3.8400e-10, 3.4817e-10, 4.6332e-10, 3.6169e-10,
#               4.2255e-10, 4.9114e-10, 3.7455e-10, 3.8146e-10, 4.4791e-10, 3.7549e-10,
#               3.7893e-10, 4.2193e-10, 3.8049e-10, 4.6151e-10, 3.5601e-10, 4.0841e-10,
#               4.0164e-10, 4.9591e-10, 4.3480e-10, 3.7457e-10, 4.2555e-10, 3.9410e-10,
#               4.4641e-10, 3.9870e-10, 4.2307e-10, 4.1630e-10, 4.4727e-10, 3.7710e-10,
#               3.8136e-10, 3.7457e-10, 5.5710e-10, 4.2317e-10, 4.5752e-10, 4.0467e-10,
#               4.3705e-10, 4.7327e-10, 3.8936e-10, 4.3410e-10, 3.6849e-10, 3.8047e-10,
#               3.8061e-10, 3.6111e-10, 4.1076e-10, 3.8238e-10, 4.1136e-10, 3.5884e-10,
#               3.8311e-10, 4.3666e-10, 3.8452e-10, 3.0462e-10, 3.7008e-10, 3.9861e-10,
#               3.8673e-10, 4.2984e-10, 3.9570e-10, 4.4722e-10, 4.3217e-10, 4.7292e-10,
#               4.0151e-10, 3.7788e-10, 3.9093e-10, 4.3658e-10, 3.8515e-10, 3.7936e-10,
#               4.0405e-10, 3.8950e-10, 4.1713e-10, 4.5942e-10, 4.0730e-10, 3.6726e-10,
#               4.5458e-10, 4.0502e-10, 4.2169e-10, 3.6148e-10, 4.1583e-10, 4.7659e-10,
#               4.4567e-10, 3.8460e-10], device='cuda:0'))
#     )
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): QuantConv2d(
#       128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([3.4312e-06, 3.0423e-06, 2.9862e-06, 3.3037e-06, 3.0946e-06, 3.1827e-06,
#               2.6641e-06, 2.7613e-06, 3.1504e-06, 3.2920e-06, 3.7545e-06, 3.2203e-06,
#               2.9135e-06, 3.2822e-06, 3.1509e-06, 3.2705e-06, 2.9648e-06, 3.5323e-06,
#               3.5031e-06, 2.8192e-06, 3.1679e-06, 2.8015e-06, 3.2838e-06, 3.4825e-06,
#               2.7373e-06, 2.9041e-06, 2.8318e-06, 3.1192e-06, 3.0789e-06, 3.3372e-06,
#               3.2866e-06, 2.6893e-06, 3.1892e-06, 3.0934e-06, 2.8287e-06, 3.4115e-06,
#               3.2363e-06, 3.3968e-06, 2.6937e-06, 4.1110e-06, 2.6674e-06, 2.9059e-06,
#               3.5160e-06, 2.9117e-06, 3.0089e-06, 3.4309e-06, 2.7332e-06, 3.2847e-06,
#               3.3531e-06, 3.0442e-06, 3.0461e-06, 3.3085e-06, 3.4747e-06, 3.2245e-06,
#               3.1334e-06, 3.2002e-06, 3.4175e-06, 3.0157e-06, 3.2602e-06, 2.7680e-06,
#               3.5195e-06, 2.7169e-06, 3.1381e-06, 3.3629e-06, 3.3153e-06, 3.5320e-06,
#               2.9642e-06, 3.0652e-06, 3.4338e-06, 3.1153e-06, 3.4530e-06, 2.7473e-06,
#               3.0457e-06, 2.9633e-06, 3.0381e-06, 3.0972e-06, 3.1138e-06, 2.8584e-06,
#               3.0108e-06, 3.2683e-06, 3.5816e-06, 2.6609e-06, 2.9531e-06, 2.8927e-06,
#               3.0116e-06, 3.2842e-06, 3.3669e-06, 3.1165e-06, 3.1679e-06, 3.1729e-06,
#               2.9268e-06, 3.1576e-06, 3.0193e-06, 2.8451e-06, 3.0306e-06, 3.6104e-06,
#               2.6985e-06, 4.3165e-06, 3.1627e-06, 3.7053e-06, 3.0407e-06, 3.3817e-06,
#               4.0135e-06, 2.7746e-06, 2.6559e-06, 3.2771e-06, 3.8363e-06, 2.6259e-06,
#               3.7507e-06, 2.8345e-06, 2.9651e-06, 3.3164e-06, 3.1643e-06, 3.7840e-06,
#               2.9168e-06, 3.1845e-06, 2.9757e-06, 3.1630e-06, 2.9196e-06, 2.8601e-06,
#               3.2252e-06, 3.6011e-06, 2.6523e-06, 3.4554e-06, 2.9050e-06, 3.7161e-06,
#               2.8857e-06, 2.9879e-06, 3.1059e-06, 3.5183e-06, 2.9414e-06, 2.9496e-06,
#               3.1828e-06, 3.4519e-06, 3.4434e-06, 2.9859e-06, 3.2954e-06, 3.0827e-06,
#               3.1997e-06, 3.8580e-06, 3.3235e-06, 3.1586e-06, 3.0281e-06, 3.5829e-06,
#               3.1675e-06, 3.1765e-06, 3.0896e-06, 3.5476e-06, 3.0635e-06, 3.1572e-06,
#               3.1684e-06, 3.6320e-06, 2.7240e-06, 3.1148e-06, 3.0724e-06, 2.8692e-06,
#               2.9801e-06, 3.3900e-06, 3.4515e-06, 4.1879e-06, 2.7781e-06, 3.2878e-06,
#               3.3167e-06, 2.9305e-06, 3.2181e-06, 3.1968e-06, 3.1829e-06, 2.7201e-06,
#               2.7195e-06, 3.9798e-06, 2.8916e-06, 3.1842e-06, 3.4470e-06, 3.1396e-06,
#               2.7903e-06, 3.6074e-06, 2.7374e-06, 3.0692e-06, 2.9927e-06, 3.0929e-06,
#               2.8483e-06, 3.2016e-06, 2.9105e-06, 3.1430e-06, 3.5815e-06, 3.2971e-06,
#               3.0459e-06, 2.9627e-06, 3.0407e-06, 2.7717e-06, 3.4373e-06, 4.3610e-06,
#               3.0229e-06, 4.0982e-06, 3.1090e-06, 3.8891e-06, 3.2523e-06, 3.4609e-06,
#               3.1555e-06, 2.9463e-06, 2.6849e-06, 3.3959e-06, 3.4543e-06, 3.0468e-06,
#               3.2112e-06, 3.1209e-06, 3.2231e-06, 3.1114e-06, 3.1341e-06, 3.1643e-06,
#               2.9293e-06, 3.0216e-06, 3.1159e-06, 3.0080e-06, 3.1904e-06, 3.1733e-06,
#               3.0280e-06, 3.9168e-06, 2.6222e-06, 3.1048e-06, 2.9087e-06, 2.7899e-06,
#               3.2396e-06, 3.1842e-06, 3.2169e-06, 3.3130e-06, 3.0614e-06, 2.7063e-06,
#               3.3222e-06, 2.9368e-06, 3.2225e-06, 2.9840e-06, 3.4231e-06, 3.4833e-06,
#               2.7281e-06, 3.9016e-06, 3.3759e-06, 2.7846e-06, 3.5099e-06, 3.2715e-06,
#               2.6610e-06, 2.9489e-06, 2.8060e-06, 2.7995e-06, 3.6626e-06, 3.4008e-06,
#               3.2471e-06, 3.5003e-06, 3.1730e-06, 2.9734e-06, 3.0780e-06, 2.8371e-06,
#               3.2974e-06, 3.0114e-06, 2.9220e-06, 3.0730e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([3.1414e-10, 2.7854e-10, 2.7340e-10, 3.0247e-10, 2.8332e-10, 2.9139e-10,
#               2.4391e-10, 2.5280e-10, 2.8844e-10, 3.0140e-10, 3.4374e-10, 2.9484e-10,
#               2.6674e-10, 3.0050e-10, 2.8848e-10, 2.9942e-10, 2.7144e-10, 3.2340e-10,
#               3.2072e-10, 2.5811e-10, 2.9004e-10, 2.5649e-10, 3.0064e-10, 3.1884e-10,
#               2.5061e-10, 2.6589e-10, 2.5926e-10, 2.8557e-10, 2.8189e-10, 3.0554e-10,
#               3.0090e-10, 2.4622e-10, 2.9198e-10, 2.8322e-10, 2.5898e-10, 3.1234e-10,
#               2.9630e-10, 3.1099e-10, 2.4662e-10, 3.7638e-10, 2.4421e-10, 2.6604e-10,
#               3.2191e-10, 2.6658e-10, 2.7548e-10, 3.1412e-10, 2.5024e-10, 3.0073e-10,
#               3.0699e-10, 2.7871e-10, 2.7888e-10, 3.0291e-10, 3.1813e-10, 2.9522e-10,
#               2.8687e-10, 2.9299e-10, 3.1288e-10, 2.7610e-10, 2.9849e-10, 2.5342e-10,
#               3.2222e-10, 2.4874e-10, 2.8730e-10, 3.0788e-10, 3.0353e-10, 3.2337e-10,
#               2.7138e-10, 2.8063e-10, 3.1438e-10, 2.8522e-10, 3.1613e-10, 2.5152e-10,
#               2.7885e-10, 2.7130e-10, 2.7815e-10, 2.8356e-10, 2.8508e-10, 2.6170e-10,
#               2.7565e-10, 2.9923e-10, 3.2791e-10, 2.4362e-10, 2.7037e-10, 2.6484e-10,
#               2.7572e-10, 3.0068e-10, 3.0826e-10, 2.8533e-10, 2.9004e-10, 2.9049e-10,
#               2.6796e-10, 2.8909e-10, 2.7643e-10, 2.6048e-10, 2.7747e-10, 3.3055e-10,
#               2.4706e-10, 3.9519e-10, 2.8956e-10, 3.3923e-10, 2.7839e-10, 3.0961e-10,
#               3.6746e-10, 2.5402e-10, 2.4316e-10, 3.0003e-10, 3.5123e-10, 2.4042e-10,
#               3.4339e-10, 2.5951e-10, 2.7147e-10, 3.0363e-10, 2.8970e-10, 3.4644e-10,
#               2.6705e-10, 2.9156e-10, 2.7244e-10, 2.8958e-10, 2.6730e-10, 2.6185e-10,
#               2.9528e-10, 3.2970e-10, 2.4283e-10, 3.1635e-10, 2.6597e-10, 3.4022e-10,
#               2.6420e-10, 2.7355e-10, 2.8436e-10, 3.2212e-10, 2.6929e-10, 2.7005e-10,
#               2.9140e-10, 3.1604e-10, 3.1525e-10, 2.7337e-10, 3.0171e-10, 2.8224e-10,
#               2.9295e-10, 3.5321e-10, 3.0428e-10, 2.8918e-10, 2.7723e-10, 3.2803e-10,
#               2.9000e-10, 2.9082e-10, 2.8287e-10, 3.2479e-10, 2.8048e-10, 2.8905e-10,
#               2.9008e-10, 3.3253e-10, 2.4939e-10, 2.8518e-10, 2.8129e-10, 2.6269e-10,
#               2.7284e-10, 3.1037e-10, 3.1600e-10, 3.8342e-10, 2.5434e-10, 3.0101e-10,
#               3.0366e-10, 2.6830e-10, 2.9463e-10, 2.9268e-10, 2.9141e-10, 2.4904e-10,
#               2.4898e-10, 3.6437e-10, 2.6473e-10, 2.9152e-10, 3.1559e-10, 2.8744e-10,
#               2.5546e-10, 3.3027e-10, 2.5062e-10, 2.8100e-10, 2.7399e-10, 2.8317e-10,
#               2.6077e-10, 2.9312e-10, 2.6647e-10, 2.8776e-10, 3.2791e-10, 3.0187e-10,
#               2.7886e-10, 2.7125e-10, 2.7839e-10, 2.5376e-10, 3.1470e-10, 3.9926e-10,
#               2.7676e-10, 3.7521e-10, 2.8464e-10, 3.5606e-10, 2.9776e-10, 3.1686e-10,
#               2.8890e-10, 2.6974e-10, 2.4581e-10, 3.1091e-10, 3.1625e-10, 2.7895e-10,
#               2.9400e-10, 2.8573e-10, 2.9509e-10, 2.8486e-10, 2.8694e-10, 2.8970e-10,
#               2.6819e-10, 2.7664e-10, 2.8527e-10, 2.7540e-10, 2.9210e-10, 2.9053e-10,
#               2.7722e-10, 3.5860e-10, 2.4008e-10, 2.8426e-10, 2.6630e-10, 2.5542e-10,
#               2.9660e-10, 2.9153e-10, 2.9452e-10, 3.0332e-10, 2.8029e-10, 2.4778e-10,
#               3.0416e-10, 2.6888e-10, 2.9503e-10, 2.7320e-10, 3.1340e-10, 3.1891e-10,
#               2.4977e-10, 3.5720e-10, 3.0908e-10, 2.5494e-10, 3.2135e-10, 2.9952e-10,
#               2.4363e-10, 2.6998e-10, 2.5690e-10, 2.5631e-10, 3.3533e-10, 3.1136e-10,
#               2.9728e-10, 3.2047e-10, 2.9050e-10, 2.7223e-10, 2.8180e-10, 2.5975e-10,
#               3.0189e-10, 2.7571e-10, 2.6752e-10, 2.8134e-10], device='cuda:0'))
#     )
#     (11): ReLU(inplace=True)
#     (12): QuantConv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.], requires_grad=True), scale_factor=9.155413135886192e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0007], requires_grad=True), scale_factor=9.156471060123295e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([3.1861e-06, 3.3484e-06, 3.6270e-06, 3.5296e-06, 3.0417e-06, 2.8602e-06,
#               3.2133e-06, 3.4838e-06, 3.3670e-06, 3.0231e-06, 3.4276e-06, 3.1864e-06,
#               3.3628e-06, 3.3704e-06, 3.3462e-06, 3.2142e-06, 3.6922e-06, 2.9871e-06,
#               2.9850e-06, 3.2062e-06, 3.1483e-06, 3.4310e-06, 3.2082e-06, 2.5784e-06,
#               3.4686e-06, 2.9784e-06, 3.0760e-06, 3.4573e-06, 3.4976e-06, 3.0710e-06,
#               2.9652e-06, 3.3549e-06, 3.2878e-06, 3.3225e-06, 3.1810e-06, 3.1489e-06,
#               3.6708e-06, 3.5202e-06, 3.2766e-06, 3.0403e-06, 3.1803e-06, 3.2012e-06,
#               2.9493e-06, 3.7339e-06, 2.8708e-06, 3.2826e-06, 3.3199e-06, 3.2092e-06,
#               3.2272e-06, 3.4709e-06, 3.2428e-06, 2.9040e-06, 3.0544e-06, 3.1467e-06,
#               3.3916e-06, 3.4058e-06, 3.2080e-06, 3.0323e-06, 2.9185e-06, 3.4937e-06,
#               3.1201e-06, 3.9485e-06, 2.9147e-06, 3.5673e-06, 3.7167e-06, 3.4541e-06,
#               3.2867e-06, 3.2966e-06, 2.9571e-06, 2.8989e-06, 3.1030e-06, 2.9981e-06,
#               3.7770e-06, 3.0551e-06, 3.0787e-06, 3.1049e-06, 3.1955e-06, 2.9307e-06,
#               3.2207e-06, 3.2397e-06, 3.6105e-06, 3.0002e-06, 3.0769e-06, 3.1237e-06,
#               3.4216e-06, 3.2182e-06, 2.9702e-06, 3.3118e-06, 2.7984e-06, 3.3192e-06,
#               2.9191e-06, 3.5825e-06, 3.0638e-06, 3.3703e-06, 3.7391e-06, 3.2626e-06,
#               2.9712e-06, 3.2132e-06, 2.8819e-06, 2.9755e-06, 3.1706e-06, 3.8363e-06,
#               3.2805e-06, 3.2506e-06, 3.1641e-06, 3.2690e-06, 3.6249e-06, 3.0752e-06,
#               3.3960e-06, 2.9116e-06, 3.5345e-06, 3.3423e-06, 3.7977e-06, 3.5037e-06,
#               3.0125e-06, 3.0966e-06, 3.1662e-06, 3.1701e-06, 4.0485e-06, 3.1078e-06,
#               3.4033e-06, 3.4850e-06, 3.1470e-06, 3.1201e-06, 3.8897e-06, 3.0921e-06,
#               2.9446e-06, 3.3857e-06, 3.6052e-06, 2.6908e-06, 2.7615e-06, 3.2414e-06,
#               3.0472e-06, 3.0659e-06, 3.6178e-06, 3.2523e-06, 3.2534e-06, 3.2657e-06,
#               3.0178e-06, 2.9555e-06, 3.1769e-06, 4.0153e-06, 3.0285e-06, 3.2902e-06,
#               3.6328e-06, 3.4069e-06, 3.2611e-06, 3.7955e-06, 3.6838e-06, 2.8803e-06,
#               3.6943e-06, 3.4952e-06, 3.0988e-06, 3.0515e-06, 3.3686e-06, 3.1912e-06,
#               2.9271e-06, 2.9312e-06, 3.3313e-06, 4.0613e-06, 3.1340e-06, 3.6547e-06,
#               2.9234e-06, 3.6923e-06, 3.2730e-06, 3.3050e-06, 2.8681e-06, 3.4725e-06,
#               3.0973e-06, 2.7814e-06, 3.0282e-06, 3.3915e-06, 3.0876e-06, 3.2622e-06,
#               3.2125e-06, 2.9853e-06, 3.1864e-06, 3.0011e-06, 3.1272e-06, 2.8097e-06,
#               3.4983e-06, 3.5326e-06, 3.3402e-06, 3.4461e-06, 3.1714e-06, 2.8525e-06,
#               3.3864e-06, 2.8898e-06, 3.3025e-06, 3.2913e-06, 2.9425e-06, 3.4292e-06,
#               3.2862e-06, 3.2187e-06, 3.5876e-06, 3.6114e-06, 3.2304e-06, 3.0747e-06,
#               2.9819e-06, 3.5055e-06, 3.4631e-06, 2.9262e-06, 3.0800e-06, 3.1178e-06,
#               2.8290e-06, 3.1830e-06, 2.9789e-06, 3.5861e-06, 2.9453e-06, 2.8880e-06,
#               3.4949e-06, 2.9088e-06, 3.1836e-06, 3.1949e-06, 3.1426e-06, 2.8440e-06,
#               3.4408e-06, 3.4013e-06, 3.1378e-06, 3.3810e-06, 2.8921e-06, 3.2545e-06,
#               3.1807e-06, 2.9408e-06, 2.9293e-06, 3.2116e-06, 3.8925e-06, 2.8914e-06,
#               3.3631e-06, 3.3834e-06, 3.4147e-06, 3.4486e-06, 3.3108e-06, 3.3015e-06,
#               2.9955e-06, 3.4824e-06, 2.9660e-06, 3.3310e-06, 3.2651e-06, 3.3408e-06,
#               3.1192e-06, 3.4995e-06, 3.6197e-06, 3.1392e-06, 3.5374e-06, 3.0572e-06,
#               3.2145e-06, 2.9246e-06, 3.1588e-06, 3.0244e-06, 3.4028e-06, 3.3432e-06,
#               2.8685e-06, 2.7805e-06, 3.2450e-06, 2.8238e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([2.9170e-10, 3.0656e-10, 3.3207e-10, 3.2315e-10, 2.7848e-10, 2.6186e-10,
#               2.9419e-10, 3.1895e-10, 3.0826e-10, 2.7677e-10, 3.1381e-10, 2.9173e-10,
#               3.0788e-10, 3.0857e-10, 3.0636e-10, 2.9427e-10, 3.3804e-10, 2.7348e-10,
#               2.7329e-10, 2.9354e-10, 2.8824e-10, 3.1412e-10, 2.9372e-10, 2.3606e-10,
#               3.1756e-10, 2.7268e-10, 2.8162e-10, 3.1653e-10, 3.2022e-10, 2.8116e-10,
#               2.7147e-10, 3.0715e-10, 3.0101e-10, 3.0419e-10, 2.9124e-10, 2.8830e-10,
#               3.3608e-10, 3.2229e-10, 2.9998e-10, 2.7836e-10, 2.9117e-10, 2.9308e-10,
#               2.7002e-10, 3.4186e-10, 2.6283e-10, 3.0054e-10, 3.0395e-10, 2.9381e-10,
#               2.9547e-10, 3.1778e-10, 2.9689e-10, 2.6588e-10, 2.7965e-10, 2.8809e-10,
#               3.1051e-10, 3.1182e-10, 2.9371e-10, 2.7762e-10, 2.6720e-10, 3.1987e-10,
#               2.8566e-10, 3.6150e-10, 2.6685e-10, 3.2660e-10, 3.4028e-10, 3.1624e-10,
#               3.0091e-10, 3.0182e-10, 2.7074e-10, 2.6541e-10, 2.8409e-10, 2.7449e-10,
#               3.4580e-10, 2.7971e-10, 2.8187e-10, 2.8427e-10, 2.9256e-10, 2.6832e-10,
#               2.9487e-10, 2.9661e-10, 3.3056e-10, 2.7468e-10, 2.8170e-10, 2.8599e-10,
#               3.1326e-10, 2.9464e-10, 2.7193e-10, 3.0321e-10, 2.5620e-10, 3.0389e-10,
#               2.6726e-10, 3.2799e-10, 2.8051e-10, 3.0857e-10, 3.4233e-10, 2.9871e-10,
#               2.7203e-10, 2.9418e-10, 2.6385e-10, 2.7242e-10, 2.9028e-10, 3.5123e-10,
#               3.0034e-10, 2.9761e-10, 2.8968e-10, 2.9929e-10, 3.3188e-10, 2.8155e-10,
#               3.1091e-10, 2.6656e-10, 3.2360e-10, 3.0600e-10, 3.4769e-10, 3.2078e-10,
#               2.7580e-10, 2.8351e-10, 2.8988e-10, 2.9023e-10, 3.7066e-10, 2.8453e-10,
#               3.1159e-10, 3.1906e-10, 2.8812e-10, 2.8566e-10, 3.5612e-10, 2.8309e-10,
#               2.6959e-10, 3.0998e-10, 3.3007e-10, 2.4636e-10, 2.5282e-10, 2.9677e-10,
#               2.7898e-10, 2.8069e-10, 3.3123e-10, 2.9776e-10, 2.9787e-10, 2.9899e-10,
#               2.7629e-10, 2.7059e-10, 2.9086e-10, 3.6762e-10, 2.7727e-10, 3.0123e-10,
#               3.3259e-10, 3.1192e-10, 2.9857e-10, 3.4749e-10, 3.3727e-10, 2.6370e-10,
#               3.3823e-10, 3.2000e-10, 2.8371e-10, 2.7938e-10, 3.0841e-10, 2.9217e-10,
#               2.6799e-10, 2.6836e-10, 3.0500e-10, 3.7183e-10, 2.8693e-10, 3.3461e-10,
#               2.6765e-10, 3.3805e-10, 2.9966e-10, 3.0258e-10, 2.6258e-10, 3.1792e-10,
#               2.8357e-10, 2.5465e-10, 2.7724e-10, 3.1051e-10, 2.8268e-10, 2.9866e-10,
#               2.9412e-10, 2.7332e-10, 2.9173e-10, 2.7477e-10, 2.8631e-10, 2.5724e-10,
#               3.2028e-10, 3.2343e-10, 3.0581e-10, 3.1551e-10, 2.9035e-10, 2.6116e-10,
#               3.1004e-10, 2.6457e-10, 3.0236e-10, 3.0133e-10, 2.6940e-10, 3.1396e-10,
#               3.0086e-10, 2.9469e-10, 3.2846e-10, 3.3064e-10, 2.9575e-10, 2.8151e-10,
#               2.7301e-10, 3.2095e-10, 3.1706e-10, 2.6790e-10, 2.8199e-10, 2.8545e-10,
#               2.5901e-10, 2.9141e-10, 2.7273e-10, 3.2833e-10, 2.6966e-10, 2.6441e-10,
#               3.1997e-10, 2.6631e-10, 2.9147e-10, 2.9251e-10, 2.8772e-10, 2.6038e-10,
#               3.1502e-10, 3.1140e-10, 2.8727e-10, 3.0955e-10, 2.6478e-10, 2.9797e-10,
#               2.9121e-10, 2.6924e-10, 2.6819e-10, 2.9403e-10, 3.5638e-10, 2.6472e-10,
#               3.0790e-10, 3.0977e-10, 3.1263e-10, 3.1574e-10, 3.0312e-10, 3.0227e-10,
#               2.7425e-10, 3.1883e-10, 2.7155e-10, 3.0497e-10, 2.9893e-10, 3.0586e-10,
#               2.8557e-10, 3.2040e-10, 3.3140e-10, 2.8741e-10, 3.2387e-10, 2.7990e-10,
#               2.9430e-10, 2.6776e-10, 2.8920e-10, 2.7690e-10, 3.1154e-10, 3.0608e-10,
#               2.6262e-10, 2.5457e-10, 2.9710e-10, 2.5853e-10], device='cuda:0'))
#     )
#     (13): ReLU(inplace=True)
#     (14): QuantConv2d(
#       256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0007], requires_grad=True), scale_factor=9.156471060123295e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0063], requires_grad=True), scale_factor=9.165062510874122e-05)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([2.9269e-06, 3.0665e-06, 3.3881e-06, 2.9632e-06, 4.2027e-06, 2.9224e-06,
#               3.2426e-06, 3.1937e-06, 3.8531e-06, 2.9057e-06, 3.7946e-06, 3.5325e-06,
#               3.3519e-06, 3.3103e-06, 3.7432e-06, 3.3098e-06, 2.8281e-06, 3.0314e-06,
#               2.9930e-06, 3.7415e-06, 3.3300e-06, 3.3890e-06, 2.9764e-06, 3.4176e-06,
#               2.9923e-06, 3.2012e-06, 3.6995e-06, 3.0725e-06, 3.2701e-06, 3.0092e-06,
#               3.4738e-06, 3.1457e-06, 3.4545e-06, 3.0453e-06, 3.1292e-06, 3.3376e-06,
#               2.9724e-06, 3.2024e-06, 3.4328e-06, 3.1690e-06, 3.0090e-06, 3.1892e-06,
#               2.8110e-06, 3.2321e-06, 3.5544e-06, 3.2279e-06, 3.0277e-06, 3.3753e-06,
#               3.0396e-06, 3.3876e-06, 3.4435e-06, 3.1190e-06, 2.8661e-06, 3.2664e-06,
#               3.4529e-06, 3.1018e-06, 3.5551e-06, 3.1484e-06, 3.3891e-06, 3.7735e-06,
#               3.0667e-06, 2.9075e-06, 3.1700e-06, 3.4080e-06, 3.0059e-06, 3.1776e-06,
#               3.5591e-06, 3.2378e-06, 3.3283e-06, 3.2818e-06, 3.5360e-06, 3.1728e-06,
#               3.2089e-06, 3.7041e-06, 3.7172e-06, 3.3174e-06, 3.3873e-06, 3.2818e-06,
#               3.5645e-06, 2.7712e-06, 3.9409e-06, 3.4919e-06, 3.2224e-06, 3.0915e-06,
#               2.9806e-06, 2.9593e-06, 3.1797e-06, 3.1246e-06, 3.3391e-06, 3.2222e-06,
#               3.3327e-06, 3.0892e-06, 3.4809e-06, 3.0543e-06, 2.9096e-06, 3.1919e-06,
#               3.5042e-06, 3.2451e-06, 3.1072e-06, 3.8197e-06, 3.3948e-06, 3.0356e-06,
#               3.2896e-06, 3.4115e-06, 3.0365e-06, 3.2733e-06, 3.6818e-06, 2.9796e-06,
#               3.7399e-06, 3.0371e-06, 3.2030e-06, 3.5176e-06, 3.0859e-06, 3.3119e-06,
#               3.0723e-06, 3.0361e-06, 2.9132e-06, 3.3875e-06, 3.6859e-06, 3.4171e-06,
#               3.0747e-06, 3.1131e-06, 3.6124e-06, 3.4013e-06, 3.5666e-06, 3.1927e-06,
#               3.3641e-06, 3.3758e-06, 4.4060e-06, 3.6246e-06, 3.5710e-06, 3.0639e-06,
#               3.0563e-06, 3.5308e-06, 2.8135e-06, 3.1588e-06, 3.0835e-06, 3.0450e-06,
#               3.3400e-06, 3.3935e-06, 3.6904e-06, 3.1147e-06, 3.1039e-06, 3.0932e-06,
#               3.2379e-06, 3.5500e-06, 3.5106e-06, 2.8989e-06, 2.9191e-06, 3.5038e-06,
#               3.2240e-06, 3.4382e-06, 3.3258e-06, 3.1688e-06, 3.2858e-06, 3.3895e-06,
#               3.4458e-06, 2.9129e-06, 3.1079e-06, 3.2381e-06, 3.1487e-06, 3.6135e-06,
#               3.0949e-06, 2.9829e-06, 3.1411e-06, 3.4917e-06, 2.9279e-06, 3.2661e-06,
#               3.1275e-06, 3.2733e-06, 2.9156e-06, 3.7129e-06, 3.1224e-06, 3.0696e-06,
#               3.1839e-06, 3.1280e-06, 3.0632e-06, 3.5166e-06, 2.8788e-06, 2.9499e-06,
#               3.2383e-06, 3.4701e-06, 3.5703e-06, 3.5372e-06, 3.0398e-06, 3.2698e-06,
#               2.7939e-06, 3.1118e-06, 3.2230e-06, 3.0921e-06, 2.9963e-06, 3.0714e-06,
#               3.9901e-06, 3.2097e-06, 3.2621e-06, 3.5329e-06, 2.9412e-06, 3.0029e-06,
#               3.4588e-06, 3.6077e-06, 3.4428e-06, 3.1023e-06, 3.4733e-06, 2.9709e-06,
#               2.9422e-06, 3.6717e-06, 3.0125e-06, 3.2139e-06, 3.3557e-06, 3.3111e-06,
#               2.9987e-06, 3.6203e-06, 3.2803e-06, 3.2443e-06, 3.5294e-06, 2.8984e-06,
#               3.4012e-06, 3.2444e-06, 3.7914e-06, 3.3133e-06, 3.6943e-06, 3.3858e-06,
#               3.3435e-06, 3.5305e-06, 3.8921e-06, 3.0962e-06, 3.5807e-06, 3.0678e-06,
#               3.6326e-06, 3.4354e-06, 3.1286e-06, 2.9983e-06, 3.3400e-06, 3.4239e-06,
#               3.3262e-06, 3.6154e-06, 3.6005e-06, 3.5845e-06, 3.4930e-06, 3.2231e-06,
#               3.1729e-06, 2.9430e-06, 3.5937e-06, 3.2096e-06, 3.0021e-06, 3.3623e-06,
#               3.0078e-06, 3.8951e-06, 3.0140e-06, 3.2795e-06, 3.3883e-06, 3.8357e-06,
#               3.0004e-06, 2.8895e-06, 3.0820e-06, 3.4653e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([2.6800e-10, 2.8078e-10, 3.1023e-10, 2.7132e-10, 3.8482e-10, 2.6759e-10,
#               2.9690e-10, 2.9243e-10, 3.5281e-10, 2.6606e-10, 3.4745e-10, 3.2345e-10,
#               3.0691e-10, 3.0311e-10, 3.4274e-10, 3.0306e-10, 2.5896e-10, 2.7757e-10,
#               2.7406e-10, 3.4259e-10, 3.0491e-10, 3.1031e-10, 2.7254e-10, 3.1293e-10,
#               2.7399e-10, 2.9312e-10, 3.3874e-10, 2.8133e-10, 2.9942e-10, 2.7554e-10,
#               3.1808e-10, 2.8804e-10, 3.1631e-10, 2.7884e-10, 2.8653e-10, 3.0561e-10,
#               2.7217e-10, 2.9323e-10, 3.1433e-10, 2.9017e-10, 2.7552e-10, 2.9202e-10,
#               2.5738e-10, 2.9594e-10, 3.2545e-10, 2.9556e-10, 2.7723e-10, 3.0906e-10,
#               2.7832e-10, 3.1018e-10, 3.1530e-10, 2.8559e-10, 2.6244e-10, 2.9908e-10,
#               3.1616e-10, 2.8402e-10, 3.2552e-10, 2.8828e-10, 3.1032e-10, 3.4552e-10,
#               2.8080e-10, 2.6623e-10, 2.9026e-10, 3.1205e-10, 2.7524e-10, 2.9096e-10,
#               3.2588e-10, 2.9647e-10, 3.0476e-10, 3.0050e-10, 3.2377e-10, 2.9051e-10,
#               2.9382e-10, 3.3916e-10, 3.4036e-10, 3.0376e-10, 3.1015e-10, 3.0049e-10,
#               3.2639e-10, 2.5375e-10, 3.6085e-10, 3.1973e-10, 2.9506e-10, 2.8307e-10,
#               2.7292e-10, 2.7097e-10, 2.9115e-10, 2.8610e-10, 3.0575e-10, 2.9504e-10,
#               3.0516e-10, 2.8286e-10, 3.1873e-10, 2.7967e-10, 2.6642e-10, 2.9226e-10,
#               3.2086e-10, 2.9714e-10, 2.8451e-10, 3.4975e-10, 3.1084e-10, 2.7795e-10,
#               3.0122e-10, 3.1237e-10, 2.7804e-10, 2.9972e-10, 3.3712e-10, 2.7283e-10,
#               3.4245e-10, 2.7809e-10, 2.9328e-10, 3.2209e-10, 2.8256e-10, 3.0325e-10,
#               2.8132e-10, 2.7800e-10, 2.6675e-10, 3.1018e-10, 3.3750e-10, 3.1289e-10,
#               2.8154e-10, 2.8505e-10, 3.3077e-10, 3.1144e-10, 3.2658e-10, 2.9234e-10,
#               3.0803e-10, 3.0911e-10, 4.0343e-10, 3.3189e-10, 3.2698e-10, 2.8055e-10,
#               2.7985e-10, 3.2330e-10, 2.5762e-10, 2.8924e-10, 2.8234e-10, 2.7882e-10,
#               3.0583e-10, 3.1073e-10, 3.3791e-10, 2.8520e-10, 2.8421e-10, 2.8323e-10,
#               2.9647e-10, 3.2506e-10, 3.2145e-10, 2.6544e-10, 2.6729e-10, 3.2083e-10,
#               2.9520e-10, 3.1482e-10, 3.0452e-10, 2.9015e-10, 3.0086e-10, 3.1036e-10,
#               3.1551e-10, 2.6672e-10, 2.8458e-10, 2.9649e-10, 2.8831e-10, 3.3087e-10,
#               2.8338e-10, 2.7313e-10, 2.8761e-10, 3.1972e-10, 2.6809e-10, 2.9906e-10,
#               2.8637e-10, 2.9972e-10, 2.6697e-10, 3.3997e-10, 2.8591e-10, 2.8107e-10,
#               2.9153e-10, 2.8642e-10, 2.8048e-10, 3.2200e-10, 2.6360e-10, 2.7011e-10,
#               2.9651e-10, 3.1774e-10, 3.2692e-10, 3.2389e-10, 2.7834e-10, 2.9940e-10,
#               2.5582e-10, 2.8493e-10, 2.9511e-10, 2.8313e-10, 2.7435e-10, 2.8123e-10,
#               3.6535e-10, 2.9389e-10, 2.9869e-10, 3.2349e-10, 2.6931e-10, 2.7496e-10,
#               3.1671e-10, 3.3034e-10, 3.1524e-10, 2.8406e-10, 3.1803e-10, 2.7203e-10,
#               2.6940e-10, 3.3620e-10, 2.7584e-10, 2.9428e-10, 3.0726e-10, 3.0318e-10,
#               2.7457e-10, 3.3149e-10, 3.0036e-10, 2.9706e-10, 3.2317e-10, 2.6539e-10,
#               3.1143e-10, 2.9708e-10, 3.4716e-10, 3.0338e-10, 3.3827e-10, 3.1002e-10,
#               3.0614e-10, 3.2326e-10, 3.5638e-10, 2.8350e-10, 3.2786e-10, 2.8090e-10,
#               3.3262e-10, 3.1456e-10, 2.8647e-10, 2.7454e-10, 3.0582e-10, 3.1351e-10,
#               3.0456e-10, 3.3105e-10, 3.2968e-10, 3.2822e-10, 3.1983e-10, 2.9512e-10,
#               2.9053e-10, 2.6947e-10, 3.2906e-10, 2.9389e-10, 2.7489e-10, 3.0787e-10,
#               2.7541e-10, 3.5665e-10, 2.7598e-10, 3.0028e-10, 3.1025e-10, 3.5121e-10,
#               2.7473e-10, 2.6457e-10, 2.8221e-10, 3.1730e-10], device='cuda:0'))
#     )
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): QuantConv2d(
#       256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0063], requires_grad=True), scale_factor=9.165062510874122e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0015], requires_grad=True), scale_factor=9.157729800790548e-05)
#       (w_quantizer): MinMaxWeight(precision=8, scale_factor=tensor([0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0008, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0005, 0.0007,
#               0.0006, 0.0005, 0.0005, 0.0005, 0.0005, 0.0007, 0.0006, 0.0006, 0.0005,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0007, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0005, 0.0007,
#               0.0006, 0.0008, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0005,
#               0.0006, 0.0005, 0.0007, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0007, 0.0007, 0.0008, 0.0005, 0.0005, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0005, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0007, 0.0005, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0005, 0.0006, 0.0005, 0.0005, 0.0007, 0.0006,
#               0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0005, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0005, 0.0006, 0.0006,
#               0.0006, 0.0005, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0005, 0.0005, 0.0005, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0005, 0.0005, 0.0007, 0.0005, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0007, 0.0005, 0.0005, 0.0006,
#               0.0007, 0.0007, 0.0005, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0007, 0.0005, 0.0007, 0.0007,
#               0.0006, 0.0005, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0008,
#               0.0006, 0.0006, 0.0006, 0.0005, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0005, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0005, 0.0006, 0.0006, 0.0005, 0.0005, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0005, 0.0007, 0.0007, 0.0006, 0.0007, 0.0006, 0.0005, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0005, 0.0006,
#               0.0006, 0.0006, 0.0005, 0.0006, 0.0005, 0.0005, 0.0008, 0.0005, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0005, 0.0007,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0005, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0005, 0.0006, 0.0007, 0.0005, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0008, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005,
#               0.0007, 0.0007, 0.0006, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0005, 0.0006, 0.0005, 0.0005, 0.0006, 0.0006, 0.0006, 0.0005,
#               0.0005, 0.0007, 0.0005, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0005, 0.0006, 0.0005, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0006,
#               0.0005, 0.0006, 0.0007, 0.0005, 0.0006, 0.0008, 0.0006, 0.0006, 0.0005,
#               0.0006, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006],
#              device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([5.7597e-08, 6.0490e-08, 5.3328e-08, 5.9462e-08, 5.3636e-08, 5.7455e-08,
#               5.0653e-08, 5.6903e-08, 5.3692e-08, 6.5642e-08, 5.2914e-08, 5.6919e-08,
#               5.8073e-08, 6.2494e-08, 5.1012e-08, 5.8134e-08, 5.1999e-08, 5.4848e-08,
#               4.9901e-08, 5.3337e-08, 5.3987e-08, 5.1386e-08, 5.3028e-08, 6.9038e-08,
#               5.0871e-08, 5.3990e-08, 6.5075e-08, 5.1268e-08, 5.2627e-08, 5.4566e-08,
#               5.0548e-08, 6.0332e-08, 5.9771e-08, 5.1248e-08, 5.0183e-08, 6.4569e-08,
#               5.3782e-08, 4.8621e-08, 4.9438e-08, 4.7567e-08, 5.0298e-08, 6.1104e-08,
#               5.5412e-08, 5.0728e-08, 4.9491e-08, 5.3119e-08, 5.4961e-08, 5.4744e-08,
#               5.4410e-08, 5.9540e-08, 5.5307e-08, 5.1600e-08, 5.6528e-08, 5.8684e-08,
#               4.9763e-08, 6.2165e-08, 5.8716e-08, 5.9515e-08, 4.9414e-08, 5.5817e-08,
#               5.6367e-08, 4.9483e-08, 6.2586e-08, 5.7957e-08, 7.3997e-08, 5.5560e-08,
#               5.5921e-08, 5.0092e-08, 5.3908e-08, 5.8152e-08, 5.2549e-08, 4.9826e-08,
#               5.3336e-08, 4.7187e-08, 6.0089e-08, 5.0747e-08, 5.0164e-08, 5.1641e-08,
#               5.9293e-08, 5.4968e-08, 6.0050e-08, 6.1951e-08, 6.2642e-08, 7.0797e-08,
#               4.9223e-08, 4.8368e-08, 5.5119e-08, 5.5380e-08, 6.0917e-08, 5.3570e-08,
#               4.6621e-08, 5.6745e-08, 5.4576e-08, 5.9604e-08, 6.2733e-08, 5.4674e-08,
#               5.4030e-08, 5.8175e-08, 5.6465e-08, 5.2979e-08, 6.2604e-08, 5.5120e-08,
#               5.4595e-08, 4.9982e-08, 6.7531e-08, 5.2397e-08, 5.0925e-08, 5.4171e-08,
#               5.4071e-08, 5.1268e-08, 4.9917e-08, 5.4385e-08, 5.6304e-08, 5.5659e-08,
#               5.9757e-08, 4.9069e-08, 5.1163e-08, 4.7651e-08, 5.5943e-08, 5.5838e-08,
#               4.9197e-08, 5.6366e-08, 5.0057e-08, 5.0132e-08, 6.8692e-08, 5.3237e-08,
#               5.0681e-08, 4.8094e-08, 5.4106e-08, 5.1465e-08, 5.5111e-08, 5.7167e-08,
#               5.3169e-08, 5.9417e-08, 5.5451e-08, 4.6768e-08, 5.6859e-08, 5.9041e-08,
#               5.4010e-08, 5.5360e-08, 5.3709e-08, 5.5890e-08, 5.3584e-08, 5.7419e-08,
#               5.1851e-08, 6.6822e-08, 4.6667e-08, 5.4230e-08, 5.2608e-08, 5.8102e-08,
#               5.1699e-08, 5.1361e-08, 5.2095e-08, 5.3304e-08, 5.3975e-08, 5.1518e-08,
#               5.5215e-08, 5.1569e-08, 5.5650e-08, 5.5079e-08, 5.3737e-08, 6.1915e-08,
#               5.3841e-08, 5.4027e-08, 5.5855e-08, 5.3055e-08, 5.5178e-08, 5.2453e-08,
#               4.9662e-08, 5.9219e-08, 5.5469e-08, 6.2298e-08, 5.1859e-08, 5.3404e-08,
#               5.6668e-08, 5.9587e-08, 5.1930e-08, 5.7848e-08, 5.4063e-08, 5.9956e-08,
#               5.2014e-08, 5.2698e-08, 5.3385e-08, 5.5164e-08, 5.5015e-08, 5.4027e-08,
#               6.0612e-08, 5.0332e-08, 5.6686e-08, 5.4665e-08, 5.8083e-08, 5.1272e-08,
#               5.1171e-08, 5.1961e-08, 4.5638e-08, 4.8670e-08, 5.2345e-08, 5.7902e-08,
#               5.2348e-08, 4.7113e-08, 5.3993e-08, 5.4310e-08, 6.4909e-08, 6.7297e-08,
#               5.7428e-08, 5.4229e-08, 5.2463e-08, 6.1194e-08, 5.6610e-08, 4.7423e-08,
#               4.9811e-08, 4.9180e-08, 5.1739e-08, 5.9675e-08, 5.7724e-08, 5.6234e-08,
#               5.3133e-08, 5.6521e-08, 6.1992e-08, 5.8141e-08, 5.2175e-08, 6.2298e-08,
#               5.2596e-08, 5.4652e-08, 6.4168e-08, 5.7142e-08, 5.3869e-08, 4.7677e-08,
#               4.7469e-08, 6.2484e-08, 5.0132e-08, 5.4617e-08, 5.6083e-08, 5.9586e-08,
#               5.0702e-08, 5.8944e-08, 6.4778e-08, 5.5969e-08, 6.0555e-08, 6.1791e-08,
#               5.0325e-08, 4.6425e-08, 5.2892e-08, 6.0153e-08, 6.3517e-08, 4.7921e-08,
#               6.0789e-08, 5.0508e-08, 5.5781e-08, 5.7395e-08, 5.5408e-08, 5.3085e-08,
#               5.1764e-08, 5.4610e-08, 4.9812e-08, 5.2954e-08, 5.9089e-08, 5.1566e-08,
#               5.5630e-08, 5.8971e-08, 5.5502e-08, 6.0613e-08, 5.4593e-08, 5.2823e-08,
#               5.7065e-08, 5.1096e-08, 5.0263e-08, 5.1413e-08, 5.5339e-08, 5.2769e-08,
#               5.1932e-08, 5.0264e-08, 5.3893e-08, 5.6811e-08, 5.6770e-08, 5.4179e-08,
#               5.9275e-08, 5.6684e-08, 5.3763e-08, 5.8209e-08, 5.4414e-08, 5.1464e-08,
#               5.2696e-08, 4.7722e-08, 6.0455e-08, 4.2907e-08, 6.3938e-08, 5.9863e-08,
#               5.4712e-08, 4.9506e-08, 5.2497e-08, 6.1021e-08, 5.2921e-08, 5.8631e-08,
#               6.4209e-08, 5.6410e-08, 6.8775e-08, 5.0510e-08, 5.2770e-08, 5.3477e-08,
#               4.7623e-08, 5.6585e-08, 4.4679e-08, 5.7894e-08, 5.9017e-08, 5.3451e-08,
#               5.5758e-08, 5.1084e-08, 5.6123e-08, 4.8167e-08, 5.7356e-08, 6.5849e-08,
#               5.2106e-08, 5.9510e-08, 5.8102e-08, 5.7357e-08, 5.7203e-08, 5.8687e-08,
#               5.0028e-08, 5.0503e-08, 5.2509e-08, 5.7210e-08, 5.6105e-08, 5.0528e-08,
#               4.9624e-08, 4.4848e-08, 5.3912e-08, 5.0759e-08, 4.8646e-08, 4.8851e-08,
#               5.3851e-08, 5.0469e-08, 5.1924e-08, 4.7712e-08, 5.0305e-08, 6.0261e-08,
#               6.0747e-08, 5.0769e-08, 5.9738e-08, 5.3848e-08, 4.8586e-08, 5.4747e-08,
# ...
#               5.7375e-08, 6.7994e-08, 5.1494e-08, 5.9393e-08, 7.1443e-08, 5.0621e-08,
#               6.7930e-08, 5.4464e-08, 5.9819e-08, 5.2434e-08, 5.0533e-08, 5.7736e-08,
#               5.3867e-08, 5.4407e-08, 5.5692e-08, 5.5894e-08, 5.7553e-08, 5.2934e-08,
#               5.1620e-08, 5.3466e-08, 5.1059e-08, 6.5107e-08, 5.3943e-08, 5.1343e-08,
#               6.0321e-08, 5.0547e-08, 5.0843e-08, 5.8972e-08, 6.1329e-08, 5.5352e-08,
#               5.4692e-08, 5.3578e-08, 7.0655e-08, 5.5064e-08, 5.8922e-08, 5.0488e-08,
#               4.6827e-08, 5.9743e-08], device='cuda:0'))
#     )
#     (27): ReLU(inplace=True)
#     (28): QuantConv2d(
#       512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0052], requires_grad=True), scale_factor=9.163349022855982e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0094], requires_grad=True), scale_factor=9.169772965833545e-05)
#       (w_quantizer): MinMaxWeight(precision=8, scale_factor=tensor([0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0005, 0.0007, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0008, 0.0007, 0.0007, 0.0007, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0008, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0005, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0007,
#               0.0007, 0.0006, 0.0006, 0.0007, 0.0007, 0.0007, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0008, 0.0007, 0.0007, 0.0005, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0005,
#               0.0007, 0.0006, 0.0005, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0008, 0.0006, 0.0006, 0.0005, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0007, 0.0006, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0007, 0.0005, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0007, 0.0007, 0.0005, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0007, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0008, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0007, 0.0007,
#               0.0007, 0.0007, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0007,
#               0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0008, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007,
#               0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0008, 0.0007, 0.0007, 0.0005,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0006, 0.0007, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0007,
#               0.0006, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0007, 0.0006, 0.0006, 0.0007, 0.0008, 0.0006, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0007, 0.0007, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0005, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006,
#               0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007, 0.0006, 0.0006,
#               0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0007, 0.0006, 0.0007],
#              device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([6.2493e-08, 5.3221e-08, 5.6828e-08, 5.2220e-08, 5.5875e-08, 5.6392e-08,
#               6.6513e-08, 5.3423e-08, 6.8225e-08, 5.6075e-08, 5.6917e-08, 5.3379e-08,
#               5.4040e-08, 6.5411e-08, 5.2837e-08, 5.3658e-08, 5.7108e-08, 6.3176e-08,
#               5.4911e-08, 5.4510e-08, 5.8894e-08, 6.7877e-08, 5.4166e-08, 5.7629e-08,
#               5.4564e-08, 6.2249e-08, 5.3944e-08, 5.5153e-08, 5.7962e-08, 4.9957e-08,
#               6.0221e-08, 6.0840e-08, 5.1457e-08, 6.4484e-08, 5.7090e-08, 5.8356e-08,
#               5.1546e-08, 5.9365e-08, 6.7120e-08, 5.5114e-08, 6.4471e-08, 6.1994e-08,
#               6.5901e-08, 5.9294e-08, 5.6576e-08, 5.0921e-08, 5.5600e-08, 5.6235e-08,
#               5.7544e-08, 5.4847e-08, 6.3861e-08, 5.5169e-08, 5.7600e-08, 5.0557e-08,
#               5.6644e-08, 5.5060e-08, 5.9852e-08, 7.0447e-08, 6.0521e-08, 6.1491e-08,
#               6.0911e-08, 6.3366e-08, 5.7171e-08, 5.3689e-08, 5.2450e-08, 5.7732e-08,
#               5.2908e-08, 5.6743e-08, 5.5784e-08, 5.4647e-08, 6.0808e-08, 6.2890e-08,
#               5.7145e-08, 6.0305e-08, 5.4674e-08, 5.5969e-08, 5.8912e-08, 5.8290e-08,
#               7.1455e-08, 5.6854e-08, 5.8038e-08, 6.0609e-08, 5.6073e-08, 5.3504e-08,
#               5.6108e-08, 6.0602e-08, 5.5762e-08, 5.5628e-08, 5.5651e-08, 5.9318e-08,
#               4.7930e-08, 5.1830e-08, 5.8742e-08, 6.0105e-08, 5.5165e-08, 6.2626e-08,
#               5.9510e-08, 5.5580e-08, 5.6839e-08, 6.0709e-08, 5.6454e-08, 5.8982e-08,
#               5.5936e-08, 5.9173e-08, 5.6593e-08, 5.4195e-08, 6.1298e-08, 5.6637e-08,
#               5.9208e-08, 5.5896e-08, 5.9952e-08, 5.9247e-08, 5.8324e-08, 5.2646e-08,
#               5.2896e-08, 5.6214e-08, 5.0991e-08, 6.3428e-08, 5.3281e-08, 5.8005e-08,
#               5.5053e-08, 5.7815e-08, 6.0919e-08, 6.4783e-08, 5.5836e-08, 6.1320e-08,
#               6.5585e-08, 5.1993e-08, 5.7870e-08, 6.5936e-08, 6.0755e-08, 6.0005e-08,
#               5.2789e-08, 6.3971e-08, 5.6096e-08, 5.5288e-08, 6.1380e-08, 6.6109e-08,
#               5.9259e-08, 5.9036e-08, 5.6933e-08, 5.2710e-08, 5.7708e-08, 5.5738e-08,
#               6.3643e-08, 6.8986e-08, 6.1425e-08, 6.4585e-08, 4.9212e-08, 5.9177e-08,
#               5.4307e-08, 5.6512e-08, 5.9093e-08, 6.0227e-08, 6.0664e-08, 5.1968e-08,
#               5.4529e-08, 5.4010e-08, 6.4013e-08, 5.9339e-08, 5.5563e-08, 4.9404e-08,
#               6.2576e-08, 5.4370e-08, 5.0079e-08, 6.3924e-08, 5.9977e-08, 6.4734e-08,
#               5.5359e-08, 5.0927e-08, 5.3991e-08, 6.3439e-08, 6.3607e-08, 5.4094e-08,
#               5.2917e-08, 5.7685e-08, 6.0679e-08, 6.0376e-08, 5.3995e-08, 5.5491e-08,
#               6.0710e-08, 5.6829e-08, 5.3603e-08, 5.7714e-08, 7.3221e-08, 5.2150e-08,
#               5.3868e-08, 5.0370e-08, 5.6721e-08, 5.5279e-08, 5.6751e-08, 6.1098e-08,
#               5.4582e-08, 5.7324e-08, 6.0268e-08, 5.7814e-08, 6.0315e-08, 5.5923e-08,
#               5.3149e-08, 5.6867e-08, 5.6606e-08, 6.3934e-08, 5.9614e-08, 5.3327e-08,
#               5.4675e-08, 5.7091e-08, 6.0142e-08, 6.2443e-08, 5.8107e-08, 6.2606e-08,
#               5.2869e-08, 6.0983e-08, 5.5501e-08, 5.4772e-08, 6.3772e-08, 5.6949e-08,
#               6.1096e-08, 6.2875e-08, 5.6663e-08, 6.1060e-08, 5.0321e-08, 5.8481e-08,
#               5.7821e-08, 6.2320e-08, 5.5083e-08, 6.2181e-08, 6.3925e-08, 5.0293e-08,
#               5.2125e-08, 6.1644e-08, 5.7964e-08, 5.6074e-08, 5.6864e-08, 6.5233e-08,
#               5.4345e-08, 6.4877e-08, 5.5176e-08, 5.2823e-08, 5.6507e-08, 5.0907e-08,
#               5.9165e-08, 5.3430e-08, 5.3979e-08, 6.0470e-08, 5.8678e-08, 5.1766e-08,
#               5.5165e-08, 5.1952e-08, 6.2102e-08, 5.8703e-08, 5.7176e-08, 5.3747e-08,
#               6.0893e-08, 6.4037e-08, 6.5505e-08, 5.7338e-08, 5.1059e-08, 5.6692e-08,
#               5.1816e-08, 5.2709e-08, 5.2313e-08, 5.3909e-08, 5.5059e-08, 5.5494e-08,
#               5.5934e-08, 5.0191e-08, 6.3184e-08, 5.2686e-08, 6.0710e-08, 5.4167e-08,
#               5.8601e-08, 6.1868e-08, 5.9771e-08, 5.6704e-08, 5.7890e-08, 5.7011e-08,
#               6.9071e-08, 5.8855e-08, 5.6594e-08, 6.7399e-08, 6.0549e-08, 5.5124e-08,
#               5.0545e-08, 6.2101e-08, 5.5224e-08, 5.9549e-08, 5.5374e-08, 6.0062e-08,
#               5.5465e-08, 6.2434e-08, 5.5176e-08, 5.7940e-08, 5.4442e-08, 6.0300e-08,
#               6.2558e-08, 6.4037e-08, 6.7546e-08, 6.4479e-08, 6.2981e-08, 6.7353e-08,
#               5.7104e-08, 6.0041e-08, 5.4954e-08, 5.0860e-08, 5.1633e-08, 6.4684e-08,
#               5.6853e-08, 5.8191e-08, 5.7253e-08, 6.1666e-08, 5.5135e-08, 6.2837e-08,
#               5.5950e-08, 5.6751e-08, 5.5664e-08, 6.3554e-08, 5.2406e-08, 5.5219e-08,
#               5.5342e-08, 6.5297e-08, 5.4843e-08, 5.5280e-08, 5.3678e-08, 5.0691e-08,
#               5.3591e-08, 5.4003e-08, 5.9165e-08, 5.7783e-08, 6.0880e-08, 5.1829e-08,
#               5.6116e-08, 6.3077e-08, 6.2191e-08, 5.7608e-08, 5.7846e-08, 6.2763e-08,
#               5.5143e-08, 5.6304e-08, 5.1954e-08, 6.2599e-08, 5.2894e-08, 6.1028e-08,
#               5.1809e-08, 5.2838e-08, 7.0741e-08, 5.3402e-08, 5.3912e-08, 5.9464e-08,
#               5.3647e-08, 5.4553e-08, 6.4069e-08, 5.6338e-08, 5.3020e-08, 5.9740e-08,
#               6.5300e-08, 5.6537e-08, 5.4709e-08, 5.9349e-08, 6.2096e-08, 5.1713e-08,
#               5.5726e-08, 5.6124e-08, 6.5871e-08, 6.5249e-08, 6.3897e-08, 5.1630e-08,
#               5.5425e-08, 5.6863e-08, 5.8871e-08, 5.6362e-08, 5.5634e-08, 5.9194e-08,
#               6.3108e-08, 6.0510e-08, 5.7819e-08, 5.5258e-08, 6.3285e-08, 5.1938e-08,
#               5.1040e-08, 5.9715e-08, 6.4657e-08, 5.0795e-08, 5.3560e-08, 6.9107e-08,
#               6.0333e-08, 6.0971e-08, 4.6328e-08, 5.6096e-08, 5.6440e-08, 5.5921e-08,
#               5.7948e-08, 5.5276e-08, 5.4164e-08, 5.7310e-08, 6.5508e-08, 5.5375e-08,
#               5.2261e-08, 5.1406e-08, 5.2657e-08, 5.3516e-08, 6.4270e-08, 5.5494e-08,
#               5.6270e-08, 5.4309e-08, 5.1109e-08, 5.4659e-08, 5.9887e-08, 5.1817e-08,
#               6.2362e-08, 6.1334e-08, 6.1953e-08, 6.0159e-08, 5.1568e-08, 5.7739e-08,
#               5.6946e-08, 5.5158e-08, 5.8513e-08, 5.9878e-08, 5.1193e-08, 5.7483e-08,
#               6.0490e-08, 5.4946e-08, 5.2434e-08, 5.7730e-08, 5.3542e-08, 6.5288e-08,
#               6.7399e-08, 5.8120e-08, 5.4621e-08, 5.7477e-08, 6.4835e-08, 6.1650e-08,
#               5.9192e-08, 5.3480e-08, 6.2202e-08, 6.2041e-08, 5.7641e-08, 5.1795e-08,
#               5.7050e-08, 5.4573e-08, 5.7353e-08, 6.4592e-08, 6.7969e-08, 5.5792e-08,
#               5.5012e-08, 5.2313e-08, 6.2473e-08, 5.6298e-08, 5.6942e-08, 5.7381e-08,
#               5.8199e-08, 6.0673e-08, 5.1975e-08, 5.6780e-08, 6.2877e-08, 6.8963e-08,
#               5.9191e-08, 5.3770e-08, 5.3788e-08, 6.3974e-08, 5.3701e-08, 5.9602e-08,
#               6.0088e-08, 5.2943e-08, 5.0737e-08, 6.3727e-08, 5.6466e-08, 5.8935e-08,
#               5.7342e-08, 5.5556e-08, 5.1459e-08, 6.0587e-08, 5.3378e-08, 5.7287e-08,
#               5.1863e-08, 5.5350e-08, 5.7479e-08, 5.5590e-08, 5.3778e-08, 5.1450e-08,
#               6.1617e-08, 5.3781e-08, 5.4129e-08, 5.7037e-08, 5.9039e-08, 5.7805e-08,
#               5.8716e-08, 5.3140e-08, 5.4063e-08, 4.9852e-08, 6.0344e-08, 6.4065e-08,
#               5.3428e-08, 5.2224e-08, 5.3262e-08, 5.9471e-08, 5.5623e-08, 5.6796e-08,
#               5.2913e-08, 6.0121e-08, 5.4285e-08, 6.4062e-08, 5.5346e-08, 5.8504e-08,
#               6.1325e-08, 5.5973e-08, 5.1907e-08, 5.8217e-08, 5.4540e-08, 5.9809e-08,
#               5.7413e-08, 6.0966e-08], device='cuda:0'))
#     )
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Module(
#     (0): QuantLinear(
#       in_features=25088, out_features=4096, bias=True
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0094], requires_grad=True), scale_factor=9.169772965833545e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0042], requires_grad=True), scale_factor=9.16184508241713e-05)
#       (w_quantizer): MinMaxWeight(precision=8, scale_factor=tensor([0.0003, 0.0003, 0.0004,  ..., 0.0004, 0.0003, 0.0003], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([3.1061e-08, 2.9734e-08, 3.2870e-08,  ..., 3.3292e-08, 3.0402e-08,
#               3.0947e-08], device='cuda:0'))
#     )
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): QuantLinear(
#       in_features=4096, out_features=4096, bias=True
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0042], requires_grad=True), scale_factor=9.16184508241713e-05)
#       (out_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0000], requires_grad=True), scale_factor=9.155402221949771e-05)
#       (w_quantizer): MinMaxWeight(precision=8, scale_factor=tensor([0.0003, 0.0003, 0.0003,  ..., 0.0003, 0.0003, 0.0003], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([2.6870e-08, 2.6487e-08, 2.8261e-08,  ..., 2.5933e-08, 2.9229e-08,
#               2.7700e-08], device='cuda:0'))
#     )
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): QuantLinear(
#       in_features=4096, out_features=10, bias=True
#       (in_quantizer): PACTAct(precision=16, clip_val=Parameter containing:
#       tensor([6.0000], requires_grad=True), scale_factor=9.155402221949771e-05)
#       (out_quantizer): DummyQuantizer(precision=None (dummy quantizer), scale_factor=1.0)
#       (w_quantizer): MinMaxWeight(precision=16, scale_factor=tensor([1.3248e-06, 1.2514e-06, 1.2681e-06, 1.2420e-06, 1.3987e-06, 1.2554e-06,
#               1.2507e-06, 1.1633e-06, 1.2032e-06, 1.1967e-06], device='cuda:0'))
#       (b_quantizer): QuantizerBias(precision=32, scale_factor=tensor([1.2129e-10, 1.1457e-10, 1.1610e-10, 1.1371e-10, 1.2806e-10, 1.1494e-10,
#               1.1451e-10, 1.0650e-10, 1.1016e-10, 1.0957e-10], device='cuda:0'))
#     )
#   )
# )

# %% [markdown]
# #### **LIMITATION**
#
# The exported model does not come with changed data types according to the precisions found during MPS. Rather, it comes with quantizers (_e.g._ `in_quantizer`, `out_quantizer`, `w_quantizer`, `b_quantizer`) for each layer considered during optimization. That's why there is no gain in memory space (the size of the model is equal to the baseline) and the model takes much more time for inference.

# %%
# Look at layers' datatypes
for name, param in MPS_model.named_parameters():
    print(f'Parameter: {name} -> Precision: {param.dtype}')
# Out:
# Parameter: x_input_quantizer.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.0.weight -> Precision: torch.float32
# Parameter: features.0.bias -> Precision: torch.float32
# Parameter: features.0.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.2.weight -> Precision: torch.float32
# Parameter: features.2.bias -> Precision: torch.float32
# Parameter: features.2.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.5.weight -> Precision: torch.float32
# Parameter: features.5.bias -> Precision: torch.float32
# Parameter: features.5.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.7.weight -> Precision: torch.float32
# Parameter: features.7.bias -> Precision: torch.float32
# Parameter: features.7.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.10.weight -> Precision: torch.float32
# Parameter: features.10.bias -> Precision: torch.float32
# Parameter: features.10.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.12.weight -> Precision: torch.float32
# Parameter: features.12.bias -> Precision: torch.float32
# Parameter: features.12.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.14.weight -> Precision: torch.float32
# Parameter: features.14.bias -> Precision: torch.float32
# Parameter: features.14.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.17.weight -> Precision: torch.float32
# Parameter: features.17.bias -> Precision: torch.float32
# Parameter: features.17.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.19.weight -> Precision: torch.float32
# Parameter: features.19.bias -> Precision: torch.float32
# Parameter: features.19.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.21.weight -> Precision: torch.float32
# Parameter: features.21.bias -> Precision: torch.float32
# Parameter: features.21.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.24.weight -> Precision: torch.float32
# Parameter: features.24.bias -> Precision: torch.float32
# Parameter: features.24.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.26.weight -> Precision: torch.float32
# Parameter: features.26.bias -> Precision: torch.float32
# Parameter: features.26.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: features.28.weight -> Precision: torch.float32
# Parameter: features.28.bias -> Precision: torch.float32
# Parameter: features.28.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: classifier.0.weight -> Precision: torch.float32
# Parameter: classifier.0.bias -> Precision: torch.float32
# Parameter: classifier.0.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: classifier.3.weight -> Precision: torch.float32
# Parameter: classifier.3.bias -> Precision: torch.float32
# Parameter: classifier.3.out_quantizer.clip_val -> Precision: torch.float32
# Parameter: classifier.6.weight -> Precision: torch.float32
# Parameter: classifier.6.bias -> Precision: torch.float32

# %% [markdown]
# ## 4.5 VGG16 with SuperNet optimization

# %%
# Model
SuperNet_model = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_SuperNet.pth')

# Results
size_mb = utils.model_size(model=SuperNet_model)
SuperNet_model_results = utils.evaluate_model(model=SuperNet_model, device=device, loss_fn=loss_fn, data_loader=test_dataloader)

# Compare the results with the standard model
size_ratio = size_mb / size_mb_baseline

print(f'''SuperNet optimization Results (on {SuperNet_model_results['device']}):
    - Model size: {size_mb:.3f} MB -> {((1 - size_ratio)*100):.2f}% lighter than baseline
    - Total inference time: {SuperNet_model_results['total_inference_time']:.3f} seconds
    - Inference time per batch: {SuperNet_model_results['avg_inference_time']:.3f} milliseconds
    - Minimum inference time: {SuperNet_model_results['min_inference_time']:.3f} milliseconds
    - Average loss: {SuperNet_model_results['avg_loss']:.5f}
    - Average accuracy: {(SuperNet_model_results['avg_acc']*100):.2f} %''')
# Out:
# SuperNet optimization Results (on cuda):
#     - Model size: 136.206 MB -> 73.41% lighter than baseline
#     - Total inference time: 3.366 seconds
#     - Inference time per batch: 5.385 milliseconds
#     - Minimum inference time: 3.276 milliseconds
#     - Average loss: 0.30037
#     - Average accuracy: 91.97 %

# %%
SuperNet_model
# Out:
# GraphModule(
#   (features): Module(
#     (sn_branches): Module(
#       (3): Module(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Module(
#     (sn_branches): Module(
#       (3): Module(
#         (0): Linear(in_features=25088, out_features=1024, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=1024, out_features=10, bias=True)
#       )
#     )
#   )
# )

# %%
# Model
SuperNet_duccio_model = torch.load('./Models_checkpoints/notMNIST/VGG16_notMNIST_SuperNet_duccio.pth')

# Results
size_mb = utils.model_size(model=SuperNet_duccio_model)
SuperNet_duccio_model_results = utils.evaluate_model(model=SuperNet_duccio_model, device=device, loss_fn=loss_fn, data_loader=test_dataloader)

# Compare the results with the standard model
size_ratio = size_mb / size_mb_baseline

print(f'''SuperNet optimization Results (on {SuperNet_duccio_model_results['device']}):
    - Model size: {size_mb:.3f} MB -> {((1 - size_ratio)*100):.2f}% lighter than baseline
    - Total inference time: {SuperNet_duccio_model_results['total_inference_time']:.3f} seconds
    - Inference time per batch: {SuperNet_duccio_model_results['avg_inference_time']:.3f} milliseconds
    - Minimum inference time: {SuperNet_duccio_model_results['min_inference_time']:.3f} milliseconds
    - Average loss: {SuperNet_duccio_model_results['avg_loss']:.5f}
    - Average accuracy: {(SuperNet_duccio_model_results['avg_acc']*100):.2f} %''')
# Out:
# SuperNet optimization Results (on cuda):
#     - Model size: 136.206 MB -> 73.41% lighter than baseline
#     - Total inference time: 3.287 seconds
#     - Inference time per batch: 5.259 milliseconds
#     - Minimum inference time: 3.464 milliseconds
#     - Average loss: 0.29239
#     - Average accuracy: 92.08 %

# %%
SuperNet_duccio_model
# Out:
# GraphModule(
#   (features): Module(
#     (sn_branches): Module(
#       (3): Module(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): ReLU(inplace=True)
#         (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): ReLU(inplace=True)
#         (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): ReLU(inplace=True)
#         (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): ReLU(inplace=True)
#         (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (20): ReLU(inplace=True)
#         (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): ReLU(inplace=True)
#         (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (27): ReLU(inplace=True)
#         (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#         (29): ReLU(inplace=True)
#         (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Module(
#     (sn_branches): Module(
#       (3): Module(
#         (0): Linear(in_features=25088, out_features=1024, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Dropout(p=0.5, inplace=False)
#         (3): Linear(in_features=1024, out_features=10, bias=True)
#       )
#     )
#   )
# )
